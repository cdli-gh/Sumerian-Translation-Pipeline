# %%
import nltk
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize
from sklearn_crfsuite import CRF
from sklearn_crfsuite import metrics
from sklearn_crfsuite import scorers
from collections import Counter
import re

# %%
#nltk.download('treebank')
#nltk.download('universal_tagset')

# %%
df=pd.read_csv('../Dataset/Augmented_NER_training_ml.csv')
df=df[['ID','FORM','NER']]

# %%
df.groupby('NER').count()
# Out:
#         ID   FORM
# NER
# AN       1      1
# DN     909    909
# EN      60     60
# FN    1463   1463
# GN    1351   1351
# MN      79     79
# O    38822  38822
# ON      18     18
# PN   17729  17729
# RN     150    150
# SN     521    521
# TN      60     60
# WN     304    304

# %%
df
# Out:
#           ID                  FORM NER
# 0          1               2(disz)   O
# 1          1                 sag-x  PN
# 2          2                 giri3   O
# 3          2          {d}nanna-ag2  PN
# 4          3                    mu   O
# ...      ...                   ...  ..
# 61462  22727                   zi3   O
# 61463  22727                    u4   O
# 61464  22727           2(disz)-kam   O
# 61465  22728  lugal-{gesz}gigir-re  PN
# 61466  22728          aga3-us2-gal   O
#
# [61467 rows x 3 columns]

# %%
def Preparing_tagged_data(df):
    tagged_sentence=[]
    c=1
    temp=[]
    for i in range(len(df)):
        if df['ID'][i]==c:
            temp.append((df['FORM'][i],df['NER'][i]))
        else:
            tagged_sentence.append(temp)
            temp=[]
            temp.append((df['FORM'][i],df['NER'][i]))
            c+=1
    tagged_sentence.append(temp)
    return tagged_sentence
tagged_sentence=Preparing_tagged_data(df)

# %%
#l=[tagged_sentences[i] for i in range(len(tagged_sentences)) if len(tagged_sentences[i])==1]
#print('Phrases with single words')
#print(len(l))

# %%
tagged_sentence[0]
# Out:
# [('2(disz)', 'O'), ('sag-x', 'PN')]

# %%
#s='1(disz)'
#re.search(r'\d+\(\w+\)',s)

# %%
print("Number of Tagged Sentences ",len(tagged_sentence))
tagged_words=[tup for sent in tagged_sentence for tup in sent]
print("Total Number of Tagged words", len(tagged_words))
vocab=set([word for word,tag in tagged_words])
print("Vocabulary of the Corpus",len(vocab))
tags=set([tag for word,tag in tagged_words])
print("Number of Tags in the Corpus ",len(tags))
# Out:
# Number of Tagged Sentences  22728
# Total Number of Tagged words 61467
# Vocabulary of the Corpus 21556
# Number of Tags in the Corpus  13

# %%
train_set, test_set = train_test_split(tagged_sentence,test_size=0.1,random_state=42)
print("Number of Sentences in Training Data ",len(train_set))
print("Number of Sentences in Testing Data ",len(test_set))
# Out:
# Number of Sentences in Training Data  20455
# Number of Sentences in Testing Data  2273

# %%
test_set
# Out:
# [[('2(disz)', 'O'), ('da-dam', 'PN'), ('dumu', 'O'), ('...-in', 'PN')],
#  [('1(barig)', 'O'),
#   ('2(ban2)', 'O'),
#   ('sze', 'O'),
#   ('ur5-ra', 'O'),
#   ('kiszib3', 'O'),
#   ('a-bu-um-...', 'PN')],
#  [('udu', 'O'), ('{d}utu-ka', 'DN')],
#  [('kiszib3', 'O'), ('u4-ma-ni-gar', 'PN')],
#  [('ugu2', 'O'),
#   ('i-din-esz18-dar', 'PN'),
#   ('dumu', 'O'),
#   ('nin-anzu2{muszen}', 'PN'),
#   ('ga2-ga2-dam', 'O')],
#  [('ki', 'O'), ('e2-...', 'PN')],
#  [('giri3', 'O'), ('ur-sza-nig2-sza3-ge', 'PN'), ('sa12-du5', 'O')],
#  [('giri3', 'O'), ('du-uk-ra', 'PN')],
#  [('geme2-{d}amar-{d}suen', 'PN')],
#  [('ki', 'O'), ('ur-ab-ba-ta', 'PN')],
#  [('ugula', 'O'), ('ab-ba-sa6-ga-a', 'PN')],
#  [('1(disz)', 'O'), ('tug2', 'O'), ('{d}bala-a', 'PN'), ('iszib', 'O')],
#  [('ama-na-si', 'PN'), ('szu', 'O'), ('ba-ti', 'O')],
#  [('{d}nin-mar{ki}-i3-sa6', 'PN')],
#  [('2(disz)', 'O'), ('udu', 'O'), ('niga', 'O'), ('{d}nin-szir', 'DN')],
#  [('kab2-ku5', 'O'), ('tur-an-na', 'FN')],
#  [('giri3', 'O'), ('SZIM', 'PN')],
#  [('3(ban2)', 'O'),
#   ('sze', 'O'),
#   ('ur-{gesz}gigir', 'PN'),
#   ('lu2', 'O'),
#   ('azlag2', 'O')],
#  [('2(asz)', 'O'), ('2(barig)', 'O'), ('lugal-mu-x', 'PN')],
#  [('mu', 'O'),
#   ('i-tur-dingir', 'PN'),
#   ('{d}inanna', 'DN'),
#   ('unu{ki}', 'SN'),
#   ('ba-hun', 'O')],
#  [('ki', 'O'), ('{d}en-ki-BAD3@s', 'PN')],
#  [('dumu', 'O'), ('lugal-za3-am3', 'PN')],
#  [('mu', 'O'),
#   ('e2', 'O'),
#   ('{d}mes-lam-ta-e3', 'DN'),
#   ('umma{ki}-ka', 'SN'),
#   ('ba-du3', 'O')],
#  [('mu', 'O'),
#   ('us2-sa', 'O'),
#   ('ki-isz-ga-ti{ki}-me-esz2', 'GN'),
#   ('ba-hul', 'O')],
#  [('lugal-sa6-ga', 'PN')],
#  [('a2-bi', 'O'),
#   ('u4', 'O'),
#   ('6(gesz2)', 'O'),
#   ('4(u)', 'O'),
#   ('7(disz)-kam', 'O')],
#  [('n', 'O'),
#   ('n(barig)', 'O'),
#   ('1(ban2)', 'O'),
#   ('gur', 'O'),
#   ('ki', 'O'),
#   ('ab-ba-kal-la', 'PN')],
#  [('dumu', 'O'), ('na-ab-ri2-lum-ma', 'PN'), ('ba-usz2', 'O')],
#  [('dumu', 'O'), ('ha-la-{d}ba-ba6', 'PN')],
#  [('n', 'O'),
#   ('n(barig)', 'O'),
#   ('1(ban2)', 'O'),
#   ('gur', 'O'),
#   ('ki', 'O'),
#   ('i3-lu-lu-tar-si', 'PN')],
#  [('u3', 'O'), ('a-sza3', 'O'), ('ga2-ni-ab-ba-na', 'FN')],
#  [('2(u)', 'O'),
#   ('...', 'O'),
#   ('{kusz}e-sir2', 'O'),
#   ('kusz', 'O'),
#   ('gu4', 'O')],
#  [('ninda-sag10', 'PN')],
#  [('ugula', 'O'), ('e2-u6', 'PN')],
#  [('a-ga-lum', 'PN')],
#  [('ki-ur2-...', 'PN'), ('maszkim', 'O')],
#  [('giri3', 'O'), ('{d}dug', 'PN')],
#  [('giri3', 'O'), ('nin9-ab-ba', 'PN'), ('sukkal', 'O'), ('lugal', 'O')],
#  [('7(asz)', 'O'), ('2(barig)', 'O'), ('mu', 'O'), ('nin-x-x-zi', 'PN')],
#  [('kab2-ku5', 'O'), ('a-bu3', 'FN'), ('gub-ba', 'O')],
#  [('nig2-erim2-x', 'PN')],
#  [('ki', 'O'), ('ur-{gesz}x-x', 'PN')],
#  [('{d}szul-gi-a-al', 'PN')],
#  [('lugal', 'O'), ('u2-za-ar-i-mi-lum{ki}', 'GN'), ('en-kal-dim2{ki}', 'GN')],
#  [('...', 'O'), ('{d}en-lil2-UD-x', 'PN'), ('nu-banda3', 'O')],
#  [('ur2-ra-AN', 'PN')],
#  [('giri3', 'O'), ('nin-utu', 'PN')],
#  [('kab2-ku5', 'O'), ('gibil', 'FN')],
#  [('hu-ba-{d}szul-gi-da-asz', 'PN'), ('...{ki}', 'SN')],
#  [('ki', 'O'), ('ur-da-da-da', 'PN')],
#  [('ki', 'O'), ('{d}mes-lam-ma', 'PN')],
#  [('zu-szim', 'PN')],
#  [('nibru{ki}-da-lu2', 'PN')],
#  [('giri3', 'O'), ('sze-ri-e2-igi-il2-la', 'PN')],
#  [('usz2', 'O'), ('lugal-men', 'PN')],
#  [('dumu', 'O'), ('ur-{d}dumu', 'PN')],
#  [('geme2-KU-KU', 'PN')],
#  [('4(barig)', 'O'), ('ki', 'O'), ('an-ne2-ba-ab-du7', 'PN'), ('...-ta', 'O')],
#  [('1(gesz2)', 'O'),
#   ('gur', 'O'),
#   ('kiszib3', 'O'),
#   ('{d}al-la-sza-ni-sza', 'PN'),
#   ('dumu', 'O'),
#   ('{d}ama-esz3-{d}ba-ba6', 'PN')],
#  [('giri3', 'O'), ('dan-na-li', 'PN')],
#  [('mu', 'O'), ('us2-sa', 'O'), ('ga2-nun-na', 'GN'), ('ba-hul', 'O')],
#  [('ki', 'O'), ('szim-da-ku-ni', 'PN')],
#  [('szu', 'O'), ('ba-an-ti', 'O')],
#  [('a-sza3', 'O'), ('gu2', 'O'), ('i7', 'O'), ('i7-musz-bi-an-na', 'WN')],
#  [('|PU3.SZA|-{d}suen', 'PN'), ('dumu', 'O'), ('nu-banda3', 'O')],
#  [('dingir-ra', 'PN')],
#  [('{d}ba-ba6-x-x', 'PN')],
#  [('ki', 'O'), ('{d}en-lil2-ri-su-szu', 'PN')],
#  [('u3-na-a-du11', 'O')],
#  [('ki', 'O'), ('e3-de3-bi', 'PN')],
#  [('a-sza3', 'O'), ('me-lam2', 'FN')],
#  [('5(disz)', 'O'),
#   ('udu', 'O'),
#   ('niga', 'O'),
#   ('1(disz)', 'O'),
#   ('sila4', 'O'),
#   ('a-kal-la-mu', 'PN')],
#  [('da-ri2-isz-ma-tum', 'PN')],
#  [('sza3-la2-su3', 'PN')],
#  [('mu', 'O'), ('ga-a-ga-mu', 'PN'), ('{d}inanna', 'DN'), ('ba-hun', 'O')],
#  [('3(asz)', 'O'),
#   ('3(barig)', 'O'),
#   ('3(ban2)', 'O'),
#   ('gur', 'O'),
#   ('ki', 'O'),
#   ('im-x', 'PN')],
#  [('er3-ra-da-an', 'PN')],
#  [('1(bur3)', 'O'),
#   ('1(esze3)', 'O'),
#   ('2(iku)', 'O'),
#   ('GAN2', 'O'),
#   ('a-sza3', 'O'),
#   ('nesag2', 'FN')],
#  [('7(disz)', 'O'), ('sar', 'O'), ('kab2-ku5', 'O'), ('sal-le-sa6', 'FN')],
#  [('giri3', 'O'), ('a-ab-ba-...', 'PN')],
#  [('ki', 'O'), ('za-na-a', 'PN')],
#  [('dumu', 'O'), ('u2-na-ab', 'PN')],
#  [('ki', 'O'), ('lu2-da-da', 'PN')],
#  [('3(asz)', 'O'), ('sukkal-ge-si', 'PN')],
#  [('lugal-he2-gal2', 'PN')],
#  [('u-bar', 'PN'), ('alan-da', 'O'), ('gen-na', 'O')],
#  [('3(barig)', 'O'),
#   ('1(ban2)', 'O'),
#   ('7(disz)', 'O'),
#   ('2/3(disz)', 'O'),
#   ('sila3', 'O'),
#   ('sze', 'O')],
#  [('nin9-da-mu-da-gal2', 'PN')],
#  [('da-x-ki', 'PN')],
#  [('ki', 'O'), ('hu-sa', 'PN')],
#  [('1(ban2)', 'O'), ('5(disz)', 'O'), ('{d}utu-ba-an-e11', 'PN')],
#  [('dumu', 'O'), ('lugal-du11-ga-li', 'PN')],
#  [('...', 'O'), ('ur-ki-...', 'PN')],
#  [('2(barig)', 'O'), ('3(ban2)', 'O'), ('{d}amar-{d}suen-zi-mu', 'PN')],
#  [('{d}bara2-{d}en-lil2-gar', 'PN')],
#  [('ga-ma-am3-tum', 'PN'), ('szu', 'O'), ('ba-ti', 'O')],
#  [('ki', 'O'), ('ki-lu2-KU{ki}', 'PN')],
#  [('kisal-gar', 'PN')],
#  [('2(disz)', 'O'),
#   ('en-gu2-tuku', 'PN'),
#   ('dumu', 'O'),
#   ('er3-ra-kak', 'PN')],
#  [('{d}nansze-tesz2-mu', 'PN'), ('nu-banda3-gu4', 'O')],
#  [('kiszib3', 'O'), ('a-tu', 'PN'), ('nu-banda3', 'O')],
#  [('ki', 'O'), ('an-ni-a', 'PN')],
#  [('pi-mi-ri2', 'PN'), ('i3-dab5', 'O')],
#  [('i7', 'O'), ('{d}szu-{d}suen-{d}en-lil2-la2', 'WN')],
#  [('2(barig)', 'O'), ('3(ban2)', 'O'), ('a-ra-ab-iri-na', 'PN')],
#  [('ki', 'O'), ('e2-siki-gi4-mu', 'PN')],
#  [('bala', 'O'), ('{d}nin-eb-gal', 'PN')],
#  [('1(u)', 'O'),
#   ('2(asz)', 'O'),
#   ('sze', 'O'),
#   ('gur', 'O'),
#   ('kiszib3', 'O'),
#   ('lu2-{d}tug2-an-ka', 'PN')],
#  [('ki', 'O'), ('ur-tug2', 'PN')],
#  [('dumu', 'O'), ('ba-ba-ti-bi', 'PN'), ('szusz3', 'O')],
#  [('ur-{d}gesz-za-mun-na', 'PN')],
#  [('4(disz)', 'O'), ('ur-kal-la-ka', 'PN')],
#  [('5(disz)', 'O'), ('sila3', 'O'), ('zi3', 'O'), ('kaskal', 'O')],
#  [('geme2-da-nin', 'PN')],
#  [('giri3', 'O'), ('he2-na-lah5', 'PN')],
#  [('ki', 'O'), ('er3-ra-dan', 'PN'), ('dumu', 'O'), ('er3-ra-dim2', 'PN')],
#  [('a-sza3', 'O'), ('da-{gesz}kiri6', 'FN')],
#  [('a-tu5-a', 'O'), ('{d}pa-bil-sag', 'DN')],
#  [('kiszib3', 'O'), ('a-li-um-mi', 'PN')],
#  [('mu-ti-lum', 'PN')],
#  [('1(disz)', 'O'), ('lugal-sa6', 'PN')],
#  [('nin-i3-mah', 'PN')],
#  [('sza3-gul-lum', 'PN'), ('szu', 'O'), ('ba-ti', 'O')],
#  [('kab2-ku5', 'O'), ('nibru{ki}-ka', 'GN'), ('tir-sze3', 'O')],
#  [('a2-si-du-du', 'PN'), ('ugula', 'O'), ('kas4', 'O')],
#  [('1(disz)', 'O'), ('a-i3-li2-su', 'PN')],
#  [('dumu', 'O'), ('ma-an-za-tum', 'PN')],
#  [('4(disz)', 'O'), ('gurusz', 'O'), ('ugula', 'O'), ('hal-i3-lum', 'PN')],
#  [('kiszib3', 'O'), ('bu3-u2-ku-um', 'PN')],
#  [('u3', 'O'), ('ab-ba-da-x', 'PN')],
#  [('mu', 'O'), ('ur-bi-x', 'PN')],
#  [('ki', 'O'),
#   ('en-um-mi-i3-li2', 'PN'),
#   ('dumu', 'O'),
#   ('en-...-x-ni', 'PN')],
#  [('i-di3-szum', 'PN')],
#  [('kin', 'O'),
#   ('szuku-ra', 'O'),
#   ('engar', 'O'),
#   ('nu-banda3-gu4', 'O'),
#   ('u3', 'O'),
#   ('sza3-sahar', 'O')],
#  [('ki', 'O'), ('a-ba-{d}en-lil2-ki', 'PN')],
#  [('1(ban2)', 'O'),
#   ('5(disz)', 'O'),
#   ('nu', 'O'),
#   ('lu2-sukud-ra2-ka', 'PN'),
#   ('x', 'O')],
#  [('ki', 'O'), ('i-din-i3-tug2', 'PN')],
#  [('ki', 'O'), ('{d}utu-ge6', 'PN')],
#  [('iti', 'O'), ('ezem-{d}li9-si4-ta', 'MN')],
#  [('2(asz)', 'O'), ('lu2-he2-gal2-ka', 'PN')],
#  [('...', 'O'), ('lugal-gir2-nun-ne2', 'PN')],
#  [('dumu', 'O'), ('|PU3.SZA|-er11', 'PN')],
#  [('giri3', 'O'), ('lugal-nu-du11-ga', 'PN'), ('sagi', 'O')],
#  [('giri3', 'O'), ('a2-lu5-lu5', 'PN'), ('dub-sar', 'O')],
#  [('ugu2', 'O'), ('...-lu-da', 'PN')],
#  [('kiszib3', 'O'), ('lugal-e2-mah-e', 'PN')],
#  [('iti', 'O'), ('1(u)', 'O'), ('2(disz)-sze3', 'O')],
#  [('2(u)', 'O'),
#   ('4(asz)', 'O'),
#   ('1(barig)', 'O'),
#   ('4(ban2)', 'O'),
#   ('5(disz)', 'O'),
#   ('sila3', 'O'),
#   ('gig', 'O'),
#   ('gur', 'O'),
#   ('lugal', 'O')],
#  [('ha-du-du', 'PN'), ('a-ta', 'O'), ('de6-a', 'O')],
#  [('kiszib3', 'O'), ('lu2-{d}nin-ga2', 'PN')],
#  [('su-ur3-ra', 'PN')],
#  [('1(disz)', 'O'), ('da-gi-szu', 'PN')],
#  [('3(disz)', 'O'), ('lu2-gar3-ne-ne{ki}', 'PN')],
#  [('1(asz)', 'O'),
#   ('2(disz)', 'O'),
#   ('gur', 'O'),
#   ('kiszib3', 'O'),
#   ('e2-lu2-bi-su', 'PN')],
#  [('kiszib3', 'O'), ('i3-li2-si-ga-am', 'PN')],
#  [('ur-ga-ki-du10', 'PN'), ('ra2-gaba', 'O'), ('maszkim', 'O')],
#  [('kab2-ku5', 'O'), ('nag-x-x', 'FN')],
#  [('1(u)', 'O'),
#   ('2(disz)', 'O'),
#   ('{gi}ha-an-ka-ze2', 'O'),
#   ('a2-bi', 'O'),
#   ('u4', 'O'),
#   ('6(disz)', 'O')],
#  [('kiszib3', 'O'), ('gu3-de2-nu-si', 'PN')],
#  [('ur-{d}nin-ur3', 'PN')],
#  [('kiszib3', 'O'), ('{d}nanna-da-a-nun', 'PN')],
#  [('3(asz)', 'O'), ('du', 'O'), ('szu-e2-a', 'PN')],
#  [('1(gesz2)', 'O'),
#   ('gur', 'O'),
#   ('kiszib3', 'O'),
#   ('ur-e2-sanga', 'PN'),
#   ('dumu', 'O'),
#   ('ur-esz2-nun', 'PN')],
#  [('dumu', 'O'), ('{d}szu-{d}suen-dingir-mu', 'PN')],
#  [('na-ba-sa2', 'PN'), ('szu', 'O'), ('ba-ti', 'O')],
#  [('2(asz)', 'O'),
#   ('4(barig)', 'O'),
#   ('3(ban2)', 'O'),
#   ('gur', 'O'),
#   ('ki', 'O'),
#   ('dingir-du11-ga', 'PN')],
#  [('u3', 'O'), ('a-sza3', 'O'), ('i7', 'O'), ('i7-ku3-ga', 'WN')],
#  [('ki', 'O'), ('be6-li2-dag-lugal', 'PN')],
#  [('giri3', 'O'), ('szu-{d}iszkur', 'PN')],
#  [('ki', 'O'), ('lu2-giri17-zal-ta', 'PN')],
#  [('dumu', 'O'), ('lu2-{d}nanna', 'PN'), ('x-x', 'O')],
#  [('mu', 'O'), ('gu-za', 'O'), ('ba-dim2', 'O')],
#  [('kiszib3', 'O'), ('ku4-ra-ni-sa6', 'PN')],
#  [('ur-{d}asznan-kam', 'PN')],
#  [('1(ban2)', 'O'), ('5(disz)', 'O'), ('a-du', 'PN')],
#  [('giri3', 'O'), ('i3-lum-gar3', 'PN')],
#  [('dumu', 'O'), ('da-da-a', 'PN')],
#  [('ki', 'O'), ('da-hi-sza-tal', 'PN')],
#  [('nin-nig2-tuku', 'PN'), ('lu2', 'O')],
#  [('ur-{d}en-lil2-la2-da', 'PN')],
#  [('gub-bar', 'PN'), ('nu-banda3-gu4', 'O')],
#  [('kiszib3', 'O'), ('ur-ki-ka', 'PN')],
#  [('2(disz)', 'O'), ('gu-la-sza3', 'PN')],
#  [('lu2-na-ba-an-dah', 'PN')],
#  [('musz-x', 'PN')],
#  [('2(asz)', 'O'), ('2(barig)', 'O'), ('...-kur-ra-igi-gal2', 'PN')],
#  [('4(barig)', 'O'), ('ki', 'O'), ('ma-at-dingir', 'PN'), ('...-ta', 'O')],
#  [('iti', 'O'),
#   ('diri', 'O'),
#   ('2(disz)-am3', 'O'),
#   ('sza3-ba', 'O'),
#   ('i3-gal2', 'O')],
#  [('1(bur3)', 'O'),
#   ('1(esze3)', 'O'),
#   ('2(iku)', 'O'),
#   ('GAN2', 'O'),
#   ('a-sza3', 'O'),
#   ('lisz-HA-me-x', 'FN')],
#  [('5(gesz2)', 'O'),
#   ('3(disz)', 'O'),
#   ('gurusz', 'O'),
#   ('u4', 'O'),
#   ('1(disz)-sze3', 'O')],
#  [('ki', 'O'), ('lu2-la-ga', 'PN')],
#  [('1(disz)', 'O'), ('sila3', 'O'), ('i3-gesz', 'O')],
#  [('mu', 'O'), ('ha-ar-szi{ki}', 'SN'), ('ba-hul', 'O')],
#  [('1(disz)', 'O'), ('udu', 'O'), ('niga', 'O'), ('{d}mar-tu', 'DN')],
#  [('nu-ur2-i3-li2', 'PN'), ('engar', 'O')],
#  [('szu-{d}isztaran', 'PN'), ('sipa', 'O'), ('szah2', 'O')],
#  [('...', 'O'), ('giri3-na-DI-DU-a', 'PN')],
#  [('1(u)', 'O'),
#   ('5(disz)', 'O'),
#   ('u8', 'O'),
#   ('1(u)', 'O'),
#   ('4(disz)', 'O'),
#   ('udu', 'O')],
#  [('lugal', 'O'), ('A-pi4-sal4{ki}', 'GN'), ('bara2-sig-ga{ki}-a', 'GN')],
#  [('2(asz)', 'O'), ('saga', 'O'), ('u2-sze3-he2-du', 'PN')],
#  [('ma-da', 'O'), ('gir2-su{ki}-ke4-ne', 'SN')],
#  [('bu-KA', 'PN')],
#  [('e2-duru5', 'O'), ('hirinx(KWU318)-na', 'GN')],
#  [('ku5-da-mu', 'PN')],
#  [('u3', 'O'), ('nig2-ka9', 'O'), ('didli', 'O')],
#  [('ugula', 'O'), ('sza-ad-ra-ad', 'PN')],
#  [('ki', 'O'), ('im-ma-TUL2-a', 'PN')],
#  [('en-hi-li-su3', 'PN'), ('i3-dab5', 'O')],
#  [('2(asz)', 'O'), ('ur-{d}en-dag-ga', 'PN')],
#  [('7(disz)', 'O'), ('sar', 'O'), ('kab2-ku5', 'O'), ('u2-du-mu-ul-li', 'FN')],
#  [('giri3', 'O'), ('ka5-a-x', 'PN')],
#  [('2(barig)', 'O'), ('3(ban2)', 'O'), ('ur-{gesz}gigir-na', 'PN')],
#  [('kiszib3', 'O'), ('ib-szi-KA', 'PN')],
#  [('3(asz)', 'O'), ('du', 'O'), ('e2-mu-be6-du10', 'PN')],
#  [('dur2-du10', 'PN')],
#  [('ki', 'O'),
#   ('ku3-{d}szara2-he2-gal2', 'PN'),
#   ('giri3', 'O'),
#   ('kur-ra-an-dul3', 'PN')],
#  [('i7', 'O'), ('i7-ka-ma-ri2{ki}', 'WN')],
#  [('2(barig)', 'O'), ('3(ban2)', 'O'), ('{d}szara2-ga2', 'PN')],
#  [('ki', 'O'), ('pu3-x-x', 'PN')],
#  [('dumu', 'O'), ('ur-e2-diri', 'PN')],
#  [('nig2-dab5', 'O'),
#   ('aga3', 'O'),
#   ('lugal', 'O'),
#   ('ki', 'O'),
#   ('dingir-KA-a', 'PN')],
#  [('dumu', 'O'), ('na-ga-lu5', 'PN'), ('ARAD2-zu', 'O')],
#  [('ka5-a', 'PN'), ('sukkal', 'O')],
#  [('ki', 'O'), ('u2-u2-mu', 'PN')],
#  [('i-ti-ga', 'PN'), ('szabra', 'O')],
#  [('kiszib3-bi', 'O'),
#   ('2(disz)', 'O'),
#   ('kiszib3', 'O'),
#   ('i3-lum-da-mi-nu-um', 'PN')],
#  [('dumu', 'O'), ('a-bi2-in-gaz', 'PN')],
#  [('a2-dingir-ziz2-da', 'PN'), ('i3-dab5', 'O')],
#  [('ki', 'O'), ('ur-{d}KA-x-ra-ta', 'PN')],
#  [('lugal-ug3-...', 'PN')],
#  [('nig2-dab5', 'O'), ('gesz-kin-ti', 'O'), ('ki', 'O'), ('giri3-gen', 'PN')],
#  [('iti', 'O'), ('a2-ki-ti', 'MN')],
#  [('ugu2', 'O'), ('dingir-ga2-bi2-du11', 'PN')],
#  [('dumu', 'O'), ('i-din-e2-a', 'PN')],
#  [('sze', 'O'),
#   ('gurx(|SZE.KIN|)-a', 'O'),
#   ('zar3', 'O'),
#   ('tab-ba', 'O'),
#   ('ki-su7', 'O'),
#   ('gub-ba', 'O'),
#   ('a-sza3', 'O'),
#   ('ka-u2', 'PN')],
#  [('giri3', 'O'), ('na-hi-mu-um', 'PN')],
#  [('ki', 'O'), ('lu2-...-x', 'PN'), ('engar-ta', 'O')],
#  [('lugal-gab2-la2', 'PN')],
#  [('2(barig)', 'O'), ('3(ban2)', 'O'), ('a2-ra-da-na', 'PN')],
#  [('{d}dumu-zi-ama-mu-ur', 'PN')],
#  [('i3-li2', 'PN')],
#  [('PA', 'O'), ('nin-a-gu2-zi', 'PN')],
#  [('{d}amar-{d}suen', 'RN')],
#  [('zar3', 'O'), ('tab-ba', 'O'), ('ki-su7', 'O'), ('gub-ba', 'O')],
#  [('gurum2', 'O'), ('u4', 'O'), ('1(u)', 'O'), ('6(disz)-kam', 'O')],
#  [('mu', 'O'), ('us2-sa', 'O'), ('za-tum{ki}', 'GN'), ('ba-hul', 'O')],
#  [('1(asz)', 'O'),
#   ('ba-ta-x', 'PN'),
#   ('dumu', 'O'),
#   ('GIN2-du6-da-kusz2', 'PN')],
#  [('lu2-sa6-x-UR', 'PN'), ('e2-gibil4-le', 'GN')],
#  [('ur-ge6-par4-bar', 'PN'), ('ka-us2-sa2', 'O')],
#  [('geme2-zu-ga2', 'PN')],
#  [('1(asz)', 'O'), ('1(barig)', 'O'), ('a-ba-ki-ni', 'PN')],
#  [('kiszib3', 'O'), ('i-bi2-lu-lu', 'PN')],
#  [('1(disz)', 'O'), ('nin-dumu-gi7', 'PN')],
#  [('giri3', 'O'), ('gal-sze', 'PN'), ('sukkal', 'O')],
#  [('mu', 'O'), ('u3-da-ga', 'GN'), ('ba-hul', 'O')],
#  [('1(disz)', 'O'), ('sila4', 'O'), ('niga', 'O')],
#  [('1(disz)', 'O'), ('lu2-la2-ne', 'PN'), ('enku', 'O')],
#  [('ki', 'O'), ('ba-ki', 'PN')],
#  [('ki', 'O'), ('{d}utu-i3-di3', 'PN'), ('ba-zi', 'O')],
#  [('giri3', 'O'), ('ku3-...', 'PN')],
#  [('mu', 'O'),
#   ('en', 'O'),
#   ('{d}nisaba', 'DN'),
#   ('masz2-e', 'O'),
#   ('i3-pa3', 'O')],
#  [('lugal-kiri6', 'PN')],
#  [('1(gesz2)', 'O')],
#  [('2(asz)', 'O'), ('2(barig)', 'O'), ('{d}szara2-ba-zi-ge', 'PN')],
#  [('a-bi-da-ba', 'PN'),
#   ('ensi2', 'O'),
#   ('gir2-su{ki}', 'SN'),
#   ('i3-dab5', 'O')],
#  [('kiszib3', 'O'), ('{d}ba-ba6-da-lu2', 'PN')],
#  [('1(disz)', 'O'), ('gukkal', 'O'), ('niga', 'O')],
#  [('PI-PI-ti', 'PN'), ('kuruszda', 'O')],
#  [('{d}lamma-lu2-sa6', 'PN'), ('maszkim', 'O')],
#  [('dumu', 'O'), ('a-da-gal-szum', 'PN')],
#  [('mu-kux(DU)', 'O'), ('{d}lugal-urub{ki}', 'DN'), ('|KI.AN|{ki}', 'SN')],
#  [('e2', 'O'), ('HAR-sa6-mu', 'PN'), ('in-na-ak-a', 'O')],
#  [('ki', 'O'), ('ku3-x-ga', 'PN')],
#  [('a-sza3', 'O'), ('x-gesz-gi-tur-x', 'FN')],
#  [('2(barig)', 'O'), ('3(ban2)', 'O'), ('er3-ra-ur-sag', 'PN')],
#  [('dumu', 'O'), ('nin-nig2-zu-zu', 'PN')],
#  [('ki', 'O'), ('a-si-{d}szakkan2', 'PN')],
#  [('nin-ab-ba-na', 'PN'), ('lu2', 'O'), ('kas4', 'O')],
#  [('1(asz)', 'O'), ('sze', 'O'), ('gur', 'O'), ('lugal', 'O')],
#  [('e-lum-ma', 'PN'), ('aszgab', 'O')],
#  [('giri3', 'O'), ('hal-hal-la', 'PN')],
#  [('5(disz)', 'O'),
#   ('gin2', 'O'),
#   ('ku3', 'O'),
#   ('giri3', 'O'),
#   ('lu2-ti-i3-zu', 'PN')],
#  [('3(u)', 'O'), ('kir11', 'O'), ('szimaszgi', 'O')],
#  [('ki', 'O'), ('ur-x-za-za-lum', 'PN')],
#  [('kab-lu5-li2-um', 'PN')],
#  [('ki', 'O'), ('wa-szi-nun-na', 'PN')],
#  [('ugu2', 'O'), ('ur2-mah', 'PN'), ('ba-a-gar', 'O')],
#  [('1(disz)', 'O'),
#   ('ur-a-KU-da', 'PN'),
#   ('dumu', 'O'),
#   ('ur-a-lu3-za', 'PN')],
#  [('ki', 'O'), ('nin-e2-gal-le2-si', 'PN')],
#  [('ki-su7', 'O'), ('a-ubi', 'FN'), ('gub-ba', 'O')],
#  [('dumu', 'O'), ('dingir-luh', 'PN')],
#  [('a-ni-mu', 'PN')],
#  [('kab2-ku5', 'O'), ('gesztin-na-gu-la', 'FN')],
#  [('mu-ni-szu-za-gin3', 'PN')],
#  [('giri3', 'O'), ('kar-ra', 'PN'), ('u3', 'O'), ('bar-bar-li2-a', 'PN')],
#  [('4(u)', 'O'), ('kiszib3', 'O'), ('ri-zu-un-hu-in', 'PN')],
#  [('3(asz)', 'O'), ('a2-da', 'PN'), ('min-kam', 'O')],
#  [('i-bi2-{d}iszkur', 'PN')],
#  [('giri3', 'O'), ('nin-ge6-par4', 'PN')],
#  [('lu2-ba-a-ti', 'PN')],
#  [('u3', 'O'), ('a-sza3', 'O'), ('gi4-uru4', 'FN')],
#  [('1(disz)', 'O'),
#   ('tug2', 'O'),
#   ('geme2-sa6-ga', 'PN'),
#   ('giri17-dab5', 'O')],
#  [('3(disz)', 'O'), ('ur-da-zi-da', 'PN')],
#  [('kun-zi-da', 'O'), ('i7', 'O'), ('i7-ur-sag10', 'WN'), ('gub-ba', 'O')],
#  [('dumu', 'O'), ('lugal-sig', 'PN')],
#  [('kun-zi-da', 'O'),
#   ('i7', 'O'),
#   ('i7-{d}nin-hur-sag', 'WN'),
#   ('gub-ba', 'O')],
#  [('ul4-ul4-e-e2-babbar2', 'FN')],
#  [('8(disz)', 'O'),
#   ('sila3', 'O'),
#   ('2(disz)', 'O'),
#   ('gin2', 'O'),
#   ('ama-sza3-ga-du11-ga', 'PN')],
#  [('kiszib3', 'O'), ('e2-zi-da', 'PN')],
#  [('ki', 'O'), ('a-da-gal-di', 'PN')],
#  [('2(barig)', 'O'), ('3(ban2)', 'O'), ('ur-sa', 'PN')],
#  [('giri3', 'O'), ('hu-ru-mu', 'PN'), ('dub-sar', 'O')],
#  [('mu', 'O'),
#   ('en', 'O'),
#   ('{d}inanna-ka', 'DN'),
#   ('kar-zi-da', 'SN'),
#   ('ba-hun', 'O')],
#  [('a-sza3', 'O'), ('{d}na-ru2-a', 'O')],
#  [('kiszib3', 'O'), ('szu-im-mi-NI', 'PN')],
#  [('ur-{d}lugal-x-x', 'PN')],
#  [('kiszib3', 'O'), ('...-a2', 'PN')],
#  [('i7', 'O'), ('{d}nanna-e2-tur3', 'DN')],
#  [('kab2-ku5', 'O'), ('kam-sal4-la', 'FN')],
#  [('1(asz)', 'O'), ('1(barig)', 'O'), ('gur', 'O')],
#  [('2(barig)', 'O'), ('i-szar-a-hi', 'PN')],
#  [('lugal-ib2-ta-e3', 'PN')],
#  [('3(disz)', 'O'), ('ra-ni', 'PN')],
#  [('7(disz)', 'O'),
#   ('sar', 'O'),
#   ('kab2-ku5', 'O'),
#   ('dal-ba-ba-{d}na-ru2-a', 'FN')],
#  [('in-ti', 'PN')],
#  [('mu', 'O'), ('pu3-u2-du', 'PN'), ('ba-hun', 'O')],
#  [('7(disz)', 'O'),
#   ('sar', 'O'),
#   ('kab2-ku5', 'O'),
#   ('{gesz}szinig-mu2-am3', 'FN')],
#  [('kiszib3', 'O'), ('da-a-gi4', 'PN'), ('ugula', 'O'), ('ma2-lah5', 'O')],
#  [('4(ban2)', 'O'),
#   ('la2', 'O'),
#   ('1(disz)', 'O'),
#   ('sila3', 'O'),
#   ('{d}szara2-ma-DU', 'PN')],
#  [('dam-lugal', 'PN'), ('i3-dab5', 'O')],
#  [('6(asz)', 'O'), ('gur', 'O'), ('kiszib3', 'O'), ('ku-lu-lu', 'PN')],
#  [('2(barig)', 'O'), ('3(ban2)', 'O'), ('a-hu', 'PN')],
#  [('palil', 'PN')],
#  [('szuku', 'O'),
#   ('diri', 'O'),
#   ('i7', 'O'),
#   ('i7-{d}szul-gi-pirig-a2-igi-nim-ma', 'WN'),
#   ('4(ban2)', 'O'),
#   ('3(disz)', 'O'),
#   ('1/3(disz)-ta', 'O')],
#  [('8(disz)', 'O'),
#   ('sar', 'O'),
#   ('kin', 'O'),
#   ('u2', 'O'),
#   ('sahar-ba', 'O'),
#   ('kab2-ku5', 'O'),
#   ('ur-ma-ma', 'FN')],
#  [('ur-ku3-nun-na-ka-bi', 'PN')],
#  [('u3', 'O'), ('a-sza3', 'O'), ('gu2-banda3{da}', 'FN')],
#  [('ki', 'O'), ('ensi2-ta', 'O')],
#  [('kiszib3', 'O'), ('nin-he2-gal2-a', 'PN')],
#  [('...', 'O'), ('PA', 'O'), ('ki-in-{d}x-gi', 'PN')],
#  [('3(disz)', 'O'), ('nin-ki-tusz', 'PN')],
#  [('dumu', 'O'), ('al-la-la', 'PN')],
#  [('ki', 'O'), ('lugal-ba-ab-e3', 'PN')],
#  [('a-ah-kal-la', 'PN')],
#  [('lu2-gabar', 'PN'), ('dub-sar', 'O'), ('i3', 'O')],
#  [('dingir-tur-tur', 'PN')],
#  [('1(disz)', 'O'),
#   ('udu', 'O'),
#   ('du-u2-du-ni', 'PN'),
#   ('x', 'O'),
#   ('x', 'O')],
#  [('mu', 'O'), ('kiszib3', 'O'), ('{d}nin-e2-gal-la-ka', 'PN')],
#  [('kiszib3', 'O'), ('a-abzu-si', 'PN')],
#  [('kab2-ku5', 'O'), ('gu2-edin-na-ka', 'GN'), ('tir-sze3', 'O')],
#  [('2(disz)', 'O'), ('e2-lu2-lagar', 'PN')],
#  [('n', 'O'),
#   ('n(barig)', 'O'),
#   ('1(ban2)', 'O'),
#   ('gur', 'O'),
#   ('ki', 'O'),
#   ('a-ab-ba-mu', 'PN')],
#  [('ki', 'O'), ('a-hu-wa(IGI)-qar', 'PN')],
#  [('ki', 'O'), ('lu2-sa6-i3-zu-ta', 'PN')],
#  [('3(disz)', 'O'), ('qar-ra-di3-li2', 'PN')],
#  [('uru-du10', 'PN'), ('szabra(AL)', 'O')],
#  [('...', 'O'), ('ma-ga-ru-um', 'PN')],
#  [('szu-gid2', 'O'),
#   ('ki', 'O'),
#   ('ba-luh-dingir', 'PN'),
#   ('ensi2', 'O'),
#   ('iri-sa12-rig7{ki}-ta', 'SN')],
#  [('lugal-x-da', 'PN'), ('nu-banda3-gu4', 'O')],
#  [('lugal-kar', 'PN'), ('a-zi-ga-sze3', 'O'), ('gen-na', 'O')],
#  [('5(u)', 'O'),
#   ('3(barig)', 'O'),
#   ('3(ban2)', 'O'),
#   ('4(disz)', 'O'),
#   ('sila3', 'O'),
#   ('sze', 'O'),
#   ('gur', 'O')],
#  [('ur-gi-diri-ku3-ga', 'PN')],
#  [('{d}suen-nam-ri', 'PN')],
#  [('kab2-ku5', 'O'), ('iszib', 'FN')],
#  [('{d}nam-ma-ni', 'DN')],
#  [('a-sza3', 'O'), ('za3-mu-ba-ni-us2', 'FN')],
#  [('dumu', 'O'), ('{d}nin-tin-ug5-ga', 'PN')],
#  [('1(u)', 'O'), ('5(asz)', 'O'), ('giri3', 'O'), ('bur-ma-am3', 'PN')],
#  [('ki', 'O'), ('ur-mes', 'PN')],
#  [('ki', 'O'), ('lu2-an-na', 'PN')],
#  [('la2-ia3', 'O'),
#   ('2(asz)', 'O'),
#   ('4(barig)', 'O'),
#   ('5(ban2)', 'O'),
#   ('8(disz)', 'O'),
#   ('2/3(disz)', 'O'),
#   ('sila3', 'O'),
#   ('5(disz)', 'O'),
#   ('gin2', 'O'),
#   ('sze', 'O'),
#   ('gur', 'O')],
#  [('da-gi4-mu', 'PN'), ('szabra', 'O')],
#  [('geme2', 'O'), ('KA-x-a', 'PN'), ('dumu', 'O'), ('|PU3.SZA|-ma-ba', 'PN')],
#  [('mu', 'O'),
#   ('us2-sa', 'O'),
#   ('ma2', 'O'),
#   ('{d}ma-mi', 'DN'),
#   ('ba-ab-du8', 'O')],
#  [('a2-{d}nanna', 'PN'), ('maszkim', 'O')],
#  [('lugal-sag-aga', 'PN'), ('...{ki}', 'SN')],
#  [('szakkan-ni', 'DN')],
#  [('dumu', 'O'), ('a-sza3-A-KU-e-ga', 'PN')],
#  [('ma-ma-hir-ke4-ne', 'PN'), ('kuruszda', 'O')],
#  [('i3-bi2-za-asz', 'O'), ('e2-gal-e', 'O'), ('ma-ab-szum2-ma', 'O')],
#  [('3(disz)', 'O'), ('lugal-gur', 'PN')],
#  [('5(disz)', 'O'),
#   ('sila3', 'O'),
#   ('2(disz)', 'O'),
#   ('gin2', 'O'),
#   ('inim-{d}ba-ba6-zi', 'PN'),
#   ('KA-gu', 'PN'),
#   ('ra2-gaba-da', 'O'),
#   ('du', 'O')],
#  [('a-gir2-gal', 'PN'), ('kuruszda', 'O')],
#  [('ki', 'O'), ('lugal-{d}anzu', 'PN')],
#  [('1(disz)', 'O'), ('a2-ba-la-du', 'PN')],
#  [('kiszib3', 'O'), ('gu-u2-gu-a', 'PN')],
#  [('2(asz)', 'O'),
#   ('1(barig)', 'O'),
#   ('3(ban2)', 'O'),
#   ('sze', 'O'),
#   ('gur', 'O'),
#   ('ki', 'O'),
#   ('lu2-ba-szim-e{ki}', 'PN')],
#  [('ki', 'O'), ('a2-gi4-il2-la', 'PN')],
#  [('apin-la2', 'O'), ('ta2-hi-isz-a-tal', 'PN')],
#  [('1(gesz2)', 'O'), ('3(u)', 'O'), ('la2', 'O'), ('x', 'O'), ('masz2', 'O')],
#  [('dumu', 'O'), ('nin-tum-al6', 'PN')],
#  [('giri3', 'O'), ('geme2-dumu-ni', 'PN')],
#  [('4(disz)', 'O'), ('gurusz', 'O'), ('ugula', 'O'), ('ur-dingir-gal', 'PN')],
#  [('lugal-lal3', 'FN'), ('gub-ba', 'O')],
#  [('{d}utu-gu2-gal', 'PN'), ('nu-banda3-gu4', 'O')],
#  [('mu', 'O'), ('us2-sa', 'O'), ('u2-lum{ki}', 'GN'), ('ba-hul', 'O')],
#  [('lugal', 'O'), ('kisz{ki}-ir', 'GN'), ('ra-szi{ki}', 'GN')],
#  [('2(disz)', 'O'), ('en-ki-nu2', 'PN')],
#  [('3(asz)', 'O'), ('sza3-ge-pa3-ra2', 'PN')],
#  [('a-sza3', 'O'), ('gaba-{d}nansze-gar', 'FN')],
#  [('u2-na-ab-sze-en', 'PN'), ('umma{ki}', 'SN')],
#  [('ki', 'O'),
#   ('lugal-hi-li', 'PN'),
#   ('dumu', 'O'),
#   ('lugal-szu-nir-re', 'PN')],
#  [('3(iku)', 'O'), ('GAN2', 'O'), ('4(barig)', 'O'), ('lu2-{d}li9-si4', 'PN')],
#  [('ki', 'O'), ('a-gu-za', 'PN')],
#  [('dumu', 'O'), ('ur-x-x-x-x', 'PN'), ('szusz3', 'O')],
#  [('mu', 'O'),
#   ('{d}szu-{d}suen', 'RN'),
#   ('lugal-e', 'O'),
#   ('na-ru2-a-mah', 'O'),
#   ('uszum:gal', 'DN'),
#   ('{d}nin-mug-ga', 'DN')],
#  [('1(disz)', 'O'), ('sila4', 'O'), ('hu-bu-ul', 'PN'), ('u2-x', 'O')],
#  [('kab2-ku5', 'O'), ('gu4-mul', 'FN'), ('gub-ba', 'O')],
#  [('giri3-{d}gu-la', 'PN'), ('szu', 'O'), ('ba-ti', 'O')],
#  [('en-ne2', 'PN')],
#  [('1(u)', 'O'),
#   ('1(disz)', 'O'),
#   ('gurusz', 'O'),
#   ('ugula', 'O'),
#   ('ur-gu2-zi-la', 'PN')],
#  [('1(u)', 'O'),
#   ('8(disz)', 'O'),
#   ('sze', 'O'),
#   ('ku3', 'O'),
#   ('szuku', 'O'),
#   ('nin-a-tu5', 'PN')],
#  [('en-zi-kalam-ma', 'PN')],
#  [('3(disz)', 'O'), ('ubur3-imin', 'PN')],
#  [('a-sza3', 'O'), ('du6-lugal-u3-a', 'FN')],
#  [('dumu', 'O'), ('ha-la-ziz2-ka', 'PN'), ('x-x', 'O')],
#  [('kiszib3', 'O'), ('nin-bar-bi2', 'PN'), ('nu-banda3-gu4', 'O')],
#  [('sza-lim-dingir', 'PN')],
#  [('{d}szara2-he2-gal2', 'PN')],
#  [('4(u)', 'O'), ('pu2-si4-mu', 'FN')],
#  [('kab2-ku5', 'O'), ('lu2-{d}x', 'FN')],
#  [('1(ban2)', 'O'), ('5(disz)', 'O'), ('a-bil-{d}suen', 'PN')],
#  [('1(disz)', 'O'),
#   ('gu4', 'O'),
#   ('zuh-a', 'O'),
#   ('ki', 'PN'),
#   ('dub-sar', 'O'),
#   ('szu', 'O'),
#   ('ba-ra', 'O')],
#  [('...', 'O'), ('mu-ni-sze3', 'O')],
#  [('tur-da-ki-num2', 'PN')],
#  [('2(barig)', 'O'), ('3(ban2)', 'O'), ('u6-unu-tug2', 'PN')],
#  [('pirig-me3', 'PN')],
#  [('1(u)', 'O'),
#   ('2(disz)', 'O'),
#   ('2/3(disz)', 'O'),
#   ('sar', 'O'),
#   ('kab2-ku5', 'O'),
#   ('du6-imin', 'FN')],
#  [('ki', 'O'), ('gu-sze', 'PN'), ('nin-ta', 'O')],
#  [('ki', 'O'), ('ur-...-da', 'PN')],
#  [('mu', 'O'), ('us2-sa', 'O'), ('hu-hu-nu-ru{ki}', 'GN'), ('ba-hul', 'O')],
#  [('2(asz)', 'O'), ('saga', 'O'), ('lugal-{d}nin-gir2-su', 'PN')],
#  [('1(disz)', 'O'), ('masz-da3', 'O'), ('ur-la-lu', 'PN')],
#  [('a-sza3', 'O'),
#   ('durux(U3)', 'FN'),
#   ('i7', 'O'),
#   ('nun-ta', 'O'),
#   ('ka', 'O'),
#   ('i7-{d}amar-{d}suen', 'WN')],
#  [('e-ta-e3-a', 'PN')],
#  [('{d}nin-{d}szu-nir', 'PN')],
#  [('{d}szul-gi-zi-kalam-ma', 'PN')],
#  [('{d}nin-an-sze3-la2-a', 'PN')],
#  [('mu', 'O'), ('szu2-a', 'PN'), ('ba-hun', 'O')],
#  [('lugal-nam-mes', 'PN')],
#  [('a-sza3', 'O'), ('a-suhur-gu-la', 'FN')],
#  [('ugu2', 'O'),
#   ('ama-szu-{d}x-x', 'PN'),
#   ('dumu', 'O'),
#   ('AN-ma-a-a', 'PN'),
#   ('ga2-ga2-dam', 'O')],
#  [('{uruda}ur2-zi-ir', 'O'), ('ku3-babbar', 'O')],
#  [('lugal-si-sa2', 'PN')],
#  [('1/3(disz)', 'O'),
#   ('gin2', 'O'),
#   ('7(disz)', 'O'),
#   ('1/2(disz)', 'O'),
#   ('sze', 'O'),
#   ('apin-la2', 'O'),
#   ('esz18-dar-x', 'PN'),
#   ('szuku', 'O'),
#   ('bi-er3', 'PN'),
#   ('u3', 'O'),
#   ('ge6-par4-e-he2-du7', 'PN'),
#   ('szu-i', 'O')],
#  [('nin-szesz-szesz', 'PN')],
#  [('szesz-kal-la', 'PN')],
#  [('mu', 'O'), ('kiszib3', 'GN'), ('ba-hul', 'O')],
#  [('ki', 'O'), ('KU-a', 'PN')],
#  [('{d}ba-ba6-da', 'DN')],
#  [('kiszib3', 'O'), ('ki-lugal-mu', 'PN')],
#  [('ki', 'O'), ('lu2-{d}inanna-ta', 'PN')],
#  [('lugal-lam', 'PN')],
#  [('...', 'O'),
#   ('3(ban2)', 'O'),
#   ('5(disz)', 'O'),
#   ('sila3', 'O'),
#   ('x-nita2', 'PN')],
#  [('mu', 'O'),
#   ('{d}szu-{d}suen', 'RN'),
#   ('lugal-e', 'O'),
#   ('na-ru2-a', 'O'),
#   ('dingir-mah', 'DN'),
#   ('x-x-kal-la', 'DN'),
#   ('mu-ne-du3', 'O')],
#  [('...', 'O'), ('4(ban2)', 'O'), ('sze-ba', 'O'), ('i3-lu5-lu5-a', 'PN')],
#  [('3(asz)', 'O'), ('{d}utu-ga-zi', 'PN')],
#  [('ur-{d}szul-pa-e3(DU)', 'PN'), ('i3-dab5', 'O')],
#  [('2(disz)', 'O'), ('nin-en-sa6', 'PN')],
#  [('ama-ki-lu5-la', 'PN'), ('maszkim', 'O')],
#  [('mi-ni', 'PN'), ('dumu', 'O'), ('im-a-ni', 'PN')],
#  [('u3', 'O'), ('a-sza3', 'O'), ('HAR-me-za-NE', 'FN')],
#  [('1(u)', 'O'),
#   ('ud5', 'O'),
#   ('giri3', 'O'),
#   ('lu2(LUGAL)-sa6-i3-zu', 'PN'),
#   ('szusz3', 'O')],
#  [('ugula', 'O'), ('|PU3.SZA|-{d}za-ga2-ri2', 'PN')],
#  [('iti', 'O'), ('ezem-an-na', 'MN')],
#  [('{d}isz-ha', 'DN')],
#  [('lugal-na4', 'PN')],
#  [('dumu', 'O'), ('a-tal', 'PN')],
#  [('1(asz)', 'O'),
#   ('1(barig)', 'O'),
#   ('7(disz)', 'O'),
#   ('sila3', 'O'),
#   ('gesz-i3', 'O'),
#   ('gur', 'O')],
#  [('ki', 'O'), ('KA-...-ka', 'PN')],
#  [('1(gesz2)', 'O'),
#   ('1(u)', 'O'),
#   ('1(asz)', 'O'),
#   ('3(ban2)', 'O'),
#   ('8(disz)', 'O'),
#   ('1/2(disz)', 'O'),
#   ('sila3', 'O'),
#   ('zi3', 'O'),
#   ('gur', 'O')],
#  [('nig2-dab5', 'O'), ('gesz-kin-ti', 'O'), ('ki', 'O'), ('x-...-ne', 'PN')],
#  [('1(disz)', 'O'), ('dug', 'O'), ('dida', 'O'), ('1(ban2)', 'O')],
#  [('{d}nin-ne2', 'PN')],
#  [('1(bur3)', 'O'),
#   ('GAN2', 'O'),
#   ('1(barig)', 'O'),
#   ('lu2-kal-la', 'PN'),
#   ('ma2-lah5', 'O')],
#  [('la-ma-mu', 'PN')],
#  [('siskur2', 'O'), ('{d}lugal-uru11{ki}-a-ma-nu', 'DN')],
#  [('ugula', 'O'), ('e2-du10-us2', 'PN')],
#  [('2(disz)', 'O'), ('nin-mu-ma-az', 'PN')],
#  [('{d}suen-{d}szara2-ki-ag2', 'FN'), ('gub-ba', 'O')],
#  [('1(disz)', 'O'), ('udu', 'O'), ('niga', 'O'), ('...-a-mu', 'DN')],
#  [('ki', 'O'), ('ab-ba-na', 'PN')],
#  [('ki', 'O'), ('a-da-da', 'PN')],
#  [('ki', 'O'), ('geme2-lal3', 'PN')],
#  [('{d}nanna-ku3-zu', 'PN'), ('gaba-ta', 'O')],
#  [('dumu', 'O'), ('{d}USZ-esz', 'PN'), ('szusz3', 'O')],
#  [('mu', 'O'), ('dam', 'O'), ('lu2-mu-x', 'PN')],
#  [('ki', 'O'), ('ku-ri-ru', 'PN')],
#  [('sag-du7', 'PN'), ('sukkal', 'O'), ('gaba-asz', 'O')],
#  [('ma-nu-um-ki-{d}szul-gi', 'PN')],
#  [('iti', 'O'),
#   ('ezem-an-na', 'MN'),
#   ('u4', 'O'),
#   ('2(u)', 'O'),
#   ('ba-zal', 'O')],
#  [('dumu', 'O'), ('nin-lu2-ni-nu-sza-ge', 'PN')],
#  [('ba-an-na-zi', 'O')],
#  [('giri3', 'O'),
#   ('{d}ba-ba6-eb2-gu-ul', 'PN'),
#   ('sukkal', 'O'),
#   ('lugal', 'O')],
#  [('1/2(disz)', 'O'), ('kur-ta-mu-gi4', 'PN')],
#  [('me-dingir-ra', 'PN'), ('ugula', 'O'), ('kas4', 'O')],
#  [('giri3', 'O'), ('...-dalla-mu', 'PN')],
#  [('ki', 'O'), ('a-bu-bu', 'PN')],
#  [('1(disz)', 'O'),
#   ('e2-abzu-si{ki}', 'PN'),
#   ('dumu', 'O'),
#   ('e2-an-ta-mu-ba', 'PN')],
#  [('dumu', 'O'), ('nin-si-ga', 'PN')],
#  [('a-ha-tum', 'PN')],
#  [('1(disz)', 'O'), ('sila4', 'O'), ('nin-i3-di3', 'PN'), ('sukkal', 'O')],
#  [('kiszib3', 'O'), ('lu2-igi-sa6', 'PN')],
#  [('5(disz)', 'O'), ('gukkal', 'O'), ('diri-tum', 'PN')],
#  [('ki', 'O'), ('...-HI', 'PN')],
#  [('a-sza3', 'O'), ('a-gur8', 'FN')],
#  [('1(asz)', 'O'), ('gur', 'O'), ('kiszib3', 'O'), ('a-en-e-a-na-gu7', 'PN')],
#  [('1(gesz2)', 'O'),
#   ('2(u)', 'O'),
#   ('udu', 'O'),
#   ('1(disz)', 'O'),
#   ('1/2(disz)', 'O'),
#   ('sila3', 'O'),
#   ('1(gesz2)', 'O'),
#   ('5(disz)', 'O'),
#   ('udu', 'O'),
#   ('1(disz)', 'O'),
#   ('sila3', 'O'),
#   ('sze-bi', 'O'),
#   ('3(barig)', 'O'),
#   ('5(disz)', 'O'),
#   ('sila3', 'O'),
#   ('inim-ma-an', 'PN')],
#  [('unu{ki}-ta', 'SN'), ('ki', 'O'), ('{d}nin-im-DU-ka', 'PN')],
#  [('mu', 'O'),
#   ('ma2-dara3-abzu', 'ON'),
#   ('{d}da-mu', 'DN'),
#   ('ba-ab-du8', 'O')],
#  [('da-ga-za-na-ar', 'PN'), ('szu', 'O'), ('ba-ti', 'O')],
#  [('nin-KA', 'DN'), ('{d}nin-gesz-zi-da', 'TN')],
#  [('giri3', 'O'), ('lu2-uru11{ki}', 'PN'), ('sukkal', 'O')],
#  [('du11-ga-li', 'PN')],
#  [('ugula', 'O'), ('i-la-la', 'PN')],
#  [('mu', 'O'), ('us2-sa', 'O'), ('en-dim2-gig{ki}', 'GN'), ('ba-hul', 'O')],
#  [('{d}nin-gesz-te-te', 'DN')],
#  [('ur-{d}x{ki}', 'PN')],
#  [('ki', 'O'), ('nim', 'PN')],
#  [('en-nun-e-ki-{d}amar-{d}suen', 'PN')],
#  [('1(disz)', 'O'), ('amar-x-zi-da', 'PN')],
#  [('1(disz)', 'O'), ('udu', 'O'), ('...', 'O'), ('e2', 'O'), ('{d}...', 'DN')],
#  [('ugu2', 'O'), ('igi-husz-da', 'PN'), ('ba-a-gar', 'O')],
#  [('PA', 'O'), ('ur-hu-ma2', 'PN')],
#  [('a-sza3', 'O'), ('igi-e2-duru5-{d}pi-li-ha', 'FN')],
#  [('mu', 'O'), ('us2-sa', 'O'), ('gu-uh2-zi-ga{ki}', 'GN'), ('ba-hul', 'O')],
#  [('kiszib3', 'O'), ('lal3-dug', 'PN')],
#  [('giri3', 'O'),
#   ('sze-id-pa2-tal', 'PN'),
#   ('lu2', 'O'),
#   ('kin-gi4-a', 'O'),
#   ('lugal', 'O')],
#  [('giri3', 'O'), ('ur-i', 'PN'), ('dumu', 'O'), ('ur-kalam-ka', 'PN')],
#  [('mu', 'O'), ('sza3-asz-ru-um{ki}', 'SN'), ('ba-hul', 'O')],
#  [('u3', 'O'), ('al-ba-an(HAL)-ni-du11', 'PN')],
#  [('lu2', 'O'), ('nin-bad3', 'PN'), ('sukkal', 'O')],
#  [('ugula', 'O'), ('ir-{d}...', 'PN')],
#  [('1(asz)', 'O'), ('2(ban2)', 'O'), ('lu2-{d}szara2', 'PN')],
#  [('dumu', 'O'), ('lugal-tug2-mah', 'PN')],
#  [('kiszib3', 'O'), ('PI-ti-na-ri', 'PN'), ('sukkal', 'O')],
#  [('mu', 'O'), ('us2-sa', 'O'), ('eridu{ki}-ga', 'GN'), ('ba-hul', 'O')],
#  [('{d}isz-bi-er3-ra-na-ra-am-{d}suen', 'PN'),
#   ('sukkal', 'O'),
#   ('diri', 'O'),
#   ('dam-gar3', 'O'),
#   ('sa-gaz-ak-sze3', 'SN'),
#   ('gen-na', 'O')],
#  [('1(u)', 'O'),
#   ('ud5', 'O'),
#   ('giri3', 'O'),
#   ('lu2-mu-...', 'PN'),
#   ('szusz3', 'O')],
#  [('ANSZE', 'PN'), ('dumu', 'O'), ('a-na-la2', 'PN')],
#  [('4(disz)', 'O'), ('sila3', 'O'), ('igi-in-DU', 'PN')],
#  [('gurum2', 'O'), ('u4', 'O'), ('1(u)', 'O'), ('7(disz)-kam', 'O')],
#  [('sza-ad-nu-x', 'PN')],
#  [('1(u)', 'O'), ('ma-na', 'O'), ('siki', 'O')],
#  [('1(u)', 'O'),
#   ('9(disz)', 'O'),
#   ('sar', 'O'),
#   ('6(disz)', 'O'),
#   ('gin2', 'O'),
#   ('kab2-ku5', 'O'),
#   ('a-u2-bala-gu-la', 'FN')],
#  [('1(asz)', 'O'), ('nig2-gur11-x-ma-x', 'PN')],
#  [('2(gesz2)', 'O'), ('gur', 'O'), ('a-sza3', 'O'), ('ugur2-tur', 'FN')],
#  [('ugula', 'O'), ('nin-szud3', 'PN')],
#  [('1(disz)', 'O'), ('lugal-ma2-gur8-re', 'PN')],
#  [('u2-du-{d}nin-a-ra-li', 'FN')],
#  [('2(asz)', 'O'), ('saga', 'O'), ('munu6', 'PN')],
#  [('ki', 'O'), ('lungax(|BI.DAR|)', 'PN')],
#  [('lu2-{d}szul-sza3-ga-na', 'PN'), ('szabra', 'O')],
#  [('1(asz)', 'O'), ('saga', 'O'), ('szar2-ur3', 'PN')],
#  [('szar2-ra-ab-du-ne', 'PN')],
#  [('dingir-dan', 'PN'), ('ab-ba-iri', 'O')],
#  [('{d}dumu-zi-abzu-ta-e3-a', 'PN'), ('ra2-gaba', 'O'), ('maszkim', 'O')],
#  [('ki-su7', 'O'), ('ka-ki-du', 'FN'), ('gub-ba', 'O')],
#  [('ki', 'O'), ('lugal-sukkal-bi', 'PN')],
#  [('ARAD2-ba', 'PN'), ('i3-dab5', 'O')],
#  [('dumu', 'O'), ('ur-gu-asz2', 'PN'), ('szusz3', 'O')],
#  [('lu2-du10-ga', 'PN'), ('dumu', 'O'), ('he2-ma-du', 'PN')],
#  [('ki', 'O'), ('igi-bar', 'PN')],
#  [('dumu', 'O'), ('{d}ma-su', 'PN')],
#  [('asz-nun{ki}', 'PN'), ('ensi2-x', 'PN'), ('ba-na-...', 'O')],
#  [('ha-da-da', 'PN'), ('dam-gar3-ra', 'O')],
#  [('igi-du-am3', 'PN')],
#  [('ki', 'O'), ('lu2-ki-gu-la', 'PN')],
#  [('2(u)', 'O'), ('tug2', 'O'), ('nig2-lam2', 'O'), ('du', 'O')],
#  [('ki', 'O'), ('nu-ur2-a-sza', 'PN')],
#  [('kiszib3', 'O'), ('lugal-mudra5{ra}', 'PN')],
#  [('giri3', 'O'), ('i3-li2-mu', 'PN')],
#  [('dumu', 'O'), ('szu-dam-ki-na', 'PN')],
#  [('lu-lu-bi-um', 'PN'), ('nu-banda3-gu4', 'O')],
#  [('ki', 'O'), ('ba-mu-sza-ak', 'PN')],
#  [('gu2', 'O'), ('i7', 'O'), ('i7-tul2-la2-a{ki}', 'WN')],
#  [('ugula', 'O'), ('ba-ra-ad-KU', 'PN')],
#  [('inim-nin-ga2-ib2-ta-e3', 'PN')],
#  [('mu-kux(DU)', 'O'), ('al-la-tum', 'PN'), ('i3-dab5', 'O')],
#  [('1(asz)', 'O'), ('2(ban2)', 'O'), ('ur-dub-szen', 'PN')],
#  [('1(ban2)', 'O'), ('5(disz)', 'O'), ('szi-bu-uz-ri', 'PN')],
#  [('lu2-iri-bar', 'PN')],
#  [('mu', 'O'),
#   ('{d}x-{d}suen', 'RN'),
#   ('lugal', 'O'),
#   ('x', 'O'),
#   ('x', 'O'),
#   ('na-ru2-a-mah', 'O'),
#   ('mu-du3', 'O')],
#  [('kiszib3', 'O'), ('2(u)', 'O'), ('4(disz)', 'O'), ('ga-ri-dingir', 'PN')],
#  [('nig2-gi-na-zu', 'PN')],
#  [('ugula', 'O'), ('i3-u3-sza-na-ag2', 'PN')],
#  [('dumu', 'O'), ('lugal-kur-gu2-na', 'PN')],
#  [('2(disz)', 'O'), ('zu(SU)-ba-ga', 'PN'), ('dumu', 'O'), ('zu-ga-ra', 'PN')],
#  [('{d}mes-lam-tesz2', 'PN')],
#  [('a-bu-um-dingir', 'PN')],
#  [('la2-ia3', 'O'),
#   ('1(disz)', 'O'),
#   ('|PU3.SZA|-isz-{d}szul-gi', 'PN'),
#   ('dumu', 'O'),
#   ('...-{d}inanna', 'PN')],
#  [('1(u)', 'O'),
#   ('5(disz)', 'O'),
#   ('gurusz', 'O'),
#   ('engar', 'O'),
#   ('dumu-ni', 'O')],
#  [('nin-gin7-a-ba-gin7', 'PN')],
#  [('kiszib3', 'O'), ('ur-ab-ba-ka', 'PN')],
#  [('a-sza3', 'O'), ('{gesz}kiri6-su-gur8', 'FN')],
#  [('n', 'O'), ('udu', 'O'), ('ur-{d}nin-ig', 'PN')],
#  [('kiszib3', 'O'), ('dingir-lamma', 'PN')],
#  [('igi', 'O'), ('geme2-nun-sza3-bar', 'PN')],
#  [('ni-ga', 'PN'), ('lu2', 'O'), ('kin-gi4-a', 'O'), ('lugal', 'O')],
#  [('ugula', 'O'), ('a(ZA)-kal-la', 'PN')],
#  [('2(barig)', 'O'), ('3(ban2)', 'O'), ('isz-me-ni', 'PN')],
#  [('nesag', 'O'), ('{d}en-lil2-la2-sze3', 'DN')],
#  [('lugal-ma2-HAR-dar', 'PN'), ('uru4-sze3', 'O'), ('gen-na', 'O')],
#  [('nam-x-ni', 'PN')],
#  [('nig2-ba', 'O'), ('{d}...-gal', 'PN')],
#  [('lu2', 'O'), ('kin-gi4-a', 'O'), ('lugal-{d}sag-x', 'PN')],
#  [('sza3', 'O'), ('pa5-en7:ku6', 'GN')],
#  [('lu2-ku-la2', 'PN')],
#  [('ki', 'O'), ('lu2-iri-ki', 'PN')],
#  [('en-ni-lu', 'PN'), ('dumu', 'O'), ('u2-us2-du-ga-an', 'PN')],
#  [('mu', 'O'), ('nu-{ki}kiri6', 'GN'), ('ba-hul', 'O')],
#  [('lugal-u4-su3-sze3', 'PN'), ('gu-za-la2', 'O')],
#  [('im-KU-si', 'PN'), ('szu', 'O'), ('ba-ti', 'O')],
#  [('giri3', 'O'), ('lugal-szuba-zi', 'PN'), ('dub-sar', 'O')],
#  [('5(disz)', 'O'),
#   ('2/3(disz)', 'O'),
#   ('2(u)', 'O'),
#   ('8(disz@v)', 'O'),
#   ('1(u)', 'O'),
#   ('sze', 'O')],
#  [('kiszib3', 'O'), ('nam-sza3-tam', 'O')],
#  [('1(u)', 'O'), ('1(barig)', 'O'), ('kiszib3', 'O'), ('amar-suen', 'PN')],
#  [('ki', 'O'), ('{d}iszkur-a-mu', 'PN')],
#  [('7(disz)', 'O'), ('masz2', 'O')],
#  [('2(asz)', 'O'), ('saga', 'O'), ('lu2-kal-la', 'PN')],
#  [('lugal', 'O'), ('uri5{ki}-ma', 'SN')],
#  [('giri3', 'O'), ('{d}en-ki-nin-ul-gur3', 'PN')],
#  [('sza3', 'O'), ('e2', 'O'), ('{d}szu-il-at', 'DN')],
#  [('mu', 'O'),
#   ('us2-sa', 'O'),
#   ('isin2{si}{ki}-ke4(RA)-ne', 'GN'),
#   ('ba-hul', 'O')],
#  [('ki', 'O'), ('du-szu-mu-um-ma', 'PN')],
#  [('1(ban2)', 'O'), ('5(disz)', 'O'), ('EN', 'PN')],
#  [('lugal', 'O'), ('uri5{ki}-la', 'GN'), ('hi-bi2-la-ti{ki}', 'GN')],
#  [('ab-ba-gi-na', 'PN'), ('am-na-nu-um', 'GN')],
#  [('4(disz)', 'O'), ('sar', 'O'), ('kab2-ku5', 'O'), ('bu3-la', 'FN')],
#  [('kun-zi-da', 'O'),
#   ('i7', 'O'),
#   ('id2(ENGUR)-kun-sumun-kam', 'WN'),
#   ('gub-ba', 'O')],
#  [('szu-zu', 'PN'), ('gaba-asz', 'O')],
#  [('kiszib3', 'O'), ('lu2-{muszen}uz-ga', 'PN')],
#  [('dumu', 'O'), ('giri3-ni(MUG)', 'PN'), ('ba-usz2', 'O')],
#  [('dumu', 'O'), ('u-bar-tum', 'PN'), ('ba-usz2', 'O')],
#  [('mu', 'O'), ('szabra-ke4-ne', 'GN'), ('ba-hul', 'O')],
#  [('gurusz-bi', 'O'), ('4(disz)', 'O'), ('u4', 'O'), ('1(disz)-sze3', 'O')],
#  [('lugal', 'O'), ('asz2-nun{ki}', 'GN'), ('nibru{ki}-x', 'GN')],
#  [('1(u)', 'O'),
#   ('5(disz)', 'O'),
#   ('u8', 'O'),
#   ('2(u)', 'O'),
#   ('2(disz)', 'O'),
#   ('udu', 'O')],
#  [('ki', 'O'), ('ab-ba-ba-ti', 'PN')],
#  [('dumu', 'O'), ('KA-sa-NE', 'PN'), ('szusz3', 'O')],
#  [('ur-igi-ma-lugal', 'PN')],
#  [('giri3', 'O'), ('i3-num2-mi-a', 'PN')],
#  [('kiszib3', 'O'), ('in-mu-na-si', 'PN')],
#  [('lu2-{d}ga2-tum3-du10', 'PN')],
#  [('a-ba-{d}nanna-gin7', 'PN')],
#  [('lugal', 'O'), ('szimaszki{ki}', 'GN'), ('szu-ru-ud-hu-um{ki}', 'GN')],
#  [('szuku', 'O'), ('sza-lim-be-li2', 'PN')],
#  [('2(asz)', 'O'), ('2(barig)', 'O'), ('lu2-kal-la-da', 'PN')],
#  [('ki-la2-bi', 'O'),
#   ('5(disz)', 'O'),
#   ('2/3(disz)', 'O'),
#   ('sar', 'O'),
#   ('4(disz)', 'O'),
#   ('gin2', 'O')],
#  [('1(barig)', 'O'), ('kasz', 'O'), ('...', 'O'), ('x', 'O'), ('...', 'O')],
#  [('en-dim2-gi8-sze3', 'SN')],
#  [('nigar{gar}-ke4-ne', 'PN')],
#  [('i7', 'O'), ('gibil', 'O'), ('a-sza3-{d}nin-ur4', 'WN')],
#  [('giri3', 'O'), ('di-x', 'PN')],
#  [('{gi}ma-sab', 'PN')],
#  [('me-{d}nin-szubur', 'PN')],
#  [('szunigin', 'O'),
#   ('2(ban2)', 'O'),
#   ('2(disz)', 'O'),
#   ('sila3', 'O'),
#   ('ninda', 'O'),
#   ('szunigin', 'O'),
#   ('6(disz)', 'O'),
#   ('gin2', 'O'),
#   ('i3', 'O')],
#  [('{d}nanna-ku3-du11-ge', 'PN')],
#  [('2(disz)', 'O'),
#   ('udu', 'O'),
#   ('niga', 'O'),
#   ('1(disz)', 'O'),
#   ('masz2', 'O')],
#  [('nig2-{d}utu-mu-tum3', 'PN')],
#  [('kiszib3', 'O'), ('lu2-{d}sud3', 'PN')],
#  [('ha-ni-a-li-kam', 'PN')],
#  [('...', 'O'), ('ur-x-ma', 'PN'), ('nu-banda3', 'O')],
#  [('geme2-{d}x-x', 'PN')],
#  [('nin-sza3-si-si', 'PN'), ('i3-dab5', 'O')],
#  [('a-ba-{d}en-lil2-gin7', 'PN')],
#  [('kiszib3', 'O'), ('ka-tar-{d}nansze', 'PN')],
#  [('2(disz)', 'O'), ('{d}nin-tu-KA-i3-sa6', 'PN')],
#  [('mi-na-nu-um', 'PN')],
#  [('i7-dul9-la{ki}-ka', 'PN')],
#  [('nu-banda3', 'O'), ('ti-im-ti-be-li2-ba-ni', 'PN')],
#  [('iti', 'O'),
#   ('apin-du8-a', 'MN'),
#   ('u4', 'O'),
#   ('2(u)', 'O'),
#   ('ba-zal', 'O')],
#  [('n', 'O'),
#   ('n(barig)', 'O'),
#   ('1(ban2)', 'O'),
#   ('gur', 'O'),
#   ('ki', 'O'),
#   ('du3-us2', 'PN')],
#  [('giri3', 'O'), ('hu-un-na-zi', 'PN')],
#  [('ki', 'O'), ('GAN2-GAN2-mu-e3', 'PN')],
#  [('dumu', 'O'), ('{d}en-lil2-an-zu', 'PN')],
#  [('kiszib3', 'O'), ('{d}szul-gi-a2-mah', 'PN')],
#  [('dumu', 'O'), ('{d}nun-gal-an-dul3', 'PN')],
#  [('ki', 'O'), ('munu4-{d}lamma-...', 'PN')],
#  [('ki', 'O'), ('a-ga-hu', 'PN')],
#  [('dumu', 'O'), ('du-du8-x-um-ba-ti-la', 'PN')],
#  [('1(asz)', 'O'), ('saga', 'O'), ('nin-mu-uszur3-mu', 'PN')],
#  [('a-sza3', 'O'), ('{d}pa-bil3-sag', 'FN'), ('sag', 'O'), ('erin-gaba', 'O')],
#  [('1(disz)', 'O'),
#   ('dug', 'O'),
#   ('dida', 'O'),
#   ('1(ban2)', 'O'),
#   ('zi3', 'O'),
#   ('szu-i3-li2', 'PN'),
#   ('lu2', 'O'),
#   ('kin-gi4-a', 'O')],
#  [('iti', 'O'), ('ezem-{d}me-ki-gal2-sze3', 'MN')],
#  [('kiszib3', 'O'), ('KA-KU-KU', 'PN')],
#  [('sze', 'O'), ('giri3', 'O'), ('gu-ub-{d}utu', 'PN')],
#  [('ur-dub-la2-mah', 'PN'), ('sukkal', 'O')],
#  [('4(iku)', 'O'),
#   ('1/2(iku)', 'O'),
#   ('GAN2', 'O'),
#   ('5(asz)', 'O'),
#   ('3(barig)', 'O'),
#   ('|PU3.SZA|-ma-ma', 'PN')],
#  [('kiszib3', 'O'), ('{d}szul-gi-sipa-kalam-ma', 'PN')],
#  [('3(disz)', 'O'), ('a-tum', 'PN')],
#  [('1(barig)', 'O'), ('geme2-{d}gesztin-an-ka', 'PN')],
#  [('2(asz)', 'O'), ('lugal-eb2-gu-ul', 'PN')],
#  [('ki', 'O'), ('ar-sza-bi2-in-num2', 'PN')],
#  [('dumu', 'O'), ('i-bi-iq-x', 'PN')],
#  [('1(ban2)', 'O'),
#   ('5(disz)', 'O'),
#   ('nu', 'O'),
#   ('igi-zu-bar', 'PN'),
#   ('x', 'O')],
#  [('2(barig)', 'O'), ('3(ban2)', 'O'), ('geme2-dub-szen', 'PN')],
#  [('ki', 'O'), ('lugal-engar-x', 'PN')],
#  [('ki', 'O'), ('e2-lu2-ti', 'PN')],
#  [('3(disz)', 'O'),
#   ('gin2', 'O'),
#   ('i3', 'O'),
#   ('2(disz)', 'O'),
#   ('gin2', 'O'),
#   ('naga', 'O'),
#   ('lugal-gub-ba-ni-du10-mu', 'PN')],
#  [('dumu', 'O'), ('{d}szul-gi-bad3', 'PN')],
#  [('1(u)', 'O'), ('gu4', 'O'), ('8(disz)', 'O'), ('sila3', 'O')],
#  [('lu2-sza-lim', 'PN'), ('gaba-ta', 'O')],
#  [('sze', 'O'),
#   ('gurx(|SZE.KIN|)-a', 'O'),
#   ('zar3', 'O'),
#   ('tab-ba', 'O'),
#   ('ki-su7', 'O'),
#   ('gub-ba', 'O'),
#   ('a-sza3', 'O'),
#   ('asz-ne-u18', 'PN')],
#  [('mu', 'O'), ('ma2', 'O'), ('{d}en-zi-kalam-ma', 'DN'), ('ba-ab-du8', 'O')],
#  [('mu', 'O'), ('e2-a-da{ki}', 'GN'), ('ba-hul', 'O')],
#  [('a-li2-we-er', 'PN')],
#  [('i3-dub', 'O'), ('a-sza3', 'O'), ('inim-ur-{d}dumu-zi', 'FN')],
#  [('giri3', 'O'), ('lu2-x-x-x', 'PN')],
#  [('{d}en-lil2-sa6', 'PN')],
#  [('n', 'O'),
#   ('4(barig)', 'O'),
#   ('1(ban2)', 'O'),
#   ('gur', 'O'),
#   ('ki', 'O'),
#   ('lugal-me-a', 'PN')],
#  [('dumu', 'O'), ('{d}dumu-zi-an-dul3', 'PN')],
#  [('lugal-anzu{muszen}', 'PN')],
#  [('ki', 'O'), ('amar-AB', 'PN')],
#  [('mu', 'O'), ('gu-sa-za-um{ki}', 'GN'), ('ba-hul', 'O')],
#  [('ki', 'O'), ('en-im-ta-x', 'PN')],
#  [('mu-kux(DU)', 'O'), ('hu-hu-ni', 'PN')],
#  [('sze-ba', 'O'), ('u3', 'O'), ('a-sza3', 'O'), ('a-sag-du3-du-gu-la', 'FN')],
#  [('1(u)', 'O'),
#   ('7(disz)', 'O'),
#   ('kid2', 'O'),
#   ('gi', 'O'),
#   ('tuku', 'O'),
#   ('x-da', 'O')],
#  [('1(ban2)', 'O'), ('szesz', 'O'), ('lu2-MI-an-na', 'PN')],
#  [('amar-e2', 'PN'), ('dumu', 'O'), ('be-li2-{d}ma-ar', 'PN')],
#  [('giri3', 'O'), ('gi4-da-num2', 'PN')],
#  [('ugula', 'O'), ('en-mah-gal-an-na', 'PN')],
#  [('kiszib3', 'O'), ('a-gu4', 'PN')],
#  [('ugula', 'O'), ('HAR-x', 'PN')],
#  [('1(disz)', 'O'), ('nin-u8-udu-ni', 'PN')],
#  [('kiszib3', 'O'), ('nin-tum-ma', 'PN')],
#  [('mu', 'O'), ('uszum-a-nun-nun', 'PN'), ('ba-hun', 'O')],
#  [('...-iti-da-...', 'PN')],
#  [('lugal-DIN-x', 'PN')],
#  [('a-sza3', 'O'), ('a2-{d}nin-ga2', 'PN')],
#  [('a-za-za', 'PN'), ('szu', 'O'), ('ba-ti', 'O')],
#  [('lugal', 'O'), ('ni-da-ra-asz-pi2{ki}', 'GN'), ('NI-HI{ki}', 'GN')],
#  [('ki', 'O'), ('ur-sila-luh', 'PN')],
#  [('e2-duru5', 'O'), ('su-bir5{ki}', 'GN')],
#  [('bi2-i3-bi2-a', 'PN'), ('szu', 'O'), ('ba-ti', 'O')],
#  [('giri3', 'O'), ('i-mar-i3-li2', 'PN')],
#  [('ki', 'O'), ('{d}nirah{ir-ha}-din-dub2-DU', 'PN')],
#  [('e2', 'O'), ('ti-ra-asz2', 'TN')],
#  [('giri3', 'O'), ('lugal-dumu-gi7', 'PN')],
#  [('szu-ha-li-ab', 'PN')],
#  [('...', 'O'), ('5(ban2)', 'O'), ('ziz2', 'O'), ('he2-ti', 'PN')],
#  [('ur-en', 'PN'), ('na-gada', 'O')],
#  [('kiszib3', 'O'), ('gu-u3-mu', 'PN')],
#  [('a-mu-esz18-dar', 'PN')],
#  [('ugula', 'O'), ('geme2-ga2-da', 'PN')],
#  [('ki', 'O'), ('lugal-pa-...', 'PN')],
#  [('{d}szul-gi-sza-am3-szi', 'PN'), ('ensi2-ka', 'O')],
#  [('8(disz)', 'O'), ('masz2', 'O')],
#  [("1(bur'u)", 'O'),
#   ('1(bur3)', 'O'),
#   ('1(esze3)', 'O'),
#   ('GAN2', 'O'),
#   ('gesz-ur3-ra', 'O'),
#   ('a-ra2', 'O'),
#   ('2(disz)-kam', 'O'),
#   ('4(disz)', 'O'),
#   ('1/2(iku)', 'O'),
#   ('GAN2-ta', 'O')],
#  [('ur-{d}ba-ba6', 'PN'), ('ensi2', 'O')],
#  [('kiszib3', 'O'), ('e2-nigin-bi-x', 'PN')],
#  [('lugal-zimbir{ki}', 'PN'), ('dub-sar', 'O')],
#  [('inim', 'O'), ('nin9-ku3-zu', 'PN')],
#  [('5(disz)', 'O'),
#   ('sila3', 'O'),
#   ('kasz', 'O'),
#   ('saga', 'O'),
#   ('5(disz)', 'O'),
#   ('sila3', 'O'),
#   ('ninda', 'O'),
#   ('5(disz)', 'O'),
#   ('gin2', 'O'),
#   ('szum2', 'O')],
#  [('ki', 'O'), ('su-sze-gan-a2-ba', 'PN')],
#  [('mu', 'O'), ('ni-a-mi-isz{ki}', 'GN'), ('ba-hul', 'O')],
#  [('lugal', 'O'), ('ma-az-SUHUR-a{ki}', 'GN'), ('bi2-la{ki}', 'GN')],
#  [('1(asz)', 'O'), ('1(barig)', 'O'), ('{d}lugal-ku3-ki', 'PN')],
#  [('3(asz)', 'O'), ('du', 'O'), ('en-gin7-sa6', 'PN')],
#  [('1(ban2)', 'O'), ('5(disz)', 'O'), ('gu-du-me-ri-isz', 'PN')],
#  [('lu2-za3', 'PN')],
#  [('kiszib3', 'O'), ('lugal-...-bi-...', 'PN')],
#  [('in-ki-si2-im-ti', 'PN'), ('i3-dab5', 'O')],
#  [('sze-ba', 'O'), ('u3', 'O'), ('a-sza3', 'O'), ('{gesz}x-...', 'FN')],
#  [('3(disz)', 'O'), ('ur-gu2-nu2', 'PN')],
#  [('ur-gu', 'PN')],
#  [('NI-za', 'PN')],
#  [('kiszib3', 'O'), ('be-li2-na-ha-ti', 'PN'), ('dub-sar', 'O')],
#  [('a-ab', 'PN')],
#  [('ki-a-nag', 'O'), ('a-da-be-li2', 'PN')],
#  [('8(disz)', 'O'),
#   ('sar', 'O'),
#   ('kin', 'O'),
#   ('u2', 'O'),
#   ('sahar-ba', 'O'),
#   ('kab2-ku5', 'O'),
#   ('a-ba-gal-sag-an-na', 'FN')],
#  [('geme2-gu3-de2-a', 'PN')],
#  [('uru4-a', 'O'), ('2(iku)', 'O'), ('GAN2-ta', 'O'), ('...', 'O')],
#  [('lu2-{d}szul-...', 'PN')],
#  [('geme2-ma-da', 'PN')],
#  [('1(u)', 'O'), ('5(asz)', 'O'), ('giri3', 'O'), ('zu-ru-ki', 'PN')],
#  [('kiszib3', 'O'), ('nin-si-par4', 'PN')],
#  [('1(ban2)', 'O'), ('2(disz)', 'O'), ('gin2', 'O'), ('ama-ug2-ga', 'PN')],
#  [('kiszib3', 'O'), ('{d}sza3-ra-hu-um-ma', 'PN')],
#  [('ma-gu-ul', 'PN')],
#  [('1(disz)', 'O'),
#   ('udu', 'O'),
#   ('1/3(disz)', 'O'),
#   ('gin2', 'O'),
#   ('2(u)', 'O'),
#   ('sze', 'O'),
#   ('...', 'O')],
#  [('ki', 'O'), ('igi-dim-kesz2', 'PN')],
#  [('i3-dub', 'O'), ('a-sza3', 'O'), ('szesz-bara2', 'FN')],
#  [('4(disz)', 'O'), ('1/2(disz)', 'O'), ('gin2', 'O'), ('ku3', 'O')],
#  [('ur-zu-ka', 'PN')],
#  [('giri3', 'O'), ('dingir-lu-ba-ni', 'PN'), ('sukkal', 'O')],
#  [('ki', 'O'), ('ur-ra-a-zu', 'PN')],
#  [('1(disz)', 'O'), ('gukkal', 'O'), ('{d}suen-ka3-szi-id', 'PN')],
#  [('ki', 'O'), ('{d}szul-gi-si-im-tum', 'PN')],
#  [('3(disz)', 'O'),
#   ('sila3', 'O'),
#   ('kasz', 'O'),
#   ('2(disz)', 'O'),
#   ('sila3', 'O'),
#   ('ninda', 'O'),
#   ('3(disz)', 'O'),
#   ('gin2', 'O'),
#   ('szum2', 'O'),
#   ('3(disz)', 'O'),
#   ('gin2', 'O'),
#   ('i3', 'O'),
#   ('2(disz)', 'O'),
#   ('gin2', 'O'),
#   ('naga', 'O')],
#  [('kiszib3', 'O'), ('ma-sag10', 'PN')],
#  [('ki', 'O'), ('lugal-du-x', 'PN')],
#  [('szu-x-na', 'PN'), ('i3-dab5', 'O')],
#  [('igi', 'O'), ('ab-ba-gi-na-sze3', 'PN')],
#  [('ku3-bi', 'O'), ('1(u)', 'O'), ('1(disz)', 'O'), ('sze', 'O')],
#  [('nin-{d}ku3-sig17', 'PN')],
#  [('...', 'O'), ('la2', 'O'), ('1(disz)', 'O'), ('...', 'O')],
#  [('2(gesz2)', 'O'),
#   ('5(u)', 'O'),
#   ('la2', 'O'),
#   ('2(disz)', 'O'),
#   ('udu', 'O')],
#  [('2(u)', 'O'),
#   ('6(disz)', 'O'),
#   ('gu4', 'O'),
#   ('lu2', 'O'),
#   ('mar-ha-szi{ki}', 'SN')],
#  [('2(gesz2)', 'O'), ('gur', 'O'), ('a-sza3', 'O'), ('hi-ba-ri2-tum', 'FN')],
#  [('1(asz)', 'O'), ('saga', 'O'), ('nin-mu-sze3-igi-mu-la2', 'PN')],
#  [('ki', 'O'), ('lu2-{d}dumu-zi', 'PN')],
#  [('4(disz)', 'O'), ('ab2', 'O'), ('mu', 'O'), ('2(asz)', 'O')],
#  [('ki', 'O'), ('lu2-ku-ni-da', 'PN')],
#  [('ru-ba-tum', 'PN')],
#  [('{d}nin-mar{ki}-ab2-lu', 'GN'),
#   ('u3', 'O'),
#   ('nibru{ki}-ta', 'SN'),
#   ('gen-na', 'O')],
#  [('ki', 'O'), ('ba-mu-ka', 'PN')],
#  [('kiszib3', 'O'), ('ur-{u2}ninni5', 'PN')],
#  [('mu', 'O'),
#   ('us2-sa', 'O'),
#   ('a-pi4-sal4-musz-bi-edin-na', 'GN'),
#   ('ba-hul', 'O')],
#  [('siskur2', 'O'), ('{d}be-la-at-suh-ner', 'DN')],
#  [('mu', 'O'), ('unu{ki}-ga-asz', 'GN'), ('ba-hul', 'O')],
#  [('1(disz)', 'O'), ('{gesz}ig', 'O'), ('LAGAB-a', 'O'), ('...', 'O')],
#  [('...', 'O'), ('nin-{d}ba-ba6', 'PN')],
#  [('dumu', 'O'), ('lugal-la{ki}', 'PN')],
#  [('lu2', 'O'), ('lugal-kal-ga', 'PN'), ('ka(SAG)-guru7', 'O')],
#  [('geme2-a-tu5', 'PN'), ('gu4', 'O'), ('udu-da', 'O'), ('gen-na', 'O')],
#  [('x-x-mu', 'PN')],
#  [('ki', 'O'), ('dingir-al-su', 'PN')],
#  [('lu2-kas4-me-esz2', 'PN'), ('szu', 'O'), ('ba-ti', 'O')],
#  [('a-sza3', 'O'), ('lu2-ka-dim', 'FN')],
#  [('...', 'O'),
#   ('7(asz)', 'O'),
#   ('1(ban2)', 'O'),
#   ('...', 'O'),
#   ('ur-gidri', 'PN')],
#  [('ama-muru2', 'PN')],
#  [('ku3-gin2', 'PN')],
#  [('iti', 'O'), ('ses-da-gu7', 'MN')],
#  [('ki', 'O'), ('|PU3.SZA|-lu-ni', 'PN')],
#  [('la2-ia3', 'O'), ('su-ga', 'O'), ('tu-ga-rum', 'PN')],
#  [('1(asz)', 'O'),
#   ('saga', 'O'),
#   ('2(asz)', 'O'),
#   ('du', 'O'),
#   ('ur-{d}en-ki', 'PN')],
#  [('4(gesz2)', 'O'), ('2(u)', 'O'), ('masz2', 'O')],
#  [('lugal', 'O'), ('e2-te-na', 'GN'), ('gar-sza-na{ki}-ka', 'GN')],
#  [('lugal', 'O'), ('zi-da-nu-um{ki}', 'GN'), ('zi-da-ni-num2{ki}', 'GN')],
#  [('lu2', 'O'), ('kin-gi4-a', 'O'), ('giri3-ni-i3-dab5', 'PN')],
#  [('lu2-bala-sa6-ga', 'FN')],
#  [('giri3', 'O'), ('szesz-sa6-sa6', 'PN')],
#  [('ni-li', 'PN')],
#  [('i3-dub', 'O'), ('a-sza3', 'O'), ('da-hul2-la', 'FN')],
#  [('dumu', 'O'), ('lugal-ma2-gur8-re', 'PN')],
#  [('szu-esz-dar', 'PN'), ('szu', 'O'), ('ba-ti', 'O')],
#  [('mu', 'O'), ('us2-sa', 'O'), ('e2-gibil4-le{ki}', 'GN'), ('ba-hul', 'O')],
#  [('u4', 'O'), ('1(disz)-kam', 'O'), ('u4', 'O'), ('3(u)-sze3', 'O')],
#  [('dumu', 'O'), ('lugal-sila3-x', 'PN')],
#  [('kiszib3', 'O'), ('lu2-ra-ba', 'PN'), ('sukkal', 'O')],
#  [('ki', 'O'), ('ur-x-kal', 'PN')],
#  [('ki', 'O'), ('nig2-{d}ba-ba6-NI-ba', 'PN')],
#  [('1(disz)', 'O'), ('udu', 'O'), ('niga', 'O'), ('{d}ku3-su3', 'DN')],
#  [('ki', 'O'), ('ur-ki-la2-a', 'PN')],
#  [('...', 'O'), ('nin-dilmun-mah', 'PN')],
#  [('ki', 'O'), ('lu2-igi-x-dim2-ma', 'PN')],
#  [('ki', 'O'), ('er3-ra-x-x', 'PN')],
#  [('i7', 'O'), ('gibil', 'O'), ('i7-e-e-dar-a', 'WN')],
#  [('3(disz)', 'O'), ('e2-ku4-ra-ni-sa6', 'PN')],
#  [('dumu', 'O'), ('szu-{d}esz18-dar', 'PN')],
#  [('giri3-i3-sa6', 'PN')],
#  [('dumu', 'O'), ('nin-ib2-ta-e3', 'PN')],
#  [('6(disz)', 'O'), ('udu', 'O'), ('szu-gid2', 'O')],
#  [('mu', 'O'),
#   ('en', 'O'),
#   ('{d}a-ba-ba', 'DN'),
#   ('kar-zi-da', 'SN'),
#   ('ba-hun', 'O')],
#  [('iti', 'O'), ('masz-da3-gu7', 'MN')],
#  [('ugula', 'O'), ('ku-bala', 'PN')],
#  [('1(disz)', 'O'), ('du-ki-in', 'PN')],
#  [('ARAD2-dam', 'PN')],
#  [('ki', 'O'), ('sag-sug5-ka-kam', 'PN')],
#  [('mu', 'O'), ('en', 'O'), ('HAR-im', 'DN'), ('ba-a-hun-sze3', 'O')],
#  [('mu', 'O'),
#   ('{d}nanna', 'DN'),
#   ('kar-zi-da', 'SN'),
#   ('a-ra2', 'O'),
#   ('2(disz@t)', 'O')],
#  [('PA', 'O'), ('e2-da-hul2-la', 'PN')],
#  [('dumu', 'O'), ('ni-a-ma-ti', 'PN')],
#  [('i3-dub', 'O'), ('a-sza3', 'O'), ('es3-sa2-...', 'FN')],
#  [('...', 'O'), ('na-ra-am-{d}en-zu', 'PN')],
#  [('{d}x', 'DN'), ('...', 'O')],
#  [('a-sza3', 'O'), ('u2-du-lu-za-ma-hi', 'FN')],
#  [('ki', 'O'), ('lugal-un-ga2', 'PN')],
#  [('5(disz)', 'O'),
#   ('sila3', 'O'),
#   ('kasz', 'O'),
#   ('3(disz)', 'O'),
#   ('sila3', 'O'),
#   ('ninda', 'O'),
#   ('3(disz)', 'O'),
#   ('gin2', 'O'),
#   ('szum2', 'O'),
#   ('3(disz)', 'O'),
#   ('gin2', 'O'),
#   ('i3', 'O'),
#   ('2(disz)', 'O'),
#   ('gin2', 'O'),
#   ('naga', 'O')],
#  [('ki', 'O'), ('er3-e2-ninnu', 'PN')],
#  [('giri3-se3-ga', 'O'), ('{gesz}kiri6', 'O'), ('nin-ama-tu-da-ni', 'PN')],
#  [('ki', 'O'), ('ur-sila-sir2-sir2', 'PN')],
#  [('ki', 'O'), ('ad-la-{d}iszkur', 'PN'), ('aszgab-ta', 'O')],
#  [('ugula', 'O'), ('ur-es3-sa2', 'PN')],
#  [('{d}x-x-x-a', 'PN'), ('i3-dab5', 'O')],
#  [('gu-u2-gu-a', 'PN')],
#  [('2(disz)', 'O'),
#   ('u8', 'O'),
#   ('a-lum', 'O'),
#   ('2(disz)', 'O'),
#   ('udu', 'O'),
#   ('gukkal', 'O')],
#  [('kiszib3', 'O'), ('nu-ur2-{d}szu-{d}suen', 'PN')],
#  [('dumu', 'O'), ('tab-i3-li2', 'PN')],
#  [('a-sza3', 'O'), ('ugur2-tur-tum', 'FN')],
#  [('a2-ga2-dab5-ba', 'PN'), ('i3-dab5', 'O')],
#  [('1(disz)', 'O'),
#   ('udu', 'O'),
#   ('{d}esz18-dar-al-su', 'PN'),
#   ('x', 'O'),
#   ('x', 'O')],
#  [('ur-lagar', 'PN')],
#  [('ki', 'O'), ('na-ba-x', 'PN')],
#  [('giri3', 'O'), ('ah-ha-ti-mur', 'PN'), ('sukkal', 'O')],
#  [('zi-ib-mi-szar', 'PN')],
#  [('ki', 'O'), ('ti-um-ma', 'PN')],
#  [('ki', 'O'), ('da-at-ti', 'PN')],
#  [('ur-mu', 'PN')],
#  [('a-tir', 'PN')],
#  [('ki', 'O'), ('na-sa6', 'PN')],
#  [('kab2-ku5', 'O'), ('e2-duru5-ad-da', 'FN')],
#  [('hu-li2-bar-a', 'PN'), ('dub-sar', 'O'), ('maszkim', 'O')],
#  [('kun-zi-da', 'O'),
#   ('i7', 'O'),
#   ('{gesz}kiri6-a-ab-ba-ka', 'WN'),
#   ('gub-ba', 'O')],
#  [('{d}GESZ-x', 'PN'), ('sanga', 'O')],
#  [('eren-da-ni', 'PN')],
#  [('2(barig)', 'O'), ('3(ban2)', 'O'), ('{d}ku3-sig17', 'PN')],
#  [('giri3', 'O'),
#   ('lugal-szesz-x', 'PN'),
#   ('lu2', 'O'),
#   ('kin-gi4-a', 'O'),
#   ('lugal', 'O')],
#  [('u4', 'O'), ('n-kam', 'O')],
#  [('2(barig)', 'O'), ('3(ban2)', 'O'), ('szesz-du3-a', 'PN')],
#  [('dumu', 'O'), ('en-in-na-kal', 'PN')],
#  [('kiszib3', 'O'), ('ku-zu-ku-zu', 'PN')],
#  [('e2-lu2-...', 'PN'), ('dam-gar3', 'O')],
#  [('ri-ba-a-ka', 'PN')],
#  [('aga3-us2', 'O'),
#   ('lugal', 'O'),
#   ('ki', 'O'),
#   ('ur-{d}nin-pirig-kam', 'PN'),
#   ('gen-na', 'O')],
#  [('mu', 'O'), ('e2-nam-ha-ni', 'PN')],
#  [('szunigin', 'O'),
#   ('3(u)', 'O'),
#   ('3(barig)', 'O'),
#   ('8(disz)', 'O'),
#   ('1/2(disz)', 'O'),
#   ('sila3', 'O')],
#  [('ki', 'O'), ('nin-mu-ha-ma-ti', 'PN')],
#  [('ki', 'O'), ('a-lum-gun3-a', 'PN')],
#  [('3(disz)', 'O'), ('ama6-tu', 'PN')],
#  [('dumu', 'O'), ('dingir-tu', 'PN')],
#  [('1(bur3)', 'O'),
#   ('1(esze3)', 'O'),
#   ('2(iku)', 'O'),
#   ('GAN2', 'O'),
#   ('a-sza3', 'O'),
#   ('{gesz}balag-kur-DU-na', 'FN')],
#  [('1(gesz2)', 'O'),
#   ('2(u)', 'O'),
#   ('udu', 'O'),
#   ('1(disz)', 'O'),
#   ('1/2(disz)', 'O'),
#   ('sila3', 'O'),
#   ('1(gesz2)', 'O'),
#   ('5(disz)', 'O'),
#   ('udu', 'O'),
#   ('1(disz)', 'O'),
#   ('sila3', 'O'),
#   ('sze-bi', 'O'),
#   ('3(barig)', 'O'),
#   ('5(disz)', 'O'),
#   ('sila3', 'O'),
#   ('ur-{d}nanibgal', 'PN')],
#  [('dingir-re-i3-zu', 'PN'), ('nu-banda3', 'O')],
#  [('mu-kux(DU)', 'O'), ('ur-{d}iszkur', 'PN')],
#  [('dingir-mu-ta2-bil2', 'PN')],
#  [('ugula', 'O'), ('a-bi2-zu-zi', 'PN')],
#  [('ur-nig2-a-x', 'PN'), ('aga3-us2-gal', 'O')],
#  [('2(disz)', 'O'),
#   ('dam-ba-al-la', 'PN'),
#   ('dumu', 'O'),
#   ('lugal-sipa-sipa-hal-hal-la', 'PN')],
#  [('zi-sza{ki}', 'GN'), ('u3', 'O'), ('nibru{ki}-ta', 'SN'), ('gen-na', 'O')],
#  [('2(disz)', 'O'), ('ri-im-ga-ga', 'PN')],
#  [('{d}pa-bil-mu-dah', 'PN')],
#  [('giri3', 'O'), ('a-ni-im-ma', 'PN'), ('sukkal', 'O')],
#  [('ka-sa6-a', 'PN')],
#  [('sze-musz3', 'PN')],
#  [('ugula', 'O'), ('ba-za', 'PN')],
#  [('ki-su7', 'O'), ('GAN2-ku3', 'FN'), ('gub-ba', 'O')],
#  [('ni-SU', 'PN')],
#  [('kiszib3', 'O'), ('bar-su', 'PN')],
#  [('bur2-sar', 'PN')],
#  [('dumu', 'O'), ('e-lum-me-luh', 'PN')],
#  [('giri3', 'O'), ('lu2-bar', 'PN')],
#  [('{d}nanna-zi', 'PN')],
#  [('id-dan-num2', 'PN')],
#  [('mu', 'O'), ('ur-bi2-bi2-lum{ki}', 'GN'), ('ba-hul', 'O')],
#  [('mu', 'O'),
#   ('us2-sa', 'O'),
#   ('{d}szul-gi-he2-gal2{ki}', 'GN'),
#   ('ba-hul', 'O')],
#  [('sa6-ga-tur', 'PN')],
#  [('lu2-...-x-x', 'PN'), ('aga3-us2-gal', 'O')],
#  [('dumu', 'O'), ('ba-hi-zu-zu', 'PN')],
#  [('musz-bi-an-na', 'FN'), ('gub-ba', 'O')],
#  [('muszen-x', 'PN')],
#  [('u4-su13', 'PN')],
#  [('ki', 'O'), ('sza3-la2-tum', 'PN')],
#  [('a-sza3', 'O'), ('nin-tug2-asz-mah', 'FN')],
#  [('szuku', 'O'),
#   ('u2-lam-i3-li2', 'PN'),
#   ('u3', 'O'),
#   ('u3-ba-a', 'PN'),
#   ('ul-le-be-lu-ug', 'PN')],
#  [('1(barig)', 'O'), ('sze-ba', 'O'), ('ga-ad-ma-nu-um', 'PN')],
#  [('du11-ga-{d}szara2', 'PN')],
#  [('ki', 'O'), ('ur-{d}ba-ba6-da-gen-na', 'PN')],
#  [('4(barig)', 'O'), ('ki', 'O'), ('...-i3-tar', 'PN'), ('...-ta', 'O')],
#  [('lugal-zi', 'PN')],
#  [('ki', 'O'), ('lu2-nam-...', 'PN')],
#  [('szunigin', 'O'),
#   ('5/6(disz)', 'O'),
#   ('sila3', 'O'),
#   ('1(disz)', 'O'),
#   ('gin2', 'O'),
#   ('i3', 'O')],
#  [('mu', 'O'), ('A2-pil-li2-ni', 'PN'), ('{d}inanna', 'DN'), ('ba-hun', 'O')],
#  [('masz-um', 'PN'), ('dumu', 'O'), ('ur-ma-an-ba', 'PN')],
#  [('ki', 'O'), ('nam-mah-uru11{ki}', 'PN')],
#  [('isz-me-a', 'PN'), ('dub-sar', 'O'), ('maszkim', 'O')],
#  [('2(disz)', 'O'), ('lugal-{d}lamma-mu', 'PN')],
#  [('1(disz)', 'O'), ('sila4', 'O'), ('geme2-e2-hi-nun', 'PN')],
#  [('siskur2', 'O'), ('zi-zi-da', 'DN')],
#  [('2(disz)', 'O'), ('sila4', 'O'), ('ur-ki-lu2', 'PN'), ('sanga', 'O')],
#  [('unu3-de3-ne', 'PN')],
#  [('giri3', 'O'), ('a-ki-ma', 'PN'), ('sukkal', 'O')],
#  [('{d}szul-gi(ZI)', 'RN'), ('nita', 'O'), ('kal-ga', 'O')],
#  [('mu-ni-e2-gal-la', 'PN')],
#  [('ugula', 'O'), ('u3-lu-lu', 'PN')],
#  [('giri3', 'O'), ('ur-{d}bil2', 'PN'), ('sukkal', 'O'), ('lugal', 'O')],
#  [('2(disz)', 'O'), ('|PU3.SZA|-er3-ra', 'PN')],
#  [('mu', 'O'),
#   ('{d}szu-{d}suen', 'RN'),
#   ('lugal', 'O'),
#   ('uri5{ki}-ma-ke4', 'SN'),
#   ('e2', 'O'),
#   ('{d}lugal-es3-sa2', 'DN'),
#   ('umma{ki}-ka', 'SN'),
#   ('mu-du3', 'O')],
#  [('1(asz)', 'O'), ('gur', 'O'), ('kiszib3', 'O'), ('ba-na-ha', 'PN')],
#  [('i7', 'O'), ('gibil', 'O'), ('a-sza3-...-du-mu-ul-li', 'WN')],
#  [('ki', 'O'), ('lu2-esz18-dar', 'PN')],
#  [('ki', 'O'), ('ur-{d}nisaba-ta', 'PN')],
#  [('...', 'O'), ('GAN2', 'O'), ('su3', 'O')],
#  [('6(disz)', 'O'), ('gurusz', 'O'), ('u4', 'O'), ('2(disz)-sze3', 'O')],
#  [('ma2', 'O'), ('an-na-sze3', 'DN')],
#  [('ki', 'O'), ('ARAD2-am3', 'PN'), ('dumu', 'O'), ('ma-ba', 'PN')],
#  [('la2-ia3', 'O'),
#   ('ka-ga', 'O'),
#   ('gi-na', 'O'),
#   ('lugal-hi-li', 'PN'),
#   ('su-su-dam', 'O')],
#  [('hu-ri-la', 'PN')],
#  [('1(barig)', 'O'), ('sze-ba', 'O'), ('mu-tum-dingir', 'PN')],
#  [('iti', 'O'),
#   ('sze-kar-ra-gal2', 'MN'),
#   ('u4', 'O'),
#   ('2(u)', 'O'),
#   ('1(disz)-kam', 'O')],
#  [('1(disz)', 'O'),
#   ('ha-i3-li2', 'PN'),
#   ('dumu', 'O'),
#   ('lugal-szuku', 'PN'),
#   ('za-ga-la2', 'PN')],
#  [('szuku', 'O'),
#   ('lugal-mas-su2', 'PN'),
#   ('u3', 'O'),
#   ('ab-ba-gi-na', 'PN'),
#   ('ka-tar', 'PN')],
#  [('giri3', 'O'), ('{d}nanna-ma-ba', 'PN'), ('dub-sar', 'O')],
#  [('3(disz)', 'O'), ('nin-a-zu', 'PN')],
#  [('u3', 'O'), ('ur-{d}lugal-ban3-da', 'PN')],
#  [('7(disz)', 'O'), ('sar', 'O'), ('kab2-ku5', 'O'), ('e2-{d}inanna', 'FN')],
#  [('1(disz)', 'O'),
#   ('gukkal', 'O'),
#   ('niga', 'O'),
#   ('4(disz)-kam', 'O'),
#   ('us2', 'O')],
#  [('ki', 'O'), ('amar-e2-gibil', 'PN'), ('ba-zi', 'O')],
#  [('a-sza3', 'O'), ('e2-u3-ne', 'FN')],
#  [('a-sza3', 'O'), ('|NUNUZ.(KISIM5xGAG)|-{d}inanna', 'FN')],
#  [('1(asz)', 'O'), ('3(barig)', 'O'), ('gur', 'O'), ('lugal-uri2', 'PN')],
#  [('mu', 'O'), ('ama-nig2-kam', 'PN')],
#  [('kiszib3', 'O'), ('ARAD2-re-szum', 'PN')],
#  [('ku3-bi', 'O'), ('igi-6(disz)-gal2', 'O'), ('1(u)', 'O'), ('sze', 'O')],
#  [('kab2-ku5', 'O'), ('x-...-ga', 'FN')],
#  [('8(disz)', 'O'), ('gurusz', 'O'), ('ugula', 'O'), ('bu3-bu3-ga2', 'PN')],
#  [('1(disz)', 'O'), ('nun-ak-ak', 'PN')],
#  [('lu2-{d}nin-bar', 'PN')],
#  ...]

# %%
def features(sentence,index):
    ### sentence is of the form [w1,w2,w3,..], index is the position of the word in the sentence
    
    #Dictionary of features
    d={}
    
    word = sentence[index]
    left = ""
    right = ""
    if (index!=0):
        left=sentence[index-1]
    if (index!=len(sentence)-1):
        right=sentence[index+1]
        
    
    ###### ------- Rules/Features to Identify POS Tags  -------#######
    
    d['Is_first_word'] = 1 if index==0 else 0

    d['Is_last_word'] = 1 if index==len(sentence)-1 else 0

    d['previous_word'] = "" if left=="" else left

    d['next_word'] = "" if right=="" else right

    d['distorted_word_1'] = 1 if re.search(r'x',word) else 0

    d['distorted_word_2'] = 1 if re.search(r'\.\.\.',sentence[index]) else 0

    d['Is_number_form_1'] = 1 if re.search(r'\d+\(\.+\)',word) else 0
        
    d['Is_child_left'] = 1 if left=='dumu' else 0
    
    d['Is_child_right'] = 1 if right=='dumu' else 0
    
    d['Is_place'] = 1 if left=='ki' or right=='ki' else 0
    
    d['Is_witness_1'] = 1 if left=='igi' or right=='igi' else 0
    
    d['Is_witness_2'] = 1 if left=='igi' or right=='igi' and word.endswith('sze3') else 0
    
    d['Is_selling_tablet'] = 1 if left=='kiszib3' or right=='kiszib3' else 0
    
    d['Is_behalf_business'] = 1 if left=='giri3' or right=='giri3' else 0
    
    d['Is_selling_tablet'] = 1 if left=='kiszib3' or right=='kiszib3' else 0
    
    d['Is_selling_tablet'] = 1 if left=='kiszib3' or right=='kiszib3' else 0
    
    d['Is_PN_1'] = 1 if word.startswith('ur-') else 0
    
    d['Is_PN_2'] = 1 if word.startswith('lu2-') else 0
    
    d['Is_PN_3'] = 1 if word.endswith('-mu') else 0
    
    d['Is_PN_4'] = 1 if re.search(r'{d}',word) else 0
    
    d['Is_SN'] = 1 if re.search(r'{ki}',word) else 0
    
    d['Is_determinative'] = 1 if re.search(r'{',word) else 0
    
    d['Is_PN_5'] = 1 if re.search(r'lugal',word) else 0
    
    d['contains_numer'] = 1 if re.search(r'\d',word) else 0
    
    d['Is_PN_6'] = 1 if right=='sag' else 0
    
    d['Is_PN_7'] = 1 if right=='zarin' else 0
    
    d['Is_quantity'] = 1 if re.search(r'\d+\(\w+\)',left) else 0
    
    d['Is_month'] = 1 if left=='iti' else 0
    
    d['Is_mont_year'] = 1 if word=='iti' or word=='mu' else 0
    
    d['Is_PN_8'] = 1 if word[0].isupper() else 0
    
    d['Is_PN_9'] = 1 if word.startswith('{d}') else 0
    
    d['Is_hyphen'] = 1 if re.search(r'-',word) else 0
    
    d['prefix_1'] = word[0]
    
    d['prefix_2'] = word[:2]
    
    d['prefix_3'] = word[:3]
    
    d['prefix_4'] = word[:4]
    
    d['suffix_1'] = word[-1]
    
    d['suffix_2'] = word[-2:]
    
    d['suffix_3'] = word[-3:]
    
    d['suffix_4'] = word[-4:]
    
    return d

# %%
def word_list(sentence):
    list_of_words=[]
    for word,tag in sentence:
        list_of_words.append(word)
    return list_of_words

def prepareData(tagged_sentences):
    X,y=[],[]
    for sentence in tagged_sentences:
        single_sentence_feature=[]
        
        # Preparing features of all words of a single sentence/phrase
        for i in range(len(sentence)):
            #word list of sentence
            list_of_words=word_list(sentence)
            #feature of word at index i
            d=features(list_of_words,i)
            single_sentence_feature.append(d)
            
        X.append(single_sentence_feature)
        # append list of tags for the associated sentence
        y.append([tag for word,tag in sentence])
    return X,y

# %%
X_train,y_train=prepareData(train_set)
X_test,y_test=prepareData(test_set)

# %%
X_train[2]
# Out:
# [{'Is_first_word': 1,
#   'Is_last_word': 0,
#   'previous_word': '',
#   'next_word': 'tir-kak-du6-da',
#   'distorted_word_1': 0,
#   'distorted_word_2': 0,
#   'Is_number_form_1': 0,
#   'Is_child_left': 0,
#   'Is_child_right': 0,
#   'Is_place': 0,
#   'Is_witness_1': 0,
#   'Is_witness_2': 0,
#   'Is_selling_tablet': 0,
#   'Is_behalf_business': 0,
#   'Is_PN_1': 0,
#   'Is_PN_2': 0,
#   'Is_PN_3': 0,
#   'Is_PN_4': 0,
#   'Is_SN': 0,
#   'Is_determinative': 0,
#   'Is_PN_5': 0,
#   'contains_numer': 1,
#   'Is_PN_6': 0,
#   'Is_PN_7': 0,
#   'Is_quantity': 0,
#   'Is_month': 0,
#   'Is_mont_year': 0,
#   'Is_PN_8': 0,
#   'Is_PN_9': 0,
#   'Is_hyphen': 0,
#   'prefix_1': 'k',
#   'prefix_2': 'ki',
#   'prefix_3': 'kis',
#   'prefix_4': 'kisz',
#   'suffix_1': '3',
#   'suffix_2': 'b3',
#   'suffix_3': 'ib3',
#   'suffix_4': 'zib3'},
#  {'Is_first_word': 0,
#   'Is_last_word': 1,
#   'previous_word': 'kiszib3',
#   'next_word': '',
#   'distorted_word_1': 0,
#   'distorted_word_2': 0,
#   'Is_number_form_1': 0,
#   'Is_child_left': 0,
#   'Is_child_right': 0,
#   'Is_place': 0,
#   'Is_witness_1': 0,
#   'Is_witness_2': 0,
#   'Is_selling_tablet': 1,
#   'Is_behalf_business': 0,
#   'Is_PN_1': 0,
#   'Is_PN_2': 0,
#   'Is_PN_3': 0,
#   'Is_PN_4': 0,
#   'Is_SN': 0,
#   'Is_determinative': 0,
#   'Is_PN_5': 0,
#   'contains_numer': 1,
#   'Is_PN_6': 0,
#   'Is_PN_7': 0,
#   'Is_quantity': 0,
#   'Is_month': 0,
#   'Is_mont_year': 0,
#   'Is_PN_8': 0,
#   'Is_PN_9': 0,
#   'Is_hyphen': 1,
#   'prefix_1': 't',
#   'prefix_2': 'ti',
#   'prefix_3': 'tir',
#   'prefix_4': 'tir-',
#   'suffix_1': 'a',
#   'suffix_2': 'da',
#   'suffix_3': '-da',
#   'suffix_4': '6-da'}]

# %%
y_train
# Out:
# [['O', 'O', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN', 'O', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O'],
#  ['PN'],
#  ['PN', 'O'],
#  ['O', 'O'],
#  ['O', 'FN', 'O'],
#  ['O', 'PN'],
#  ['O', 'SN'],
#  ['PN'],
#  ['PN', 'O'],
#  ['PN', 'O'],
#  ['DN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'PN', 'EN'],
#  ['PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'GN', 'O'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'DN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN', 'GN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'DN'],
#  ['PN', 'GN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'SN', 'O'],
#  ['O', 'O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['FN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'PN', 'O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'FN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'RN', 'SN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'O'],
#  ['FN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['DN'],
#  ['O', 'PN'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'PN', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'DN'],
#  ['PN'],
#  ['O', 'O', 'FN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'MN'],
#  ['O', 'FN', 'O'],
#  ['O', 'FN'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'WN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'FN', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['PN', 'O'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'WN'],
#  ['PN'],
#  ['O', 'GN', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'PN'],
#  ['PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'GN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN', 'SN'],
#  ['O', 'O', 'FN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['PN', 'O'],
#  ['O', 'O', 'O', 'DN', 'PN', 'DN'],
#  ['O', 'PN'],
#  ['O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN', 'DN', 'SN', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['PN', 'O', 'O'],
#  ['O', 'DN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O'],
#  ['PN', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'DN', 'SN', 'O'],
#  ['PN', 'EN'],
#  ['O', 'O', 'O'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'GN', 'O'],
#  ['O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'GN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['PN', 'O'],
#  ['O', 'O', 'O', 'FN'],
#  ['SN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'GN', 'GN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN', 'O', 'PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'DN'],
#  ['O', 'RN', 'O', 'SN', 'O', 'DN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'SN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN', 'O', 'RN', 'SN', 'O'],
#  ['O', 'FN'],
#  ['O', 'O', 'GN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'GN', 'O'],
#  ['O', 'O', 'O', 'FN'],
#  ['FN', 'SN'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'SN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'FN'],
#  ['PN'],
#  ['O', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['FN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O'],
#  ['PN', 'O'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN', 'O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['GN', 'O', 'SN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'DN', 'PN', 'DN'],
#  ['PN'],
#  ['O', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O'],
#  ['O', 'PN'],
#  ['O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'RN', 'O', 'O', 'O'],
#  ['O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['PN'],
#  ['PN', 'O'],
#  ['O', 'O', 'O', 'WN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'PN', 'O', 'PN', 'O', 'PN', 'O'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['PN'],
#  ['O', 'O', 'O'],
#  ['O', 'DN'],
#  ['PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['O', 'FN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['PN', 'O'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'FN', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'GN', 'GN'],
#  ['PN'],
#  ['O', 'O', 'GN', 'O'],
#  ['GN', 'O', 'SN', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'FN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'SN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'RN', 'O', 'SN', 'O', 'DN', 'DN', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'GN', 'O'],
#  ['EN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['FN', 'SN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'DN'],
#  ['O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'GN', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O', 'PN', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'GN', 'GN'],
#  ['O', 'O', 'O', 'FN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'FN'],
#  ['O', 'PN'],
#  ['PN', 'GN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'FN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'DN', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'GN', 'GN'],
#  ['SN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'GN'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'DN', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'DN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O'],
#  ['O', 'FN'],
#  ['O', 'SN', 'O'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'SN', 'SN', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'FN'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O', 'PN', 'O', 'PN'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'FN'],
#  ['PN', 'O'],
#  ['O', 'O', 'O', 'DN'],
#  ['O', 'PN', 'O'],
#  ['DN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['O', 'PN', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'GN', 'O'],
#  ['PN'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'GN', 'GN'],
#  ['O', 'DN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'O', 'PN', 'O', 'PN'],
#  ['PN', 'O', 'O', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['PN', 'O', 'O'],
#  ['PN', 'O', 'O'],
#  ['GN'],
#  ['O', 'GN', 'O'],
#  ['O', 'ON', 'DN', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN', 'O'],
#  ['O', 'FN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['GN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['PN', 'O'],
#  ['PN'],
#  ['DN'],
#  ['O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'FN'],
#  ['O', 'O', 'WN'],
#  ['PN'],
#  ['O', 'O'],
#  ['PN'],
#  ['PN', 'SN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'FN', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'DN'],
#  ['O', 'PN', 'O'],
#  ['O', 'GN', 'O'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'O', 'O', 'O', 'FN'],
#  ['O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'DN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'RN', 'O', 'SN', 'O', 'DN', 'DN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'GN', 'O'],
#  ['PN', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'WN'],
#  ['O', 'O', 'O', 'O', 'DN'],
#  ['O', 'O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'DN', 'O'],
#  ['O', 'FN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'O', 'WN'],
#  ['O', 'O', 'PN', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['PN', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['O', 'GN', 'GN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'GN', 'GN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'FN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN', 'O', 'O'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'GN', 'GN'],
#  ['PN', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'FN', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'GN', 'GN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'MN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'WN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'GN', 'O'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'PN', 'O', 'PN', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'RN', 'O', 'SN', 'O', 'EN', 'ON', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'DN'],
#  ['O', 'O', 'O', 'WN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O', 'DN'],
#  ['O', 'GN', 'GN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'DN'],
#  ['O', 'O', 'SN', 'O'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'PN', 'O', 'PN', 'PN'],
#  ['O', 'GN', 'GN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'SN', 'O', 'SN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['O', 'MN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'GN', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'GN', 'GN'],
#  ['PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'O'],
#  ['O', 'FN', 'O', 'O', 'O', 'WN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN', 'PN'],
#  ['PN', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['PN', 'O'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'FN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'GN', 'O'],
#  ['PN', 'O'],
#  ['O', 'FN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['FN', 'O'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'GN', 'GN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'PN', 'O', 'PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['PN', 'O'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'FN', 'O'],
#  ['O', 'O', 'O', 'PN', 'O'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'SN'],
#  ['PN'],
#  ...]

# %%
crf = CRF(
    algorithm='lbfgs',
    c1=0.01,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# /home/himanshu/.local/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.01, c2=0.1,
#     keep_tempfiles=None, max_iterations=100)

# %% [markdown]
# # Predicting Our 1.5M Data

# %%
import pickle

# %%
# Save the Modle to file in the current working directory
Pkl_Filename = "../Dataset/NER_CRF_Model.pkl"  
with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(crf, file)

# %%
Pkl_Filename = "../Saved_Models/NER_CRF_Model.pkl" 
with open(Pkl_Filename, 'rb') as file:  
    crf = pickle.load(file)
crf
# Out:
# /home/himanshu/.local/lib/python3.8/site-packages/sklearn/base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.01, c2=0.1,
#     keep_tempfiles=None, max_iterations=100)

# %%
Monolingual_sumerian=[]
with open('../Dataset/sumerian_demo.txt') as f:
    for line in f:
        line=line.strip()
        Monolingual_sumerian.append(line)

# %%
Monolingual_sumerian
# Out:
# ['sag-ki hu-mu-ra-ab-zalag-ge',
#  'ki na-sa6-ta',
#  'iti szu-numun-ta',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  'ba-de6',
#  'mu us2-sa ki-masz{ki} ba-hul',
#  '1(asz) gu4 ab2',
#  '1(barig) 1(ban2) 5(disz) 1(disz) 1/2(disz) geme2-{d}szul-pa-e3 dumu-ni',
#  '1(asz) 2(ban2) nam-nin-...',
#  'dumu ur-{d}nansze',
#  'gu4 udu niga u2-sa',
#  'e2 kiszib3-ba-kam',
#  '1(disz) du-du-am3 u3 lugal-ba-tuku',
#  '{d}nin-sun2',
#  'nig2-du7-e pa mu-na-e3',
#  '2(ban2) ...',
#  'dub-sar',
#  '1(disz) {munus}asz2-gar3',
#  '8(disz) sila3 4(disz) gin2 tab-be-li2 u3 dan-num2',
#  'dumu lu2-ga',
#  'ur-kalam na-gada i3-dab5',
#  '1(disz) munu4 si-e3',
#  '1(u) 2(disz) gaszam',
#  '2(gesz2) 3(u) 7(disz) udu 1(disz) sila3',
#  'dub-sar',
#  '5(disz) 1/2(disz) ma-na 5(disz) gin2 siki tug2 guz-za 3(disz)-kam us2',
#  '5(ban2) 1(u) ba-at-ri',
#  '2(disz) sila3 nig2-ar3-ra saga',
#  '4(u) ka-dug ku3-babbar',
#  'e2-masz-sze3',
#  'ur-ma-ma lu2 bu3',
#  'iti pa4-u2-e',
#  'szunigin 1(disz) la2-ia3',
#  '4(ban2) nin-tesz2-mu',
#  '1(disz) szul-lu5 nu-{gesz}kiri6',
#  'n gu2 siki tug2 guz-za du',
#  '... nin-a-zu',
#  'szunigin 7(disz) gu4 mu 2(disz)',
#  '{d}inanna',
#  'dumu ur-e2-ninnu',
#  '1(disz) i3-li2-an-dul3',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  '1(barig) ama-na',
#  'szunigin 8(disz) dumu 1(ban2) 5(disz) sila3-ta',
#  'din |SZE.NUN&NUN|{+i-ti-sze-x}',
#  'iti ezem-{d}dumu-zi',
#  'szu ba-an-ti',
#  'du11-ga-ni si bi2-sa2',
#  '1(u) 8(disz) gurusz gub-ba la2-ia3 1(u) 5(disz)',
#  'kasz-de2-a ur-{d}iszkur ensi2 ha-ma-zi2{ki}',
#  'mu-na-ba-al',
#  'lu2-kal-la',
#  'sza3-ge engar',
#  '4(barig) ama-masz-min3',
#  'lugal an-ub-da limmu2-ba',
#  'szunigin 3(gesz2) 4(asz) 3(barig) 2(ban2) gur',
#  '5(asz) zi3',
#  '2(disz) sila3 ur3-re-ba-du7',
#  'ki e2 {d}nanna',
#  '1(asz) us2 e2-engur-ka',
#  'bahar3-e-ne szu ba-ab-ti',
#  'mu us2-sa bad3 ma-da ba-du3',
#  '... gur',
#  'ur-e2-an-na',
#  '5(disz) gu2 {u2}nin9',
#  '1(u) 2(asz) ur-gu-la',
#  'dub-sar',
#  'iti GAN2-masz',
#  'dumu nin-iri-ni-sze3',
#  'sza13-dub-ba-ka',
#  'dumu ba-zi',
#  'mu ur-bi2-lum{ki} ba-hul-sze3',
#  'lagasz{ki}-ke4',
#  'ki-la2-bi 2(asz) gu2 2(u) 4(disz) ma-na',
#  'sa2-du11 {d}nin-sun2',
#  'diri x tug2 guz-za x',
#  '1(disz) udu',
#  'szunigin 4(bur3) n GAN2',
#  'tug2 ki-la2 tag-ga',
#  'mu ma-da za-ab-sza-li{ki} ba-hul',
#  'giri3 ri-ib-hu-ti',
#  'mu en ga-esz5{ki}',
#  'iti diri me-ki-gal2 u2-sa',
#  '1(disz) udu niga 4(disz)-kam us2',
#  'szesz-da-da sanga',
#  'x x-na-sze3 ba-ra-da-du-de3-en',
#  '1(asz) geme2 3(ban2)',
#  'lugal uri5{ki}-ma',
#  '2(ban2) ga-ar3',
#  '{d}gesztin-an-na',
#  '{d}szul-gi',
#  '4(disz)',
#  'szunigin 2(asz) 3(ban2) nig2-ar3-ra saga gur',
#  'ki szu-{d}nin-kar-ak-ta',
#  '1(disz) kusz udu a-gar gu7-a',
#  'ki {d}iszkur-illat-ta',
#  'ugula ur-{d}nin-su',
#  'kiszib3 ur-{d}nun-gal',
#  'ganun ka i7 tum-al-ta',
#  '1(gesz2) 3(u) 3(asz) gesztin gal-gal',
#  '1(asz) kinda',
#  '2(u) 3(ban2) gur 5(disz) sila3 sze du',
#  'dab6-ru-um{ki}-ma ba-an-sa6',
#  'u3 gag',
#  '5(asz) 3(barig) 2(ban2) ur-{d}ba-ba6 dumu ur-nig2',
#  'dumu lugal-{gesz}kiri6',
#  '1(disz) sila4 kiszib3 ur-{d}en-ki kuruszda',
#  'dumu-munus-a-ni',
#  'an-na-ag2',
#  'iti nesag',
#  'naga-bi 1(barig) 1(ban2) 1/2(disz) sila3',
#  'giri3 lu2-{d}nanna dumu ba-ba',
#  'iti ezem-{d}...',
#  'szu-{d}suen',
#  'zi-ga',
#  'RU-lugal-me',
#  'mu mu-na-sa4',
#  'ka ba-ab-kesz2',
#  'mar-sa-asz mu-kux(DU)',
#  'u4 1(u) 3(disz)-sze3 ka-sahar-ta',
#  '2(asz) MI-si4-ad',
#  'mu ki-masz{ki} u3 hu-ur5-ti{ki} ba-hul',
#  '1(esze3) 4(iku)',
#  '5(asz) sze gur lugal',
#  '1/3(disz) ma-na x gin2 ku3 sze x x',
#  'baharx(EDIN)-ri',
#  'iti 1(disz)-kam',
#  '6(disz) 1/2(disz) gin2 6(disz) sze ku3',
#  'iti {d}dumu-zi-sze3',
#  'ugula ur-mes',
#  '{d}nin-gir2-su',
#  'gesztu2 dagal nig2-nam gal-le-esz zu',
#  'gu-nigin2-bi 7(gesz2) 2(u) 7(disz) 5/6(disz)',
#  'an-nu-ni-tum',
#  '2(u) {uruda}gur10 a-ra2 2(disz)-kam',
#  'ka-ma-ri2{ki}-ta',
#  '2(bur3) 1(esze3) la2 1/2(iku)',
#  'udu 1(asz)-sze3',
#  '1(disz) a-kal-la dumu e2-an-ne2',
#  'sipa gu4 niga',
#  '1(barig) e2-ki-bi',
#  'sa2-du11 ki-a-nag sza3-ba-na-sig szabra',
#  'gaba-ri',
#  'giri3 a-gu-a-ni dub-sar',
#  '1(gesz2) 1(u) 1(disz) x gur',
#  '1(asz) udu {d}en-...',
#  '1(asz) ni-ni',
#  'lu2-kal-la',
#  'e2-muhaldim-sze3',
#  'szunigin 4(asz) ansze ...']

# %%
def test_word_list(sentence):
    list_of_words=sentence.split()
    return list_of_words

def prepare_test_Data(all_sentences):
    X=[]
    for sentence in all_sentences:
        single_sentence_feature=[]
        #word list of sentence
        print(sentence)
        list_of_words=test_word_list(sentence)
        # Preparing features of all words of a single sentence/phrase
        for i in range(len(sentence.split())):
            #feature of word at index i
            d=features(list_of_words,i)
            single_sentence_feature.append(d)
            
        X.append(single_sentence_feature)
        
    return X

# %%
Processed_sumerian_monolingual=prepare_test_Data(Monolingual_sumerian)
# Out:
# sag-ki hu-mu-ra-ab-zalag-ge
# ki na-sa6-ta
# iti szu-numun-ta
# 3(disz) gin2 i3 2(disz) gin2 naga
# ba-de6
# mu us2-sa ki-masz{ki} ba-hul
# 1(asz) gu4 ab2
# 1(barig) 1(ban2) 5(disz) 1(disz) 1/2(disz) geme2-{d}szul-pa-e3 dumu-ni
# 1(asz) 2(ban2) nam-nin-...
# dumu ur-{d}nansze
# gu4 udu niga u2-sa
# e2 kiszib3-ba-kam
# 1(disz) du-du-am3 u3 lugal-ba-tuku
# {d}nin-sun2
# nig2-du7-e pa mu-na-e3
# 2(ban2) ...
# dub-sar
# 1(disz) {munus}asz2-gar3
# 8(disz) sila3 4(disz) gin2 tab-be-li2 u3 dan-num2
# dumu lu2-ga
# ur-kalam na-gada i3-dab5
# 1(disz) munu4 si-e3
# 1(u) 2(disz) gaszam
# 2(gesz2) 3(u) 7(disz) udu 1(disz) sila3
# dub-sar
# 5(disz) 1/2(disz) ma-na 5(disz) gin2 siki tug2 guz-za 3(disz)-kam us2
# 5(ban2) 1(u) ba-at-ri
# 2(disz) sila3 nig2-ar3-ra saga
# 4(u) ka-dug ku3-babbar
# e2-masz-sze3
# ur-ma-ma lu2 bu3
# iti pa4-u2-e
# szunigin 1(disz) la2-ia3
# 4(ban2) nin-tesz2-mu
# 1(disz) szul-lu5 nu-{gesz}kiri6
# n gu2 siki tug2 guz-za du
# ... nin-a-zu
# szunigin 7(disz) gu4 mu 2(disz)
# {d}inanna
# dumu ur-e2-ninnu
# 1(disz) i3-li2-an-dul3
# 3(disz) gin2 i3 2(disz) gin2 naga
# 1(barig) ama-na
# szunigin 8(disz) dumu 1(ban2) 5(disz) sila3-ta
# din |SZE.NUN&NUN|{+i-ti-sze-x}
# iti ezem-{d}dumu-zi
# szu ba-an-ti
# du11-ga-ni si bi2-sa2
# 1(u) 8(disz) gurusz gub-ba la2-ia3 1(u) 5(disz)
# kasz-de2-a ur-{d}iszkur ensi2 ha-ma-zi2{ki}
# mu-na-ba-al
# lu2-kal-la
# sza3-ge engar
# 4(barig) ama-masz-min3
# lugal an-ub-da limmu2-ba
# szunigin 3(gesz2) 4(asz) 3(barig) 2(ban2) gur
# 5(asz) zi3
# 2(disz) sila3 ur3-re-ba-du7
# ki e2 {d}nanna
# 1(asz) us2 e2-engur-ka
# bahar3-e-ne szu ba-ab-ti
# mu us2-sa bad3 ma-da ba-du3
# ... gur
# ur-e2-an-na
# 5(disz) gu2 {u2}nin9
# 1(u) 2(asz) ur-gu-la
# dub-sar
# iti GAN2-masz
# dumu nin-iri-ni-sze3
# sza13-dub-ba-ka
# dumu ba-zi
# mu ur-bi2-lum{ki} ba-hul-sze3
# lagasz{ki}-ke4
# ki-la2-bi 2(asz) gu2 2(u) 4(disz) ma-na
# sa2-du11 {d}nin-sun2
# diri x tug2 guz-za x
# 1(disz) udu
# szunigin 4(bur3) n GAN2
# tug2 ki-la2 tag-ga
# mu ma-da za-ab-sza-li{ki} ba-hul
# giri3 ri-ib-hu-ti
# mu en ga-esz5{ki}
# iti diri me-ki-gal2 u2-sa
# 1(disz) udu niga 4(disz)-kam us2
# szesz-da-da sanga
# x x-na-sze3 ba-ra-da-du-de3-en
# 1(asz) geme2 3(ban2)
# lugal uri5{ki}-ma
# 2(ban2) ga-ar3
# {d}gesztin-an-na
# {d}szul-gi
# 4(disz)
# szunigin 2(asz) 3(ban2) nig2-ar3-ra saga gur
# ki szu-{d}nin-kar-ak-ta
# 1(disz) kusz udu a-gar gu7-a
# ki {d}iszkur-illat-ta
# ugula ur-{d}nin-su
# kiszib3 ur-{d}nun-gal
# ganun ka i7 tum-al-ta
# 1(gesz2) 3(u) 3(asz) gesztin gal-gal
# 1(asz) kinda
# 2(u) 3(ban2) gur 5(disz) sila3 sze du
# dab6-ru-um{ki}-ma ba-an-sa6
# u3 gag
# 5(asz) 3(barig) 2(ban2) ur-{d}ba-ba6 dumu ur-nig2
# dumu lugal-{gesz}kiri6
# 1(disz) sila4 kiszib3 ur-{d}en-ki kuruszda
# dumu-munus-a-ni
# an-na-ag2
# iti nesag
# naga-bi 1(barig) 1(ban2) 1/2(disz) sila3
# giri3 lu2-{d}nanna dumu ba-ba
# iti ezem-{d}...
# szu-{d}suen
# zi-ga
# RU-lugal-me
# mu mu-na-sa4
# ka ba-ab-kesz2
# mar-sa-asz mu-kux(DU)
# u4 1(u) 3(disz)-sze3 ka-sahar-ta
# 2(asz) MI-si4-ad
# mu ki-masz{ki} u3 hu-ur5-ti{ki} ba-hul
# 1(esze3) 4(iku)
# 5(asz) sze gur lugal
# 1/3(disz) ma-na x gin2 ku3 sze x x
# baharx(EDIN)-ri
# iti 1(disz)-kam
# 6(disz) 1/2(disz) gin2 6(disz) sze ku3
# iti {d}dumu-zi-sze3
# ugula ur-mes
# {d}nin-gir2-su
# gesztu2 dagal nig2-nam gal-le-esz zu
# gu-nigin2-bi 7(gesz2) 2(u) 7(disz) 5/6(disz)
# an-nu-ni-tum
# 2(u) {uruda}gur10 a-ra2 2(disz)-kam
# ka-ma-ri2{ki}-ta
# 2(bur3) 1(esze3) la2 1/2(iku)
# udu 1(asz)-sze3
# 1(disz) a-kal-la dumu e2-an-ne2
# sipa gu4 niga
# 1(barig) e2-ki-bi
# sa2-du11 ki-a-nag sza3-ba-na-sig szabra
# gaba-ri
# giri3 a-gu-a-ni dub-sar
# 1(gesz2) 1(u) 1(disz) x gur
# 1(asz) udu {d}en-...
# 1(asz) ni-ni
# lu2-kal-la
# e2-muhaldim-sze3
# szunigin 4(asz) ansze ...

# %%
Prediction=crf.predict(Processed_sumerian_monolingual)

# %%
with open('../Output/Sumerian_NER_CRF.txt', 'w') as f:
    for i in range(len(my_list)):
        f.write("%s\n" %str(i+1))
        sentence="sentence: "+Monolingual_sumerian[i]
        f.write("%s\n" %sentence)
        f.write("POS:%s\n\n" % my_list[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-e399975b5c53> in <module>
#       1 with open('../Output/Sumerian_NER_CRF.txt', 'w') as f:
# ----> 2     for i in range(len(my_list)):
#       3         f.write("%s\n" %str(i+1))
#       4         sentence="sentence: "+Monolingual_sumerian[i]
#       5         f.write("%s\n" %sentence)
#
# NameError: name 'my_list' is not defined

# %%
my_list=[]
for i in range(len(Monolingual_sumerian)):
    print(i+1)
    print("sentence: "+Monolingual_sumerian[i])
    l=Monolingual_sumerian[i].split()
    POS=""
    for j in range(len(l)):
        POS=POS+"("+l[j]+","+Prediction[i][j]+")"+" "
    print('POS:'+POS)
    my_list.append(POS)
    print()
# Out:
# 1
# sentence: sag-ki hu-mu-ra-ab-zalag-ge
# POS:(sag-ki,GN) (hu-mu-ra-ab-zalag-ge,GN)
#
# 2
# sentence: ki na-sa6-ta
# POS:(ki,O) (na-sa6-ta,PN)
#
# 3
# sentence: iti szu-numun-ta
# POS:(iti,PN) (szu-numun-ta,MN)
#
# 4
# sentence: 3(disz) gin2 i3 2(disz) gin2 naga
# POS:(3(disz),O) (gin2,PN) (i3,PN) (2(disz),O) (gin2,PN) (naga,PN)
#
# 5
# sentence: ba-de6
# POS:(ba-de6,PN)
#
# 6
# sentence: mu us2-sa ki-masz{ki} ba-hul
# POS:(mu,GN) (us2-sa,GN) (ki-masz{ki},GN) (ba-hul,O)
#
# 7
# sentence: 1(asz) gu4 ab2
# POS:(1(asz),O) (gu4,O) (ab2,PN)
#
# 8
# sentence: 1(barig) 1(ban2) 5(disz) 1(disz) 1/2(disz) geme2-{d}szul-pa-e3 dumu-ni
# POS:(1(barig),O) (1(ban2),O) (5(disz),O) (1(disz),O) (1/2(disz),O) (geme2-{d}szul-pa-e3,PN) (dumu-ni,DN)
#
# 9
# sentence: 1(asz) 2(ban2) nam-nin-...
# POS:(1(asz),O) (2(ban2),O) (nam-nin-...,PN)
#
# 10
# sentence: dumu ur-{d}nansze
# POS:(dumu,DN) (ur-{d}nansze,PN)
#
# 11
# sentence: gu4 udu niga u2-sa
# POS:(gu4,GN) (udu,GN) (niga,GN) (u2-sa,GN)
#
# 12
# sentence: e2 kiszib3-ba-kam
# POS:(e2,PN) (kiszib3-ba-kam,DN)
#
# 13
# sentence: 1(disz) du-du-am3 u3 lugal-ba-tuku
# POS:(1(disz),O) (du-du-am3,PN) (u3,O) (lugal-ba-tuku,PN)
#
# 14
# sentence: {d}nin-sun2
# POS:({d}nin-sun2,DN)
#
# 15
# sentence: nig2-du7-e pa mu-na-e3
# POS:(nig2-du7-e,PN) (pa,GN) (mu-na-e3,GN)
#
# 16
# sentence: 2(ban2) ...
# POS:(2(ban2),O) (...,PN)
#
# 17
# sentence: dub-sar
# POS:(dub-sar,TN)
#
# 18
# sentence: 1(disz) {munus}asz2-gar3
# POS:(1(disz),O) ({munus}asz2-gar3,PN)
#
# 19
# sentence: 8(disz) sila3 4(disz) gin2 tab-be-li2 u3 dan-num2
# POS:(8(disz),O) (sila3,O) (4(disz),O) (gin2,PN) (tab-be-li2,PN) (u3,O) (dan-num2,PN)
#
# 20
# sentence: dumu lu2-ga
# POS:(dumu,DN) (lu2-ga,PN)
#
# 21
# sentence: ur-kalam na-gada i3-dab5
# POS:(ur-kalam,PN) (na-gada,PN) (i3-dab5,PN)
#
# 22
# sentence: 1(disz) munu4 si-e3
# POS:(1(disz),O) (munu4,PN) (si-e3,PN)
#
# 23
# sentence: 1(u) 2(disz) gaszam
# POS:(1(u),O) (2(disz),O) (gaszam,PN)
#
# 24
# sentence: 2(gesz2) 3(u) 7(disz) udu 1(disz) sila3
# POS:(2(gesz2),O) (3(u),O) (7(disz),O) (udu,O) (1(disz),O) (sila3,PN)
#
# 25
# sentence: dub-sar
# POS:(dub-sar,TN)
#
# 26
# sentence: 5(disz) 1/2(disz) ma-na 5(disz) gin2 siki tug2 guz-za 3(disz)-kam us2
# POS:(5(disz),O) (1/2(disz),O) (ma-na,PN) (5(disz),O) (gin2,PN) (siki,GN) (tug2,GN) (guz-za,GN) (3(disz)-kam,GN) (us2,GN)
#
# 27
# sentence: 5(ban2) 1(u) ba-at-ri
# POS:(5(ban2),O) (1(u),O) (ba-at-ri,PN)
#
# 28
# sentence: 2(disz) sila3 nig2-ar3-ra saga
# POS:(2(disz),O) (sila3,PN) (nig2-ar3-ra,PN) (saga,DN)
#
# 29
# sentence: 4(u) ka-dug ku3-babbar
# POS:(4(u),O) (ka-dug,FN) (ku3-babbar,TN)
#
# 30
# sentence: e2-masz-sze3
# POS:(e2-masz-sze3,TN)
#
# 31
# sentence: ur-ma-ma lu2 bu3
# POS:(ur-ma-ma,PN) (lu2,PN) (bu3,PN)
#
# 32
# sentence: iti pa4-u2-e
# POS:(iti,PN) (pa4-u2-e,MN)
#
# 33
# sentence: szunigin 1(disz) la2-ia3
# POS:(szunigin,O) (1(disz),O) (la2-ia3,PN)
#
# 34
# sentence: 4(ban2) nin-tesz2-mu
# POS:(4(ban2),O) (nin-tesz2-mu,PN)
#
# 35
# sentence: 1(disz) szul-lu5 nu-{gesz}kiri6
# POS:(1(disz),O) (szul-lu5,PN) (nu-{gesz}kiri6,PN)
#
# 36
# sentence: n gu2 siki tug2 guz-za du
# POS:(n,GN) (gu2,GN) (siki,GN) (tug2,GN) (guz-za,GN) (du,GN)
#
# 37
# sentence: ... nin-a-zu
# POS:(...,PN) (nin-a-zu,DN)
#
# 38
# sentence: szunigin 7(disz) gu4 mu 2(disz)
# POS:(szunigin,GN) (7(disz),GN) (gu4,GN) (mu,GN) (2(disz),GN)
#
# 39
# sentence: {d}inanna
# POS:({d}inanna,DN)
#
# 40
# sentence: dumu ur-e2-ninnu
# POS:(dumu,DN) (ur-e2-ninnu,PN)
#
# 41
# sentence: 1(disz) i3-li2-an-dul3
# POS:(1(disz),O) (i3-li2-an-dul3,PN)
#
# 42
# sentence: 3(disz) gin2 i3 2(disz) gin2 naga
# POS:(3(disz),O) (gin2,PN) (i3,PN) (2(disz),O) (gin2,PN) (naga,PN)
#
# 43
# sentence: 1(barig) ama-na
# POS:(1(barig),O) (ama-na,PN)
#
# 44
# sentence: szunigin 8(disz) dumu 1(ban2) 5(disz) sila3-ta
# POS:(szunigin,RN) (8(disz),ON) (dumu,DN) (1(ban2),PN) (5(disz),O) (sila3-ta,PN)
#
# 45
# sentence: din |SZE.NUN&NUN|{+i-ti-sze-x}
# POS:(din,GN) (|SZE.NUN&NUN|{+i-ti-sze-x},GN)
#
# 46
# sentence: iti ezem-{d}dumu-zi
# POS:(iti,PN) (ezem-{d}dumu-zi,MN)
#
# 47
# sentence: szu ba-an-ti
# POS:(szu,RN) (ba-an-ti,PN)
#
# 48
# sentence: du11-ga-ni si bi2-sa2
# POS:(du11-ga-ni,TN) (si,GN) (bi2-sa2,GN)
#
# 49
# sentence: 1(u) 8(disz) gurusz gub-ba la2-ia3 1(u) 5(disz)
# POS:(1(u),O) (8(disz),O) (gurusz,FN) (gub-ba,SN) (la2-ia3,O) (1(u),O) (5(disz),O)
#
# 50
# sentence: kasz-de2-a ur-{d}iszkur ensi2 ha-ma-zi2{ki}
# POS:(kasz-de2-a,PN) (ur-{d}iszkur,PN) (ensi2,DN) (ha-ma-zi2{ki},SN)
#
# 51
# sentence: mu-na-ba-al
# POS:(mu-na-ba-al,PN)
#
# 52
# sentence: lu2-kal-la
# POS:(lu2-kal-la,PN)
#
# 53
# sentence: sza3-ge engar
# POS:(sza3-ge,PN) (engar,PN)
#
# 54
# sentence: 4(barig) ama-masz-min3
# POS:(4(barig),O) (ama-masz-min3,PN)
#
# 55
# sentence: lugal an-ub-da limmu2-ba
# POS:(lugal,PN) (an-ub-da,GN) (limmu2-ba,GN)
#
# 56
# sentence: szunigin 3(gesz2) 4(asz) 3(barig) 2(ban2) gur
# POS:(szunigin,GN) (3(gesz2),GN) (4(asz),O) (3(barig),O) (2(ban2),O) (gur,PN)
#
# 57
# sentence: 5(asz) zi3
# POS:(5(asz),O) (zi3,PN)
#
# 58
# sentence: 2(disz) sila3 ur3-re-ba-du7
# POS:(2(disz),O) (sila3,PN) (ur3-re-ba-du7,PN)
#
# 59
# sentence: ki e2 {d}nanna
# POS:(ki,O) (e2,PN) ({d}nanna,DN)
#
# 60
# sentence: 1(asz) us2 e2-engur-ka
# POS:(1(asz),O) (us2,O) (e2-engur-ka,TN)
#
# 61
# sentence: bahar3-e-ne szu ba-ab-ti
# POS:(bahar3-e-ne,GN) (szu,GN) (ba-ab-ti,GN)
#
# 62
# sentence: mu us2-sa bad3 ma-da ba-du3
# POS:(mu,GN) (us2-sa,GN) (bad3,GN) (ma-da,GN) (ba-du3,GN)
#
# 63
# sentence: ... gur
# POS:(...,O) (gur,O)
#
# 64
# sentence: ur-e2-an-na
# POS:(ur-e2-an-na,PN)
#
# 65
# sentence: 5(disz) gu2 {u2}nin9
# POS:(5(disz),O) (gu2,O) ({u2}nin9,FN)
#
# 66
# sentence: 1(u) 2(asz) ur-gu-la
# POS:(1(u),O) (2(asz),O) (ur-gu-la,PN)
#
# 67
# sentence: dub-sar
# POS:(dub-sar,TN)
#
# 68
# sentence: iti GAN2-masz
# POS:(iti,PN) (GAN2-masz,MN)
#
# 69
# sentence: dumu nin-iri-ni-sze3
# POS:(dumu,DN) (nin-iri-ni-sze3,PN)
#
# 70
# sentence: sza13-dub-ba-ka
# POS:(sza13-dub-ba-ka,GN)
#
# 71
# sentence: dumu ba-zi
# POS:(dumu,DN) (ba-zi,PN)
#
# 72
# sentence: mu ur-bi2-lum{ki} ba-hul-sze3
# POS:(mu,FN) (ur-bi2-lum{ki},SN) (ba-hul-sze3,SN)
#
# 73
# sentence: lagasz{ki}-ke4
# POS:(lagasz{ki}-ke4,SN)
#
# 74
# sentence: ki-la2-bi 2(asz) gu2 2(u) 4(disz) ma-na
# POS:(ki-la2-bi,PN) (2(asz),O) (gu2,O) (2(u),O) (4(disz),O) (ma-na,PN)
#
# 75
# sentence: sa2-du11 {d}nin-sun2
# POS:(sa2-du11,PN) ({d}nin-sun2,DN)
#
# 76
# sentence: diri x tug2 guz-za x
# POS:(diri,GN) (x,GN) (tug2,GN) (guz-za,GN) (x,GN)
#
# 77
# sentence: 1(disz) udu
# POS:(1(disz),O) (udu,PN)
#
# 78
# sentence: szunigin 4(bur3) n GAN2
# POS:(szunigin,GN) (4(bur3),GN) (n,GN) (GAN2,GN)
#
# 79
# sentence: tug2 ki-la2 tag-ga
# POS:(tug2,GN) (ki-la2,GN) (tag-ga,GN)
#
# 80
# sentence: mu ma-da za-ab-sza-li{ki} ba-hul
# POS:(mu,GN) (ma-da,GN) (za-ab-sza-li{ki},GN) (ba-hul,GN)
#
# 81
# sentence: giri3 ri-ib-hu-ti
# POS:(giri3,PN) (ri-ib-hu-ti,PN)
#
# 82
# sentence: mu en ga-esz5{ki}
# POS:(mu,GN) (en,GN) (ga-esz5{ki},GN)
#
# 83
# sentence: iti diri me-ki-gal2 u2-sa
# POS:(iti,PN) (diri,MN) (me-ki-gal2,PN) (u2-sa,PN)
#
# 84
# sentence: 1(disz) udu niga 4(disz)-kam us2
# POS:(1(disz),O) (udu,PN) (niga,DN) (4(disz)-kam,O) (us2,O)
#
# 85
# sentence: szesz-da-da sanga
# POS:(szesz-da-da,PN) (sanga,DN)
#
# 86
# sentence: x x-na-sze3 ba-ra-da-du-de3-en
# POS:(x,DN) (x-na-sze3,SN) (ba-ra-da-du-de3-en,TN)
#
# 87
# sentence: 1(asz) geme2 3(ban2)
# POS:(1(asz),O) (geme2,PN) (3(ban2),O)
#
# 88
# sentence: lugal uri5{ki}-ma
# POS:(lugal,PN) (uri5{ki}-ma,GN)
#
# 89
# sentence: 2(ban2) ga-ar3
# POS:(2(ban2),O) (ga-ar3,PN)
#
# 90
# sentence: {d}gesztin-an-na
# POS:({d}gesztin-an-na,DN)
#
# 91
# sentence: {d}szul-gi
# POS:({d}szul-gi,RN)
#
# 92
# sentence: 4(disz)
# POS:(4(disz),O)
#
# 93
# sentence: szunigin 2(asz) 3(ban2) nig2-ar3-ra saga gur
# POS:(szunigin,O) (2(asz),O) (3(ban2),O) (nig2-ar3-ra,PN) (saga,DN) (gur,PN)
#
# 94
# sentence: ki szu-{d}nin-kar-ak-ta
# POS:(ki,O) (szu-{d}nin-kar-ak-ta,PN)
#
# 95
# sentence: 1(disz) kusz udu a-gar gu7-a
# POS:(1(disz),GN) (kusz,GN) (udu,GN) (a-gar,GN) (gu7-a,GN)
#
# 96
# sentence: ki {d}iszkur-illat-ta
# POS:(ki,O) ({d}iszkur-illat-ta,PN)
#
# 97
# sentence: ugula ur-{d}nin-su
# POS:(ugula,O) (ur-{d}nin-su,PN)
#
# 98
# sentence: kiszib3 ur-{d}nun-gal
# POS:(kiszib3,O) (ur-{d}nun-gal,PN)
#
# 99
# sentence: ganun ka i7 tum-al-ta
# POS:(ganun,GN) (ka,GN) (i7,WN) (tum-al-ta,SN)
#
# 100
# sentence: 1(gesz2) 3(u) 3(asz) gesztin gal-gal
# POS:(1(gesz2),O) (3(u),O) (3(asz),O) (gesztin,O) (gal-gal,PN)
#
# 101
# sentence: 1(asz) kinda
# POS:(1(asz),O) (kinda,PN)
#
# 102
# sentence: 2(u) 3(ban2) gur 5(disz) sila3 sze du
# POS:(2(u),O) (3(ban2),O) (gur,PN) (5(disz),O) (sila3,PN) (sze,PN) (du,FN)
#
# 103
# sentence: dab6-ru-um{ki}-ma ba-an-sa6
# POS:(dab6-ru-um{ki}-ma,GN) (ba-an-sa6,GN)
#
# 104
# sentence: u3 gag
# POS:(u3,O) (gag,DN)
#
# 105
# sentence: 5(asz) 3(barig) 2(ban2) ur-{d}ba-ba6 dumu ur-nig2
# POS:(5(asz),O) (3(barig),O) (2(ban2),O) (ur-{d}ba-ba6,PN) (dumu,DN) (ur-nig2,PN)
#
# 106
# sentence: dumu lugal-{gesz}kiri6
# POS:(dumu,DN) (lugal-{gesz}kiri6,PN)
#
# 107
# sentence: 1(disz) sila4 kiszib3 ur-{d}en-ki kuruszda
# POS:(1(disz),O) (sila4,PN) (kiszib3,PN) (ur-{d}en-ki,PN) (kuruszda,DN)
#
# 108
# sentence: dumu-munus-a-ni
# POS:(dumu-munus-a-ni,TN)
#
# 109
# sentence: an-na-ag2
# POS:(an-na-ag2,PN)
#
# 110
# sentence: iti nesag
# POS:(iti,PN) (nesag,MN)
#
# 111
# sentence: naga-bi 1(barig) 1(ban2) 1/2(disz) sila3
# POS:(naga-bi,PN) (1(barig),O) (1(ban2),O) (1/2(disz),O) (sila3,O)
#
# 112
# sentence: giri3 lu2-{d}nanna dumu ba-ba
# POS:(giri3,PN) (lu2-{d}nanna,PN) (dumu,DN) (ba-ba,PN)
#
# 113
# sentence: iti ezem-{d}...
# POS:(iti,PN) (ezem-{d}...,MN)
#
# 114
# sentence: szu-{d}suen
# POS:(szu-{d}suen,RN)
#
# 115
# sentence: zi-ga
# POS:(zi-ga,PN)
#
# 116
# sentence: RU-lugal-me
# POS:(RU-lugal-me,RN)
#
# 117
# sentence: mu mu-na-sa4
# POS:(mu,EN) (mu-na-sa4,RN)
#
# 118
# sentence: ka ba-ab-kesz2
# POS:(ka,O) (ba-ab-kesz2,WN)
#
# 119
# sentence: mar-sa-asz mu-kux(DU)
# POS:(mar-sa-asz,FN) (mu-kux(DU),SN)
#
# 120
# sentence: u4 1(u) 3(disz)-sze3 ka-sahar-ta
# POS:(u4,O) (1(u),O) (3(disz)-sze3,O) (ka-sahar-ta,PN)
#
# 121
# sentence: 2(asz) MI-si4-ad
# POS:(2(asz),O) (MI-si4-ad,PN)
#
# 122
# sentence: mu ki-masz{ki} u3 hu-ur5-ti{ki} ba-hul
# POS:(mu,GN) (ki-masz{ki},GN) (u3,GN) (hu-ur5-ti{ki},GN) (ba-hul,GN)
#
# 123
# sentence: 1(esze3) 4(iku)
# POS:(1(esze3),O) (4(iku),O)
#
# 124
# sentence: 5(asz) sze gur lugal
# POS:(5(asz),O) (sze,PN) (gur,RN) (lugal,PN)
#
# 125
# sentence: 1/3(disz) ma-na x gin2 ku3 sze x x
# POS:(1/3(disz),O) (ma-na,PN) (x,DN) (gin2,PN) (ku3,PN) (sze,PN) (x,DN) (x,DN)
#
# 126
# sentence: baharx(EDIN)-ri
# POS:(baharx(EDIN)-ri,PN)
#
# 127
# sentence: iti 1(disz)-kam
# POS:(iti,PN) (1(disz)-kam,MN)
#
# 128
# sentence: 6(disz) 1/2(disz) gin2 6(disz) sze ku3
# POS:(6(disz),O) (1/2(disz),O) (gin2,PN) (6(disz),O) (sze,O) (ku3,O)
#
# 129
# sentence: iti {d}dumu-zi-sze3
# POS:(iti,PN) ({d}dumu-zi-sze3,MN)
#
# 130
# sentence: ugula ur-mes
# POS:(ugula,O) (ur-mes,PN)
#
# 131
# sentence: {d}nin-gir2-su
# POS:({d}nin-gir2-su,DN)
#
# 132
# sentence: gesztu2 dagal nig2-nam gal-le-esz zu
# POS:(gesztu2,GN) (dagal,GN) (nig2-nam,GN) (gal-le-esz,GN) (zu,GN)
#
# 133
# sentence: gu-nigin2-bi 7(gesz2) 2(u) 7(disz) 5/6(disz)
# POS:(gu-nigin2-bi,PN) (7(gesz2),O) (2(u),O) (7(disz),O) (5/6(disz),O)
#
# 134
# sentence: an-nu-ni-tum
# POS:(an-nu-ni-tum,PN)
#
# 135
# sentence: 2(u) {uruda}gur10 a-ra2 2(disz)-kam
# POS:(2(u),O) ({uruda}gur10,PN) (a-ra2,PN) (2(disz)-kam,O)
#
# 136
# sentence: ka-ma-ri2{ki}-ta
# POS:(ka-ma-ri2{ki}-ta,SN)
#
# 137
# sentence: 2(bur3) 1(esze3) la2 1/2(iku)
# POS:(2(bur3),O) (1(esze3),O) (la2,O) (1/2(iku),O)
#
# 138
# sentence: udu 1(asz)-sze3
# POS:(udu,FN) (1(asz)-sze3,SN)
#
# 139
# sentence: 1(disz) a-kal-la dumu e2-an-ne2
# POS:(1(disz),O) (a-kal-la,PN) (dumu,DN) (e2-an-ne2,PN)
#
# 140
# sentence: sipa gu4 niga
# POS:(sipa,FN) (gu4,SN) (niga,O)
#
# 141
# sentence: 1(barig) e2-ki-bi
# POS:(1(barig),O) (e2-ki-bi,PN)
#
# 142
# sentence: sa2-du11 ki-a-nag sza3-ba-na-sig szabra
# POS:(sa2-du11,PN) (ki-a-nag,DN) (sza3-ba-na-sig,PN) (szabra,DN)
#
# 143
# sentence: gaba-ri
# POS:(gaba-ri,PN)
#
# 144
# sentence: giri3 a-gu-a-ni dub-sar
# POS:(giri3,PN) (a-gu-a-ni,PN) (dub-sar,TN)
#
# 145
# sentence: 1(gesz2) 1(u) 1(disz) x gur
# POS:(1(gesz2),O) (1(u),O) (1(disz),O) (x,O) (gur,O)
#
# 146
# sentence: 1(asz) udu {d}en-...
# POS:(1(asz),O) (udu,PN) ({d}en-...,DN)
#
# 147
# sentence: 1(asz) ni-ni
# POS:(1(asz),O) (ni-ni,PN)
#
# 148
# sentence: lu2-kal-la
# POS:(lu2-kal-la,PN)
#
# 149
# sentence: e2-muhaldim-sze3
# POS:(e2-muhaldim-sze3,TN)
#
# 150
# sentence: szunigin 4(asz) ansze ...
# POS:(szunigin,O) (4(asz),O) (ansze,O) (...,O)

# %%
s='POS:(dumu,N) (ia-szu-ub-dingir,NE) '

# %%
# Out:
# '(dumu,N)'

# %% [markdown]
# # Testing the algo

# %%
y_pred=crf.predict(X_test)
X_test[0]
# Out:
# [{'Is_first_word': 1,
#   'Is_last_word': 0,
#   'previous_word': '',
#   'next_word': 'da-dam',
#   'distorted_word_1': 0,
#   'distorted_word_2': 0,
#   'Is_number_form_1': 0,
#   'Is_child_left': 0,
#   'Is_child_right': 0,
#   'Is_place': 0,
#   'Is_witness_1': 0,
#   'Is_witness_2': 0,
#   'Is_selling_tablet': 0,
#   'Is_behalf_business': 0,
#   'Is_PN_1': 0,
#   'Is_PN_2': 0,
#   'Is_PN_3': 0,
#   'Is_PN_4': 0,
#   'Is_SN': 0,
#   'Is_determinative': 0,
#   'Is_PN_5': 0,
#   'contains_numer': 1,
#   'Is_PN_6': 0,
#   'Is_PN_7': 0,
#   'Is_quantity': 0,
#   'Is_month': 0,
#   'Is_mont_year': 0,
#   'Is_PN_8': 0,
#   'Is_PN_9': 0,
#   'Is_hyphen': 0,
#   'prefix_1': '2',
#   'prefix_2': '2(',
#   'prefix_3': '2(d',
#   'prefix_4': '2(di',
#   'suffix_1': ')',
#   'suffix_2': 'z)',
#   'suffix_3': 'sz)',
#   'suffix_4': 'isz)'},
#  {'Is_first_word': 0,
#   'Is_last_word': 0,
#   'previous_word': '2(disz)',
#   'next_word': 'dumu',
#   'distorted_word_1': 0,
#   'distorted_word_2': 0,
#   'Is_number_form_1': 0,
#   'Is_child_left': 0,
#   'Is_child_right': 1,
#   'Is_place': 0,
#   'Is_witness_1': 0,
#   'Is_witness_2': 0,
#   'Is_selling_tablet': 0,
#   'Is_behalf_business': 0,
#   'Is_PN_1': 0,
#   'Is_PN_2': 0,
#   'Is_PN_3': 0,
#   'Is_PN_4': 0,
#   'Is_SN': 0,
#   'Is_determinative': 0,
#   'Is_PN_5': 0,
#   'contains_numer': 0,
#   'Is_PN_6': 0,
#   'Is_PN_7': 0,
#   'Is_quantity': 1,
#   'Is_month': 0,
#   'Is_mont_year': 0,
#   'Is_PN_8': 0,
#   'Is_PN_9': 0,
#   'Is_hyphen': 1,
#   'prefix_1': 'd',
#   'prefix_2': 'da',
#   'prefix_3': 'da-',
#   'prefix_4': 'da-d',
#   'suffix_1': 'm',
#   'suffix_2': 'am',
#   'suffix_3': 'dam',
#   'suffix_4': '-dam'},
#  {'Is_first_word': 0,
#   'Is_last_word': 0,
#   'previous_word': 'da-dam',
#   'next_word': '...-in',
#   'distorted_word_1': 0,
#   'distorted_word_2': 0,
#   'Is_number_form_1': 0,
#   'Is_child_left': 0,
#   'Is_child_right': 0,
#   'Is_place': 0,
#   'Is_witness_1': 0,
#   'Is_witness_2': 0,
#   'Is_selling_tablet': 0,
#   'Is_behalf_business': 0,
#   'Is_PN_1': 0,
#   'Is_PN_2': 0,
#   'Is_PN_3': 0,
#   'Is_PN_4': 0,
#   'Is_SN': 0,
#   'Is_determinative': 0,
#   'Is_PN_5': 0,
#   'contains_numer': 0,
#   'Is_PN_6': 0,
#   'Is_PN_7': 0,
#   'Is_quantity': 0,
#   'Is_month': 0,
#   'Is_mont_year': 0,
#   'Is_PN_8': 0,
#   'Is_PN_9': 0,
#   'Is_hyphen': 0,
#   'prefix_1': 'd',
#   'prefix_2': 'du',
#   'prefix_3': 'dum',
#   'prefix_4': 'dumu',
#   'suffix_1': 'u',
#   'suffix_2': 'mu',
#   'suffix_3': 'umu',
#   'suffix_4': 'dumu'},
#  {'Is_first_word': 0,
#   'Is_last_word': 1,
#   'previous_word': 'dumu',
#   'next_word': '',
#   'distorted_word_1': 0,
#   'distorted_word_2': 1,
#   'Is_number_form_1': 0,
#   'Is_child_left': 1,
#   'Is_child_right': 0,
#   'Is_place': 0,
#   'Is_witness_1': 0,
#   'Is_witness_2': 0,
#   'Is_selling_tablet': 0,
#   'Is_behalf_business': 0,
#   'Is_PN_1': 0,
#   'Is_PN_2': 0,
#   'Is_PN_3': 0,
#   'Is_PN_4': 0,
#   'Is_SN': 0,
#   'Is_determinative': 0,
#   'Is_PN_5': 0,
#   'contains_numer': 0,
#   'Is_PN_6': 0,
#   'Is_PN_7': 0,
#   'Is_quantity': 0,
#   'Is_month': 0,
#   'Is_mont_year': 0,
#   'Is_PN_8': 0,
#   'Is_PN_9': 0,
#   'Is_hyphen': 1,
#   'prefix_1': '.',
#   'prefix_2': '..',
#   'prefix_3': '...',
#   'prefix_4': '...-',
#   'suffix_1': 'n',
#   'suffix_2': 'in',
#   'suffix_3': '-in',
#   'suffix_4': '.-in'}]

# %%
y_pred
# Out:
# [['O', 'PN', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'DN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN', 'O'],
#  ['PN', 'O', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'DN'],
#  ['O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN', 'O', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN', 'DN', 'SN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'DN', 'SN', 'O'],
#  ['O', 'O', 'GN', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'O', 'FN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O', 'O'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'FN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'GN', 'GN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['PN', 'SN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'O', 'O', 'PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'WN'],
#  ['PN', 'O', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN', 'DN', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O', 'O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'WN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'DN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'FN'],
#  ['O', 'DN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'GN', 'O'],
#  ['PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'MN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'FN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O', 'PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'O', 'O', 'WN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['PN'],
#  ['O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['O', 'GN', 'O'],
#  ['O', 'O', 'O', 'DN'],
#  ['PN', 'O'],
#  ['PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'GN', 'GN'],
#  ['O', 'O', 'PN'],
#  ['O', 'SN'],
#  ['PN'],
#  ['O', 'GN'],
#  ['PN'],
#  ['O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'WN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'MN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'PN', 'O', 'PN'],
#  ['PN', 'O'],
#  ['PN', 'O'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'GN', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'DN', 'O', 'O'],
#  ['PN'],
#  ['O'],
#  ['O', 'O', 'PN'],
#  ['PN', 'O', 'SN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['PN', 'O'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'DN', 'SN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'FN', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'FN'],
#  ['PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'FN'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'WN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'WN', 'O'],
#  ['O'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'DN', 'SN', 'O'],
#  ['O', 'FN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'DN'],
#  ['O', 'FN'],
#  ['O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'FN'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'O', 'FN'],
#  ['O', 'PN', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'WN', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['PN'],
#  ['O', 'O', 'FN'],
#  ['O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN', 'O', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN', 'O', 'SN'],
#  ['PN', 'O'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'FN'],
#  ['PN'],
#  ['O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['PN', 'O'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'O', 'O', 'DN', 'O'],
#  ['PN', 'O'],
#  ['PN', 'SN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'PN', 'PN', 'O', 'O'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['FN', 'O'],
#  ['PN', 'O'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'GN', 'GN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['DN', 'SN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'RN', 'O', 'O', 'O', 'DN'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'FN', 'O'],
#  ['PN', 'O', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'FN'],
#  ['O', 'FN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'PN', 'O', 'O'],
#  ['O', 'O'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'FN', 'O', 'O', 'O', 'WN'],
#  ['PN'],
#  ['PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'FN'],
#  ['O', 'PN', 'O', 'PN', 'O'],
#  ['O', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'PN', 'O', 'PN', 'O', 'PN', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'RN', 'O', 'O', 'O', 'DN', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['PN', 'O', 'PN'],
#  ['O', 'O', 'FN'],
#  ['O', 'O', 'O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'MN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['DN'],
#  ['O', 'O', 'O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'DN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['FN', 'O'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['PN'],
#  ['O', 'MN', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'PN'],
#  ['SN', 'O', 'PN'],
#  ['O', 'ON', 'DN', 'O'],
#  ['PN', 'O', 'O'],
#  ['PN', 'DN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'GN', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'DN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O', 'O', 'O'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'GN', 'O'],
#  ['PN', 'O', 'O', 'O', 'SN', 'O'],
#  ['O', 'O', 'O', 'PN', 'O'],
#  ['PN', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['PN'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['PN', 'O'],
#  ['PN', 'O', 'O'],
#  ['O', 'FN', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN', 'O'],
#  ['PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['PN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'WN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'RN', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'O', 'PN', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'DN'],
#  ['PN', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'GN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'PN'],
#  ['O', 'GN', 'O'],
#  ['PN', 'O'],
#  ['PN', 'O', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'GN'],
#  ['O', 'PN'],
#  ['O', 'O', 'DN'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'GN', 'GN'],
#  ['PN', 'GN'],
#  ['O', 'O', 'O', 'FN'],
#  ['O', 'O', 'WN', 'O'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'GN', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'GN', 'GN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'GN', 'GN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'O', 'WN'],
#  ['O', 'PN'],
#  ['O'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['PN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['GN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'FN', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'PN', 'O', 'O'],
#  ['O', 'MN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['PN', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O', 'O', 'DN', 'O'],
#  ['O', 'GN', 'O'],
#  ['PN'],
#  ['O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'GN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'FN'],
#  ['O', 'O', 'O', 'O', 'O', 'DN'],
#  ['O', 'O', 'PN'],
#  ['PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'FN'],
#  ['PN', 'O', 'O'],
#  ['O', 'GN', 'GN'],
#  ['O', 'PN'],
#  ['O', 'GN'],
#  ['PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'GN', 'O'],
#  ['O', 'GN', 'GN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'FN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'SN'],
#  ['O', 'O', 'O', 'FN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN', 'O', 'SN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'DN'],
#  ['O', 'GN', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['PN', 'O', 'O', 'O'],
#  ['DN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'FN'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'MN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O', 'O', 'O', 'PN'],
#  ['O', 'O', 'O'],
#  ['O', 'GN', 'GN'],
#  ['O', 'GN', 'GN'],
#  ['O', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'GN', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'WN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'DN', 'SN', 'O'],
#  ['O', 'MN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'DN', 'O'],
#  ['O', 'DN', 'SN', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'FN'],
#  ['O', 'PN'],
#  ['DN', 'O'],
#  ['O', 'FN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['PN', 'O'],
#  ['O', 'O', 'PN', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['PN', 'O', 'O'],
#  ['O', 'O', 'WN', 'O'],
#  ['PN', 'O'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['PN'],
#  ['O', 'O', 'O', 'PN', 'O'],
#  ['O', 'TN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'FN'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'PN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN', 'O'],
#  ['O', 'PN', 'O', 'PN'],
#  ['GN', 'O', 'SN', 'O'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['PN'],
#  ['O'],
#  ['O', 'PN'],
#  ['O', 'FN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ['PN'],
#  ['O', 'SN', 'O'],
#  ['O', 'O', 'GN', 'O'],
#  ['FN'],
#  ['PN', 'O'],
#  ['O', 'PN'],
#  ['FN', 'O'],
#  ['PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'FN'],
#  ['O', 'PN', 'O', 'O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN', 'DN', 'O'],
#  ['PN', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'O'],
#  ['O', 'O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'PN', 'O'],
#  ['RN', 'O', 'O'],
#  ['PN'],
#  ['O', 'PN'],
#  ['O', 'PN', 'O', 'O'],
#  ['O', 'PN'],
#  ['O', 'RN', 'O', 'SN', 'O', 'DN', 'SN', 'O'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'O', 'WN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'O'],
#  ['O', 'PN', 'O', 'PN'],
#  ['O', 'O', 'O', 'PN', 'O'],
#  ['PN'],
#  ['O', 'O', 'PN'],
#  ['O', 'MN', 'O', 'O', 'O'],
#  ['O', 'PN', 'O', 'PN', 'O'],
#  ['O', 'PN', 'O', 'PN', 'GN'],
#  ['O', 'PN', 'O'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'FN'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O', 'PN', 'O'],
#  ['O', 'FN'],
#  ['O', 'FN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'PN'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'FN'],
#  ['O', 'O', 'O', 'PN'],
#  ['O', 'PN'],
#  ['PN'],
#  ...]

# %%
print(metrics.flat_f1_score(y_test, y_pred,average='weighted',labels=crf.classes_))
# Out:
# 0.9773412966745056
# /home/himanshu/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1464: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(

# %%
y_pred_train=crf.predict(X_train)
metrics.flat_f1_score(y_train, y_pred_train,average='weighted',labels=crf.classes_)
# Out:
# 0.9953594729274575

# %%
metrics.flat_accuracy_score(y_test,y_pred)
# Out:
# 0.9777199544641405

# %%
metrics.flat_accuracy_score(y_train,y_pred_train)
# Out:
# 0.995372211576702

# %%
print(metrics.flat_classification_report(
    y_test, y_pred, labels=crf.classes_, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#            O      0.988     0.994     0.991      3887
#           PN      0.972     0.971     0.972      1777
#           FN      0.905     0.922     0.913       166
#           SN      0.956     0.860     0.905        50
#           DN      0.859     0.709     0.777        86
#           EN      1.000     1.000     1.000         3
#           GN      0.935     0.935     0.935       123
#           RN      1.000     0.750     0.857        16
#           MN      0.900     0.900     0.900        10
#           WN      1.000     1.000     1.000        26
#           ON      1.000     1.000     1.000         1
#           TN      0.333     0.250     0.286         4
#           AN      0.000     0.000     0.000         0
#
#    micro avg      0.978     0.978     0.978      6149
#    macro avg      0.834     0.792     0.810      6149
# weighted avg      0.977     0.978     0.977      6149
# /home/himanshu/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:68: FutureWarning: Pass labels=['O', 'PN', 'FN', 'SN', 'DN', 'EN', 'GN', 'RN', 'MN', 'WN', 'ON', 'TN', 'AN'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# /home/himanshu/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/himanshu/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Number of Transition Features ")
len(crf.transition_features_)
# Out:
# Number of Transition Features
# 147

# %%
Counter(crf.transition_features_).most_common()[:20]
# Out:
# [(('O', 'O'), 4.866402),
#  (('GN', 'GN'), 4.305474),
#  (('PN', 'O'), 2.844378),
#  (('SN', 'O'), 2.691818),
#  (('O', 'WN'), 2.587741),
#  (('O', 'PN'), 2.290635),
#  (('O', 'DN'), 2.159187),
#  (('RN', 'O'), 2.026138),
#  (('WN', 'O'), 1.777777),
#  (('ON', 'O'), 1.721653),
#  (('GN', 'O'), 1.71974),
#  (('DN', 'O'), 1.605265),
#  (('O', 'MN'), 1.555794),
#  (('FN', 'O'), 1.55328),
#  (('DN', 'SN'), 1.493999),
#  (('O', 'ON'), 1.351986),
#  (('O', 'FN'), 1.334978),
#  (('O', 'SN'), 1.167039),
#  (('EN', 'ON'), 1.048175),
#  (('TN', 'O'), 1.008371)]

# %%
print("Number of State Features ",len(crf.state_features_))
# Out:
# Number of State Features  13492

# %%
Counter(crf.state_features_).most_common(30)
# Out:
# [(('next_word:gub-ba', 'FN'), 8.866339),
#  (('previous_word:guru7', 'FN'), 8.502178),
#  (('previous_word:4(u)', 'FN'), 8.079066),
#  (('previous_word:kab2-ku5', 'FN'), 7.993145),
#  (('previous_word:a-sza3', 'FN'), 7.736178),
#  (('previous_word:i7', 'WN'), 7.709769),
#  (('next_word:ba-hul', 'GN'), 7.376593),
#  (('previous_word:e2-duru5', 'GN'), 7.304868),
#  (('next_word:tir-sze3', 'GN'), 7.300614),
#  (('next_word:ba-na-...', 'PN'), 6.644704),
#  (('previous_word:ka', 'WN'), 6.288906),
#  (('next_word:nibru{ki}-sze3', 'FN'), 5.776503),
#  (('next_word:lugal', 'RN'), 5.35052),
#  (('previous_word:lugal', 'GN'), 5.295136),
#  (('previous_word:ugu2', 'PN'), 5.273773),
#  (('next_word:mu-kux(DU)', 'FN'), 5.21914),
#  (('previous_word:gibil', 'WN'), 5.212556),
#  (('previous_word:GAN2', 'FN'), 5.049837),
#  (('next_word:lugal-e', 'RN'), 5.004249),
#  (('previous_word:ki', 'PN'), 4.937904),
#  (('next_word:ka(SAG)-guru7', 'PN'), 4.734107),
#  (('previous_word:sze-ba', 'FN'), 4.676607),
#  (('previous_word:ab-ba-gi-na', 'GN'), 4.625134),
#  (('next_word:szabra', 'PN'), 4.597793),
#  (('next_word:muhaldim-ra', 'PN'), 4.521112),
#  (('next_word:iszib', 'PN'), 4.510638),
#  (('next_word:ra2-gaba-da', 'PN'), 4.509727),
#  (('previous_word:ugula', 'PN'), 4.424878),
#  (('next_word:kar-zi-da', 'DN'), 4.424373),
#  (('previous_word:ma2', 'DN'), 4.419771)]

# %%
Counter(crf.state_features_).most_common()[-20:]
# Out:
# [(('previous_word:gibil', 'O'), -2.07774),
#  (('next_word:i3-dab5', 'O'), -2.097007),
#  (('prefix_4:ur-x', 'PN'), -2.108322),
#  (('next_word:kuruszda', 'O'), -2.179476),
#  (('suffix_4:a-na', 'DN'), -2.184469),
#  (('previous_word:apin-la2', 'O'), -2.252605),
#  (('previous_word:a-sza3', 'O'), -2.26109),
#  (('previous_word:en', 'O'), -2.29316),
#  (('next_word:u3', 'O'), -2.42417),
#  (('next_word:gudu4', 'O'), -2.534748),
#  (('suffix_4:8-um', 'PN'), -2.573472),
#  (('previous_word:a-a-kal-la', 'O'), -2.580576),
#  (('Is_SN', 'O'), -2.828562),
#  (('suffix_4:i-zi', 'FN'), -2.879286),
#  (('previous_word:e2', 'O'), -2.99784),
#  (('previous_word:kab2-ku5', 'O'), -3.222128),
#  (('next_word:ba-a-gar', 'O'), -3.289811),
#  (('Is_PN_4', 'O'), -3.49454),
#  (('Is_PN_5', 'O'), -3.80433),
#  (('next_word:ba-hun', 'O'), -3.896669)]

# %% [markdown]
# # Shuffel Dataset

# %%
import random
lines=[]
with open("CDLI_Data/Sumerian_monolingual_processed.txt", "r") as f:
    for line in f:
        line=line.strip()
        lines.append(line)

# %%
lines
# Out:
# ['su-mu-ra-pi2',
#  'dumu ia-szu-ub-dingir',
#  'ARAD2 sza {d}iszkur',
#  'ia-am-s,i2-at-nu-u2',
#  'dumu a-li2-wa-aq-rum',
#  'ARAD2 sza {d}...',
#  'ur-{d}nanna',
#  'dumu {d}suen-i-qi2-sza-am',
#  'i-ri {d}su-he2-zi',
#  '{d}nin-sza3-tuk-x',
#  'za-ri-a-nu-u2',
#  'dumu sa-ma-nu',
#  'ARAD2 sza {d}ku7',
#  '4(iku) GAN2 DUR2-HAR sar',
#  '1(u) uruda a-ru12-da ma-na',
#  '4(asz) ku3 gin2',
#  'sa10 GAN2-kam',
#  '6(asz) sze gur',
#  'nig2-diri',
#  'nita-tur',
#  'dam-ni',
#  'i7-hi-li-su3',
#  'lu2 sa10 gu7-me',
#  '4(asz) siki ma-na',
#  '1(asz) tug2 aktum',
#  '1(asz) tug2 ib2-du3',
#  '2(asz) i3 sila3',
#  '1(asz) nig2-sag-kesz2',
#  '2(asz) ninda',
#  'nig2-ba',
#  'ur-{d}en-lil2',
#  'DI-{d}utu',
#  'HAR-tu',
#  'ba-da-da',
#  'ur-{d}lamma',
#  'lu2 ki-inim-ma-me',
#  'il2',
#  'ur-{d}nin-unu{ki}',
#  'lu2 GAN2 sa10-me',
#  'dingir-a-zu',
#  'engar-bi',
#  'ig-gi-nu-gi4',
#  'dub-sar-bi',
#  'ku3 2/3(|NINDA2x(SZE.2(ASZ))|)',
#  '1(asz) i3 sila3',
#  'nig2-ba-ni',
#  'ensi2-bi',
#  'inim-ma-ni',
#  '6(asz) uruda ma-na',
#  'sa10 GAN2',
#  '4(iku) GAN2-bi',
#  '4(asz) uruda ma-na',
#  'nig2-diri',
#  '2(asz) sze lid2-ga',
#  'nig2-ba',
#  '2(asz) siki ma-na',
#  'tug2',
#  '1(asz) me-gal2 tug2',
#  '2(u) ninda',
#  '2(u) gug2',
#  '3(asz) kur2 tu7(|HIxDISZ|)',
#  '3(asz) kur2 |LAGABx(HA.A)|',
#  '1(asz) i3 sila3',
#  'ur-{d}en-lil2',
#  'ama(LAK769)-ma',
#  'lugal-du10-NU2',
#  'lu2 sa10 gu7',
#  '2(barig) sze',
#  '1(u) ninda',
#  '1(u) gug2',
#  '2(asz) kur2 tu7',
#  '2(asz) kur2 |LAGABx(HA.A)|',
#  'szesz-a-ra2-nu2',
#  'szesz lu2',
#  '1(asz) bahar4',
#  '1(asz) x-ri',
#  '1(asz) DI-utu',
#  '1(asz) mes-u4-ba',
#  '1(asz) gaba-szu',
#  '1(asz) a2-nu-kusz2',
#  '1(asz) dingir-a-zu',
#  'engar',
#  '1(asz) dingir-lu2-mah',
#  'nimgir',
#  '1(asz) amar-szuba3',
#  '1(asz) ku-li-li',
#  'gudu4',
#  '1(asz) ur2-mud',
#  'lu2 ki-inim',
#  '2(barig) sze',
#  '5(asz) ninda',
#  '1(u) gug2',
#  '1(asz) 1/2(DISZ) kur2 tu7',
#  'a-har-szi',
#  'dub-sar',
#  '3(ban2) sze',
#  '3(asz) ninda',
#  '5(asz) gug2',
#  '1(asz) 1/2(DISZ) kur2 tu7',
#  'engar-us2',
#  'szesz-ama(LAK769)-na',
#  'lu2 GAN2 sa10',
#  'GAN2 a-nig2-tur',
#  'bala',
#  'inim-ni-zi',
#  '6(asz) uruda ma-na',
#  'sa10 GAN2',
#  '4(iku) GAN2-bi',
#  '4(asz) uruda ma-na',
#  'nig2-diri',
#  '2(asz) sze lid2-ga',
#  'nig2-ba',
#  '2(asz) siki ma-na',
#  'tug2',
#  '1(asz) me-gal2 tug2',
#  '2(u) ninda',
#  '2(u) gug2',
#  '3(asz) kur2 tu7',
#  '3(asz) kur2 |LAGABx(HA.A)|',
#  '1(asz) i3 sila3',
#  'ur-{d}en-lil2',
#  'ama-ma',
#  'lugal-NU2-du10',
#  'lu2 sa10 gu7',
#  '2(barig) sze',
#  '1(u) ninda',
#  '1(u) gug2',
#  '2(asz) kur2 tu7',
#  '2(asz) kur2 |LAGABx(HA.A)|',
#  'szesz-a-ra2-nu2',
#  'szesz lu2',
#  '1(asz) bahar4',
#  '1(asz) x-ri',
#  '1(asz) di-utu',
#  '1(asz) mes-u4-ba',
#  '1(asz) gaba-szu',
#  '1(asz) a2-nu-kusz2',
#  '1(asz) dingir-a-zu',
#  'engar',
#  '1(asz) dingir-lu2-mah',
#  'nimgir',
#  '1(asz) amar-szuba3',
#  '1(asz) ku-li-li',
#  'gudu4',
#  '1(asz) ur2-mud',
#  'lu2 ki-inim',
#  '2(barig) sze',
#  '5(asz) ninda',
#  '1(u) gug2',
#  '1(asz) 1/2(disz) kur2 tu7',
#  'a-har-szi',
#  'dub-sar',
#  '3(ban2) sze',
#  '3(asz) ninda',
#  '5(asz) gug2',
#  '1(asz) 1/2(disz) kur2 tu7',
#  'engar-us2',
#  'szesz-ama(LAK769)-na',
#  'lu2 GAN2 sa10',
#  'GAN2 a-nig2-tur',
#  'bala',
#  'inim-ni-zi',
#  '{d}suen-ga-szi-id',
#  'nita kal-ga',
#  'lugal unu{ki}-ga',
#  'lugal am-na-nu-um',
#  'u2-a e2-an-na',
#  'u4 e2-an-na',
#  'mu-du3-a',
#  'e2-gal',
#  'nam-lugal-la-ka-ni',
#  'mu-du3',
#  '1(esze3) GAN2',
#  'ur-{d}nin-PA-ke4',
#  'lugal-USZ-MUSZ-ra',
#  'i3-na-ba',
#  'UD-MA2-GAD',
#  'i3-na-nu2',
#  'ur-lu-lu',
#  'maszkim-bi',
#  'inim-{d}sud3-da-zi',
#  'nu-na-gid2',
#  '1(asz) ur-AN-{d}en-lil2',
#  'sukkal za3',
#  '1(asz) nigin3-mud',
#  'nagar-gal',
#  '1(asz) du6-ku3-si',
#  'simug-gal',
#  '1(asz) szesz-a2-nu-kusz2',
#  'zadim-gal',
#  '1(asz) isz-me-lum',
#  'dub-sar',
#  'lu2 ki inim',
#  'x 1/2(asz) ku3 gin2',
#  '2(asz) lid2-ga 2(barig) sze',
#  'ur-kin-nir',
#  '1(asz) x {dug}sila3 nimgir-gal',
#  '... x SZIR sila3',
#  'x ur-sukkal-{d}saman3',
#  'x siki ma-na',
#  '2(u) ninda',
#  '2(u) gug2',
#  '3(asz) tu7',
#  'lu2-sa10-gu7',
#  '1(u) ninda',
#  '1(u) gug2',
#  '2(u) PAP tu7',
#  '2(u) PAP |GA2xHA|-A',
#  'UR-UR',
#  'szesz AN x',
#  '1(u) ur-{d}sud3',
#  '1(u) GAR-SZA3',
#  '1(u) engar-SZE3-x',
#  '1(u) NI-NI-zu',
#  'lu2-ki-inim',
#  'ku3 sa10-2(asz) ma-na',
#  '2(ban2) sze-ninda',
#  '1(u) gug2',
#  '1(gesz2) 3(u) 2(asz) i3-nun',
#  'x ga szu-tag',
#  'ad-da',
#  'na-gada',
#  'x 2(u) i3-nun',
#  '3(barig) ga szu-tag',
#  '9(asz) gamurx(LAK490) nig2-du3',
#  'UR-UR',
#  '4(u) i3-nun',
#  'x gamurx(LAK490) szu-tag',
#  'AK-{d}sud3',
#  'ad-da',
#  'na-gada',
#  '{d}gibil6',
#  'i3 e2-gal DU',
#  '2(u) i3-nun',
#  '4(ban2) ga szu-tag',
#  'nin-unken-a',
#  '{d}lugal-mes-lam',
#  '3(u) i3-nun',
#  'di-utu',
#  'na-gada',
#  '4(u) 6(asz) i3-nun',
#  '2(u) la2 2(asz) gamurx(LAK490) nig2-du3',
#  'ku-li',
#  '2(u) 1(asz) i3-nun',
#  '... ga-szu-tag',
#  '2(u) x i3-nun',
#  '3(u) 7(asz) i3-nun',
#  '1(u) la2 2(asz) ga szu-tag',
#  '9(asz) gamurx(LAK490)',
#  '{d}nin-kur',
#  'di-utu',
#  '5(asz) sila3 i3-nun',
#  '2(barig) ga szu-tag',
#  '{d}sza3-zu',
#  '2(u) 4(asz) sila3 i3-nun',
#  'x 2(asz) i3-nun',
#  '4(asz) gamurx(LAK490)',
#  '{d}...',
#  '3(asz) i3-nun',
#  '1(ban2) gamurx(LAK490)',
#  'lu2-x x',
#  '{d}sud3-...',
#  'nu-...',
#  'x 2(asz) i3-nun',
#  'dub-bar',
#  'dumu-zi',
#  '{d}sud3-anzu',
#  'dub',
#  'dingir-dingir',
#  'x dabin',
#  '4(asz) 1(barig) 2(ban2) sze',
#  '1(asz) 3(barig) sze',
#  '1(asz) x x 1(barig) ziz2',
#  '4(asz) la2 1(barig) sze',
#  '5(ban2) ziz2',
#  'iti 1(disz)',
#  '{d}nin-PA',
#  'a2-ki-ti',
#  '... NI',
#  'x 1(barig) 4(ban2) sze-ba',
#  'iti 1(disz)',
#  '1(asz) sze',
#  'x-KA',
#  'dumu-TU',
#  'iti 1(disz)',
#  '{d}nin-me-szu-du7',
#  'x 1(barig) ...',
#  '2(barig) gig',
#  'ninda u4-da',
#  '1(barig) x 2(ban2) x sze',
#  '1(asz) 2(barig) ziz2',
#  'ninda u4-da',
#  '2(asz) sze-ba',
#  '2(asz) sila3 kasz',
#  'x sze',
#  'iti ur2-NUN-U5',
#  '{d}uttu(|TAG.NUN|)',
#  '2(u) la2 1(asz) gurusz',
#  'AN-nu-me',
#  '1(u) 4(asz) ur-{d}sud3',
#  '1(gesz2) 2(asz) munus-gesztin',
#  '1(gesz2) 1(u) 3(asz) ur-{d}sud3',
#  '1(gesz2) pa4-bil4-{an}anzux(MI){muszen}',
#  '1(gesz2) 1(asz) mes-lu-lu',
#  '1(gesz2) 1(u) dumu-{an}anzux(MI){muszen}',
#  '1(gesz2) 1(u) 6(asz) ad-da',
#  '1(gesz2) 3(asz) di:utu',
#  '2(u) 5(asz) nagar',
#  '2(u) simug',
#  '1(u) 1(asz) aszgab',
#  '3(asz) nu-kiri6',
#  '2(u) 3(asz) abgal',
#  '2(u) 7(asz) gal-nimgir',
#  '3(u) 5(asz) sa12-du5',
#  '2(u) 4(asz) szita-da:nu-tuku',
#  '1(u) 5(asz) e2-su13-ag2',
#  '1(u) la2 1(asz) nin-ur-sag',
#  '2(u) amar-szuba3',
#  '2(u) la2 2(asz) amar-tur3',
#  '1(u) 2(asz) amar-nam-nir',
#  '1(u) 2(asz) ur-dumu-zi',
#  '1(gesz2) enku',
#  "szu-nigin2 1(gesz'u) 4(gesz2) 2(u) la2 2(asz) gurusz",
#  '1(u) 1(asz) 1(ban2) 5(disz) sze lid2-ga',
#  '3(barig) sze',
#  '2(asz) 1(ban2) 5(disz) sze',
#  '1(asz) 2(barig) la2 1(ban2) 5(disz) sze',
#  'en-nam-zu5-sze3',
#  '3(asz) 3(ban2) munu4-mu2',
#  '1(asz) 2(barig) 1(ban2) 5(disz) lunga3',
#  'an-sze3-gu2 2(u) sze lid2-ga',
#  'iti 6(disz)',
#  '... 1(barig) sze lid2-ga',
#  '6(asz) 2(barig) 1(ban2) 5(disz) sze lid2-ga',
#  '1(asz) 2(barig) sze lid2-ga',
#  'en-nam-zu5-sze3',
#  '3(asz) 3(ban2) munu4-mu2',
#  '1(asz) 2(barig) 1(ban2) 5(disz) lunga3',
#  'an-sze3-gu2',
#  '4(asz) 2(barig) 4(ban2) 5(disz) sze lid2-ga',
#  'ninda u4',
#  '1(asz) 2(barig) ziz2',
#  'ninda u4',
#  '2(asz) sze',
#  'ninda bad3',
#  '1(asz) ge6 lid2-ga',
#  'ninda bad3',
#  '1(asz) 1(barig) sze lid2-ga',
#  'sze-ba',
#  'iti 1(disz)',
#  'sze gu7',
#  '1(barig) sze',
#  'dumu-dumu en-il2',
#  'sze GAN2 DU',
#  '8(asz) 3(ban2) 5(disz) sze lid2-ga',
#  '4(asz) 2(barig) 4(ban2) 5(disz) sze lid2-ga',
#  '1(asz) 2(barig) 3(ban2) ziz2 lid2-ga',
#  'ninda UD',
#  '2(barig) sze-ba geme2',
#  'ga2-gi4',
#  '2(barig) sze-ba geme2 libir',
#  '2(ban2) nin-munus-zi',
#  '1(barig) 3(ban2) ninda diri',
#  'sze GAN2 DU',
#  'an-sze3-gu2 6(asz) 3(ban2) 5(disz) sze lid2-ga',
#  '1(asz) 2(barig) ziz2',
#  '6(asz) i3 sila3',
#  'sag-TAR',
#  '6(asz) ur-NI',
#  '1(u) e2-gal-|LAGAR+DA|',
#  '6(asz) sila3',
#  '{d}sud3-ur-sag',
#  '4(asz) lu2-KA-KAL',
#  '1(u) 4(asz) ba-si4',
#  'an-sze3-gu2 4(u) 6(asz) i3 sila3',
#  'engar',
#  '2(asz) tug2',
#  '2(asz) gada',
#  'u5-ri nagar',
#  'maszkim-gi4',
#  'esz3-sze3 an-na-de6',
#  '1(asz) 1/2(DISZ) tug2',
#  'maszkim',
#  'lugal',
#  'a-hu-ti',
#  'mu-gi4-a',
#  'mes-lu2-nu-sze3',
#  'mu-da-de6',
#  '7(asz) siki',
#  'e2-nanna',
#  '2(asz) abzu-alan',
#  'n szesz-kur-ra',
#  '3(asz) {d}sud3-anzux(MI){muszen}',
#  '1(u) HAR-tu-{d}sud3',
#  '2(asz) du11-ga-ni',
#  '1(u) e2-utu-gin7-e3',
#  'n x AN e2-si4',
#  '1(u) nam-mah',
#  '3(asz) PAP-PAP ugula',
#  'en-gi',
#  '2(u) 5(asz) siki',
#  'gal-la',
#  '5(asz) a2-nu-kusz2',
#  'dub(UM)-sar',
#  '1(u) an-ur2-sze3',
#  'x lu2',
#  'e2-muhaldim',
#  '1(u) siki',
#  'mes-u4-ba',
#  'mar',
#  '5(asz) szubur',
#  '1(asz) sila4 nita',
#  '1(asz) LAK020',
#  '{d}en-lil2-ukken-a',
#  'munus-a2-nu-kusz2',
#  '1(asz) 1/2(disz) u8',
#  'dingir-nu-me',
#  'masz-{d}sud3',
#  '1(asz) 1/2(disz) utu-a2-mah',
#  'dub-sar-mah',
#  '2(asz) LAK020 tur-tur',
#  'AN-AK',
#  '1(bur3) GAN2',
#  'ad-da',
#  '2(esze3) PAD',
#  'ba-lu',
#  '1(esze3) 3(iku) UDU-ur-sag',
#  '1(esze3) TAR-me-si4',
#  '1(bur3) ...',
#  '3(iku) igi-du3',
#  'igi-si4',
#  '1(esze3) e2-na engar',
#  '1(esze3) mu6-sub3',
#  '1(esze3) ur-{d}tu',
#  '3(iku) x x',
#  '3(iku) x x',
#  '3(iku) abzu-x',
#  '2(iku) x x',
#  '4(iku) a2-nu-kusz2',
#  '1(esze3) sag-AN-...',
#  '1(iku) ...',
#  '1(bur3) ...',
#  '1(esze3) ...',
#  '2(iku) ur-dumu-zi',
#  '1(iku) AN-nu-me',
#  '1(esze3) KA-lugal-zi-da',
#  'an-sze3-gu2 2(u) PAD gurusz',
#  'tul2-ba',
#  'n (x)-x-su13',
#  '1(u) 5(asz) ur2-NI',
#  '1(u) ur-lugal',
#  'n (x-x) lu-lu',
#  'dub-sar',
#  '1(u) mes-u4-ba',
#  'abgal',
#  '6(asz) siki',
#  '6(asz) x-x',
#  '6(asz) x (x)',
#  '5(asz) ur-x-x',
#  '4(u) x',
#  'an-sze3-gu2 ...',
#  '1(asz) u8',
#  '1(asz) udu nita',
#  'szesz-gal',
#  'ugula sagi',
#  '1(asz) mes-nig2-lul-le',
#  'szu-ku6',
#  '1(asz) lum-ma',
#  '1(asz) nin-x',
#  'a-ru',
#  '1(asz) x-la',
#  '1(asz) nam-mah',
#  '1(asz) AN-nu-dam',
#  'nu-kiri6',
#  '... {d}sud3',
#  '1(asz) x x',
#  '1(asz) udu-nita',
#  '1(asz) LAK020',
#  'e2-na-lu',
#  'il-i3-li2',
#  '2(asz) LAK020',
#  'dumu-nun-szita',
#  'ur-e2-gal',
#  '5(asz) ...',
#  '1(u) la2 2(asz) LAK020',
#  'ur-{d}sud3',
#  'AN-AK',
#  '1(asz) udu-nita',
#  'lu2-lum-ma',
#  '1(asz) LAK020',
#  'en-mu-du10',
#  '2(asz) udu-nita',
#  '3(asz) LAK020',
#  '... LAK020',
#  'HAR-tu-{d}sud3',
#  'x LAK020',
#  'szu-nigin2 5(u) udu',
#  'n 1(asz) LAK020 GESZ LUM ...',
#  '1(asz) gu4 sze',
#  '6(asz) gu4 u2',
#  '{d}sud3',
#  '3(asz) gu4 sze',
#  '6(asz) gu4 u2',
#  '{d}gibil6',
#  '3(asz) {d}en-lil2{ki}',
#  '2(asz) gu4',
#  '6(asz) gu4 u2',
#  'kin-nir',
#  '7(asz) gu4',
#  'EN-ZU{ki}',
#  '7(asz) gu4',
#  'utu{ki}',
#  '1(asz) gu4 sze-numun',
#  'dumu-szita',
#  'an-sze3-gu2 4(u) 2(asz) gu4',
#  'su-si',
#  'szu ba4-ti',
#  '7(asz) KAL',
#  '1(asz) dug a su13',
#  'an-tu dam ki',
#  '{d}en-ki',
#  '6(asz) KAL',
#  '1(asz) dug a su3',
#  '{d}dumu-e2-nun',
#  'AN-X-AN',
#  '8(asz) KAL',
#  '1(asz) dug a su13',
#  '{d}nin-szubur',
#  '{d}NUN-TAG',
#  '... x x na',
#  'an-na',
#  '3(u) unken-a',
#  '1(u) ni2-kur-ra',
#  '5(asz) ur-kin-nir',
#  'x a x x',
#  'munus-a2-nu-kusz2',
#  'ur-sipa',
#  'na-gada',
#  '2(u) en-nu-kur-sze3',
#  '1(u) AN-ur2-sze3',
#  '2(asz) isz-dup-il',
#  '3(asz) e2-gin7-e3',
#  'e2-ezem-du10',
#  'lum-ma',
#  'na-gada',
#  '2(u) za3-gu4',
#  '3(u) KA-NI-ga',
#  '4(u) ba-zi',
#  'na-gada',
#  '1(u) AN-x',
#  'su-si',
#  '3(u) x-x',
#  '3(asz) ...',
#  '5(asz) a2-nu-kusz2',
#  'dub-sar',
#  '2(asz) gurusz',
#  'amar-{d}iszkur',
#  '1(asz) e2-kur-ra-unken-a',
#  '1(asz) e2-ki-du10-ga',
#  '1(asz) ad-da',
#  '1(asz) AK-{d}sud3',
#  'girx(AD)-bil',
#  '1(asz) amar-tur',
#  '1(asz) szubur',
#  '1(asz) ur-nin-mu2',
#  '1(asz) nam-mah',
#  'AK-sipa',
#  '1(asz) sza3-gu2-ba',
#  '1(asz) HAR-tu-{d}sud3',
#  'ur-dumu',
#  '2(asz) gin2 2(asz) ku3 ma-na',
#  '3(gesz2) 1(u) 6(asz) uruda ma-na',
#  'szu ba4-ti',
#  '1(gesz2) 5(u) la2 1(asz) mi-gal2',
#  'dam-gar3',
#  '5(asz) ku3 gin2',
#  'il-sux(MUSZ)-me-ru',
#  '5(asz) lum-ma',
#  'lunga3',
#  '1(asz) ur-{d}lamma',
#  '2(asz) szubur',
#  'usan3-du3',
#  '1(asz) ba-za',
#  'munu4-mu2',
#  'esz3',
#  'ensi2',
#  'szu bad',
#  '1(u) sanga-GAR',
#  '5(asz) ur-{d}sud3',
#  '4(asz) lum-ma',
#  'abgal',
#  '2(asz) ur-me-te',
#  '1(asz) di-utu',
#  '1(asz) na-ni',
#  'lu2-ma2',
#  '1(asz) masz-{d}sud3',
#  'na-gada',
#  '1(asz) AN-nu-me',
#  'engar dumu-zi',
#  '2(asz) lum-ma',
#  'ba-da-da',
#  '1(asz) ur-nin-|MUSZ%MUSZ|-ru',
#  '1(asz) lu2-lum-ma',
#  'na-gada esz3',
#  '2(asz) nam-mah',
#  'szesz-tur',
#  'sza3 iri',
#  '1(u) 5(asz) ku3 gin2',
#  'dam-gar3',
#  'ku3 nu-la2',
#  'an-sze3-gu2 1(u) 4(asz) ku3 gin2',
#  'ensi2',
#  'szu bad',
#  '2/3(disz) 6(asz) gin2',
#  'ku3 nu-la3',
#  '5(asz) uruda ma-na',
#  'szusz3 sanga',
#  '3(asz) HAR-tu-{d}sud3',
#  '3(asz) NI uruda',
#  'za3 gu4',
#  'ur5 e2-gal tuku',
#  '1(asz) NI bar-dul5 nita2',
#  '3(u) uruda ma-na',
#  '1(asz) ku3 gin2',
#  '1(asz) gada',
#  '1(u) uruda ma-na',
#  'uruda me-te-na',
#  '1(asz) szen uruda',
#  '1(asz) uri uruda',
#  'e-na-dim2',
#  'amar-tur3',
#  '2(disz) 1/2(disz) tug2',
#  '5(disz) uruda ma-na',
#  '2(disz) szen dug uruda',
#  '3(disz) ku3 uruda ma-na',
#  '3(disz) uruda DUB kur-a',
#  '2(disz) KU-SAG zabar3',
#  '2(disz) GIRI3 uruda ma-na',
#  '3(disz) ziz2 lid2-ga',
#  '2(disz) szah2 sze gu7',
#  '1(disz) udu-nita2',
#  '2(disz) u8 sila4 du3',
#  '2(disz) uruda ma-na',
#  'ur5 dingir-nu-me engar',
#  '1(asz) 1/2(DISZ) tug2',
#  '5(asz) uruda ma-na',
#  'n u8 sila4 du3',
#  'n udu nita2',
#  '(x) x uruda ...',
#  '3(asz) uruda ma-na',
#  '3(u) uruda ma-na',
#  'szah2 sze',
#  '6(asz) uruda ma-na',
#  'nig2-gu7',
#  '2(u) ninda',
#  '2(asz) udu',
#  '1/2(disz) SAL x',
#  '1/2(disz) uruda ma-na',
#  'kusz edin',
#  '1(asz) gada',
#  '2(asz) szah2 sze',
#  '6(asz) uruda ma-na ku3',
#  '1(asz) uruda ma-na',
#  '1(asz) tug2 (...)',
#  '1(asz) ...',
#  '... ma-na',
#  'ama-ig-gal',
#  '1(asz) szah2 sze',
#  'ama-ig-gal',
#  '1(disz) ansze',
#  '2(disz) uruda ma-na ku3',
#  '4(disz) tug2',
#  '5(disz) udu nita',
#  '5(disz) ninda sze gu4 am',
#  '3(disz) LAK20',
#  '3(disz) udu nita',
#  '3(disz) i3-nun',
#  '2(disz) siki sag8',
#  '2(disz) LAK716 dug',
#  '5(disz) 1/2(disz) uruda ma-na',
#  '4(disz) uruda ma-na',
#  '2(disz) 1/2(disz) tug2',
#  '2(disz) 1/2(disz) tug2',
#  '2(disz) LAK716 dug',
#  '2(disz) uruda ma-na',
#  '1(gesz2) udu nita',
#  '1(disz) gar3',
#  'gu7',
#  '2(disz) uruda',
#  'dur-narx(LAK244)',
#  '1(disz) 1/2(disz) uruda',
#  'kun BULUG3-BULUG3',
#  '1(disz) uruda x',
#  '2(disz) dug sze gu2 2(disz) gar',
#  '2(disz) uruda ma-na',
#  '2(disz) sze lid2-ga',
#  '2(disz) sze lid2-ga',
#  '4(disz) 1/2(disz) sze szah2 gu7',
#  '1(disz) 1/2(disz) uruda ma-na',
#  'kun BULUG3-BULUG3',
#  '8(asz) uruda ma-na',
#  'sa10 e2',
#  '5(asz) 1/2(disz) uruda ma-na',
#  'nig2-diri',
#  '2(asz) uruda ma-na',
#  'tug2',
#  '1(u) ninda',
#  '1(u) gug2',
#  '2(asz) kur2 tu7',
#  '2(asz) kur2 |GA2x(HA.A)|',
#  '1(asz) i3 sila3',
#  'ad-da-da',
#  'ur-{d}sud3',
#  '8(asz) uruda ma-na',
#  'sa10 e2',
#  '5(asz) 1/2(disz) uruda ma-na',
#  'nig2-diri',
#  '2(asz) uruda ma-na',
#  'tug2',
#  '1(u) 5(asz) ninda',
#  '1(u) 5(asz) gug2',
#  '3(asz) kur2 tu7',
#  '3(asz) kur2 |GA2x(HA.A)|',
#  'lu2-lum-ma',
#  'ur-TUR',
#  'AK-{d}en-lil2',
#  'lu2 sa10 gu7',
#  '8(asz) ninda',
#  '8(asz) gug2',
#  '4(asz) kur2 tu7',
#  '4(asz) kur2 |GA2x(HA.A)|',
#  'inim-{d}sud3-da-zi',
#  'ur-{d}en-lil2',
#  'en-lirum',
#  'ur-{d}dumu-zi',
#  '1(asz) inim-{d}sud3-da-zi',
#  'a-si4',
#  '1(asz) ur-{d}nin-unu',
#  'zadim',
#  '1(asz) ur-{d}lamma',
#  '1(asz) e2-uri3',
#  '1(asz) {d}sud3-{an}anzu2{muszen}',
#  'dub-sar',
#  '1(asz) narx(LAK244)-pa',
#  '1(asz) {d}nin-unu-{an}anzu2{muszen}',
#  'dub-sar',
#  'lu2 ki-inim',
#  '1(asz) uruda ma-na',
#  '3(asz) ninda',
#  '2(asz) gug2',
#  '1(asz) 1/2(disz) kur2 tu7',
#  'nam-mah-{d}sud3-da',
#  'um-mi-a',
#  'lu2 e2 esz2 gar',
#  'e2-du-du',
#  '{d}asznan',
#  'lu2 e2 sa10',
#  '1(barig) e2-bappir3',
#  '2(barig) balag-di',
#  '1(barig) 2(ban2)',
#  '2(barig) e2 szim lam',
#  '1(barig) hur-sag-mah',
#  '1(barig) nibru{ki}',
#  '2(ban2) {d}gu2-la2 1(disz)',
#  '4(ban2) mes-lugal-U-zu',
#  '3(ban2) ama-{d}uszum',
#  '4(ban2) nin-PA nin-bar-szu-du7',
#  '2(ban2) AN-AN',
#  '2(ban2) nin-pirig',
#  '4(ban2) nin-szeg12-iri',
#  '1(barig) 2(ban2)',
#  '{d}en-ki',
#  '1(barig) nin-tin-ug5-ga',
#  '4(ban2) {d}nisaba',
#  '4(ban2) x-di',
#  '4(ban2) sza3-ga-pa3',
#  '1(barig) ...',
#  '1(barig) x-(x)',
#  '4(ban2) x-(x)',
#  '1(barig) 3(ban2) nanna{na}',
#  'x 2(asz) dumu-dumu',
#  'di-utu ugula',
#  'lu2-ad',
#  '... {d}sud3-ur-sag',
#  'ugula',
#  '2(u) 5(asz) ur-e2-gal',
#  'ugula',
#  '2(u) nar',
#  '1(u) 2(asz) munu4',
#  'KA-zi-da',
#  '... gal-...',
#  'lu2-di',
#  '($blank$)',
#  'ba-DU',
#  '1(bur3) GAN2',
#  'a-gid2',
#  'nam',
#  'TUR ...',
#  'szita kalam',
#  'gin2 x',
#  '2(asz) si gal-gal',
#  '4(u) si-|NUxU| sag',
#  '7(asz) 4(ban2) si',
#  '1(gesz2) 4(u) 5(asz) si-|NUxU| sag',
#  '7(asz) 4(ban2) si',
#  '5(u) 1(asz) si-|NUxU| sag',
#  '7(asz) 2(ban2) si',
#  '4(u) 2(asz) si-|NUxU| sag',
#  '2(u) 3(asz) si',
#  '2(gesz2@d) la2 2(asz) si-|NUxU| sag',
#  'szu-ku6',
#  'szu ba-ti',
#  'ba-za',
#  '2(gesz2) 4(u) 8(asz) zi3 gur',
#  '3(u) 5(asz) 2(barig) nig2-ar3 imgaga3 gur',
#  'ur-{d}nin-ildu3-ra si-mah',
#  '1(asz) ma-na 4(asz) gin2 ku3 luh-ha',
#  'bu3-la-li2',
#  '1(asz) ma-na ku3',
#  '1(asz) udu (x)',
#  'ku3-bi 6(asz) gin2-kam',
#  'gu2-en',
#  'dam-gar3',
#  '1(u) 2(asz) gin2 ku3',
#  'ur-igi',
#  'dam-gar3',
#  '1/3(asz){sza} ku3',
#  'e-da-hul',
#  'ugula surx(ERIM) suh5-ha',
#  '1(u) 5(asz) gin2 ku3',
#  'ki lugal-he2',
#  'muszen-du3',
#  'KA-{d}sud3-da-zi',
#  'ama(LAK769)-abzu-e',
#  'pisan-dub',
#  'a mu-ru',
#  '1(u) 3(asz) urudu ma-na',
#  'sa10 e2',
#  '4(u) 1(asz) urudu ma-na',
#  'nig2-diri',
#  'e2 du3',
#  '2(asz) siki ma-na tug2',
#  '1(u) 5(asz) ninda',
#  '1(u) 5(asz) gug2',
#  '4(asz) kur2 tu7(|HIxASZ|)',
#  '4(asz) kur2 |LAGABx(HA.A)|',
#  '1(asz) i3 sila3',
#  'RI-ti',
#  '1(asz) me-gal2 tug2',
#  'nin-NI-NI',
#  'lu2 sa10 gu7',
#  '2(u) la2 2(asz) ninda',
#  '2(u) la2 2(asz) gug2',
#  '4(asz) kur2 tu7',
#  '4(asz) kur2 |LAGABx(HA.A)|',
#  'KA-tar-zi',
#  'nin-szesz-mu-SILA4',
#  'UR-UR',
#  'mim-ma',
#  '5(asz) ninda',
#  '5(asz) gug2',
#  '1(asz) kur2 tu7',
#  '1(asz) kur2 |LAGABx(HA.A)|',
#  '1(asz) ga-ga',
#  'su6-mu2',
#  '1(asz) ur-tul2(|LAGABxU|)-sag',
#  'ka-guru7',
#  '1(asz) szesz-kur-ra',
#  'na-gada',
#  '1(asz) lu2-na-nam',
#  'dub-sar',
#  '1(asz) ur-mir',
#  '1(asz) ur-su13-ra2',
#  '1(asz) szul-sag-x',
#  'girx(AD)-bil',
#  '1(asz) za3-{d}sud3-ta',
#  'masz-da3',
#  '1(asz) lugal-KISAL-si',
#  'gala',
#  '1(asz) sag-an-tuku',
#  '1(asz) inim-{d}sud3-da-zi',
#  '1(asz) e2-ki-ba',
#  'sipa',
#  '1(asz) {d}gu2-la2-an-dul3',
#  'aszgab',
#  '1(asz) ur-sukkal-{d}saman3',
#  '1(asz) e2-ur2-bi-du10',
#  '1(asz) lugal-lirum',
#  '1(asz) dingir-a-mu',
#  '1(asz) {d}sud3-da-lu2',
#  '1(asz) szu-i',
#  '1(asz) {d}nin-me-szu-du7',
#  '1(asz) {d}sud3-a2-mah',
#  'unu3',
#  '1(asz) pa4-nu-la2',
#  '1(asz) amar-szuba3',
#  'dub-sar',
#  'lu2 ki-inim',
#  '1(asz) urudu ma-na',
#  'gal-nimgir',
#  '1/2(disz) urudu ma-na',
#  '5(asz) ninda',
#  '5(asz) gug2',
#  '1(asz) kur2 tu7',
#  '1(asz) kur2 |LAGABx(HA.A)|',
#  'nam-mah',
#  'um-mi-a',
#  'lu2 e2 esz2 gar',
#  'za3-{d}sud3-ta',
#  'unu3',
#  'lu2 e2 sa10',
#  'ki-uzug5',
#  'bala',
#  'abzu-ki-du10',
#  '1(u) ku3 luh-ha gin2',
#  'sa10 GAN2',
#  '1(bur3) 1(esze3) la2 1(iku) GAN2-bi',
#  '1(u) ku3-luh-ha gin2',
#  'nig2-diri',
#  '1/3(disz) 5(asz) ku3 luh-ha gin2',
#  'n(asz) sze lid2-ga',
#  'nig2-ba',
#  '2(u) siki ma-na',
#  '1(gesz2) ninda',
#  '1(gesz2) gug2',
#  '1(u) kur2 tu7(|HIxASZ|)',
#  '1(u) kur2 |GA2xHA|-A',
#  '1(asz) i3 szagan',
#  'a-ni-sikil',
#  'ur-{d}nin-unu',
#  'lu2 sa10 gu7',
#  'ur-kin-nir',
#  'dumu ur-{d}nin-unu',
#  '1(asz) ur-sukkal-{d}saman3',
#  'sukkal',
#  '1(asz) inim-{d}sud3-da-zi',
#  'dub-sar',
#  '1(asz) ur-zi',
#  'kas',
#  '1(asz) amar-{d}sag-ku5',
#  'GUR8(RSP329)-ak',
#  '1(asz) nam-mah',
#  'amar-kuara',
#  '1(asz) e-ta-e11',
#  '1(asz) sag-a-ra2-ba-szum2',
#  'dub-sar',
#  '1(asz) ba-da',
#  'i3-du8',
#  '1(asz) ur-{d}sud3',
#  'nig2-du8-du8',
#  '1(asz) e2-a-nun',
#  'gudu4',
#  '1(asz) za3-mu',
#  '1(asz) du11-ga-ni',
#  'gudu4',
#  '1(asz) lugal-szud3-gesz-tuku',
#  '1(asz) lugal-usz-sux(MUSZ)',
#  '1(asz) ur-dun3-esz3',
#  'geme2 en',
#  '1(asz) SILA3-GAR',
#  'dumu pa4-NAM2',
#  '1(asz) UR-UR',
#  'ir11',
#  '1(asz) e2-du-du',
#  '1(asz) lugal-ab2-ki-ag2',
#  'lu2 ki-inim',
#  '5(asz) siki ma-na',
#  '1(u) ninda',
#  '1(u) gug2',
#  '2(asz) kur2 tu7',
#  '2(asz) kur2 |GA2xHA|-A',
#  'HAR-tu-{d}sud3',
#  'sa12-du5',
#  '5(asz) siki ma-na',
#  '1(u) ninda',
#  '1(u) gug2',
#  '2(asz) kur2 tu7',
#  '2(asz) kur2 |GA2xHA|-A',
#  'ur-x',
#  'gu-sur-NUN',
#  '1(u) siki ma-na',
#  '1(u) ninda',
#  '1(u) gug2',
#  '2(asz) kur2 tu7',
#  '2(asz) kur2 |GA2xHA|-A',
#  'lugal-usz-SZIM',
#  'dub-sar',
#  'a2-lugal-ga2-ta',
#  'lu2 GAN2 sa10',
#  'bala',
#  'masz-{d}sud3',
#  'GAN2 e2 UN{muszen}-SAR',
#  'n gug2',
#  'n(asz) kur2 tu7',
#  'n(asz) kur2 |GA2x(HA.A)|',
#  '2(asz) kur2 tu7',
#  '2(asz) kur2 |GA2x(HA.A)|',
#  'abzu-mud',
#  '1(u) ninda',
#  '1(u) gug2',
#  ...]

# %%
random.seed(12)
random.shuffle(lines)

# %%
lines
# Out:
# ['sag-ki hu-mu-ra-ab-zalag-ge',
#  'ki na-sa6-ta',
#  'iti szu-numun-ta',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  'ba-de6',
#  'mu us2-sa ki-masz{ki} ba-hul',
#  '1(asz) gu4 ab2',
#  '1(barig) 1(ban2) 5(disz) 1(disz) 1/2(disz) geme2-{d}szul-pa-e3 dumu-ni',
#  '1(asz) 2(ban2) nam-nin-...',
#  'dumu ur-{d}nansze',
#  'gu4 udu niga u2-sa',
#  'e2 kiszib3-ba-kam',
#  '1(disz) du-du-am3 u3 lugal-ba-tuku',
#  '{d}nin-sun2',
#  'nig2-du7-e pa mu-na-e3',
#  '2(ban2) ...',
#  'dub-sar',
#  '1(disz) {munus}asz2-gar3',
#  '8(disz) sila3 4(disz) gin2 tab-be-li2 u3 dan-num2',
#  'dumu lu2-ga',
#  'ur-kalam na-gada i3-dab5',
#  '1(disz) munu4 si-e3',
#  '1(u) 2(disz) gaszam',
#  '2(gesz2) 3(u) 7(disz) udu 1(disz) sila3',
#  'dub-sar',
#  '5(disz) 1/2(disz) ma-na 5(disz) gin2 siki tug2 guz-za 3(disz)-kam us2',
#  '5(ban2) 1(u) ba-at-ri',
#  '2(disz) sila3 nig2-ar3-ra saga',
#  '4(u) ka-dug ku3-babbar',
#  'e2-masz-sze3',
#  'ur-ma-ma lu2 bu3',
#  'iti pa4-u2-e',
#  'szunigin 1(disz) la2-ia3',
#  '4(ban2) nin-tesz2-mu',
#  '1(disz) szul-lu5 nu-{gesz}kiri6',
#  'n gu2 siki tug2 guz-za du',
#  '... nin-a-zu',
#  'szunigin 7(disz) gu4 mu 2(disz)',
#  '{d}inanna',
#  'dumu ur-e2-ninnu',
#  '1(disz) i3-li2-an-dul3',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  '1(barig) ama-na',
#  'szunigin 8(disz) dumu 1(ban2) 5(disz) sila3-ta',
#  'din |SZE.NUN&NUN|{+i-ti-sze-x}',
#  'iti ezem-{d}dumu-zi',
#  'szu ba-an-ti',
#  'du11-ga-ni si bi2-sa2',
#  '1(u) 8(disz) gurusz gub-ba la2-ia3 1(u) 5(disz)',
#  'kasz-de2-a ur-{d}iszkur ensi2 ha-ma-zi2{ki}',
#  'mu-na-ba-al',
#  'lu2-kal-la',
#  'sza3-ge engar',
#  '4(barig) ama-masz-min3',
#  'lugal an-ub-da limmu2-ba',
#  'szunigin 3(gesz2) 4(asz) 3(barig) 2(ban2) gur',
#  '5(asz) zi3',
#  '2(disz) sila3 ur3-re-ba-du7',
#  'ki e2 {d}nanna',
#  '1(asz) us2 e2-engur-ka',
#  'bahar3-e-ne szu ba-ab-ti',
#  'mu us2-sa bad3 ma-da ba-du3',
#  '... gur',
#  'ur-e2-an-na',
#  '5(disz) gu2 {u2}nin9',
#  '1(u) 2(asz) ur-gu-la',
#  'dub-sar',
#  'iti GAN2-masz',
#  'dumu nin-iri-ni-sze3',
#  'sza13-dub-ba-ka',
#  'dumu ba-zi',
#  'mu ur-bi2-lum{ki} ba-hul-sze3',
#  'lagasz{ki}-ke4',
#  'ki-la2-bi 2(asz) gu2 2(u) 4(disz) ma-na',
#  'sa2-du11 {d}nin-sun2',
#  'diri x tug2 guz-za x',
#  '1(disz) udu',
#  'szunigin 4(bur3) n GAN2',
#  'tug2 ki-la2 tag-ga',
#  'mu ma-da za-ab-sza-li{ki} ba-hul',
#  'giri3 ri-ib-hu-ti',
#  'mu en ga-esz5{ki}',
#  'iti diri me-ki-gal2 u2-sa',
#  '1(disz) udu niga 4(disz)-kam us2',
#  'szesz-da-da sanga',
#  'x x-na-sze3 ba-ra-da-du-de3-en',
#  '1(asz) geme2 3(ban2)',
#  'lugal uri5{ki}-ma',
#  '2(ban2) ga-ar3',
#  '{d}gesztin-an-na',
#  '{d}szul-gi',
#  '4(disz)',
#  'szunigin 2(asz) 3(ban2) nig2-ar3-ra saga gur',
#  'ki szu-{d}nin-kar-ak-ta',
#  '1(disz) kusz udu a-gar gu7-a',
#  'ki {d}iszkur-illat-ta',
#  'ugula ur-{d}nin-su',
#  'kiszib3 ur-{d}nun-gal',
#  'ganun ka i7 tum-al-ta',
#  '1(gesz2) 3(u) 3(asz) gesztin gal-gal',
#  '1(asz) kinda',
#  '2(u) 3(ban2) gur 5(disz) sila3 sze du',
#  'dab6-ru-um{ki}-ma ba-an-sa6',
#  'u3 gag',
#  '5(asz) 3(barig) 2(ban2) ur-{d}ba-ba6 dumu ur-nig2',
#  'dumu lugal-{gesz}kiri6',
#  '1(disz) sila4 kiszib3 ur-{d}en-ki kuruszda',
#  'dumu-munus-a-ni',
#  'an-na-ag2',
#  'iti nesag',
#  'naga-bi 1(barig) 1(ban2) 1/2(disz) sila3',
#  'giri3 lu2-{d}nanna dumu ba-ba',
#  'iti ezem-{d}...',
#  'szu-{d}suen',
#  'zi-ga',
#  'RU-lugal-me',
#  'mu mu-na-sa4',
#  'ka ba-ab-kesz2',
#  'mar-sa-asz mu-kux(DU)',
#  'u4 1(u) 3(disz)-sze3 ka-sahar-ta',
#  '2(asz) MI-si4-ad',
#  'mu ki-masz{ki} u3 hu-ur5-ti{ki} ba-hul',
#  '1(esze3) 4(iku)',
#  '5(asz) sze gur lugal',
#  '1/3(disz) ma-na x gin2 ku3 sze x x',
#  'baharx(EDIN)-ri',
#  'iti 1(disz)-kam',
#  '6(disz) 1/2(disz) gin2 6(disz) sze ku3',
#  'iti {d}dumu-zi-sze3',
#  'ugula ur-mes',
#  '{d}nin-gir2-su',
#  'gesztu2 dagal nig2-nam gal-le-esz zu',
#  'gu-nigin2-bi 7(gesz2) 2(u) 7(disz) 5/6(disz)',
#  'an-nu-ni-tum',
#  '2(u) {uruda}gur10 a-ra2 2(disz)-kam',
#  'ka-ma-ri2{ki}-ta',
#  '2(bur3) 1(esze3) la2 1/2(iku)',
#  'udu 1(asz)-sze3',
#  '1(disz) a-kal-la dumu e2-an-ne2',
#  'sipa gu4 niga',
#  '1(barig) e2-ki-bi',
#  'sa2-du11 ki-a-nag sza3-ba-na-sig szabra',
#  'gaba-ri',
#  'giri3 a-gu-a-ni dub-sar',
#  '1(gesz2) 1(u) 1(disz) x gur',
#  '1(asz) udu {d}en-...',
#  '1(asz) ni-ni',
#  'lu2-kal-la',
#  'e2-muhaldim-sze3',
#  'szunigin 4(asz) ansze ...',
#  '1(asz) ...',
#  '2(ban2) zi3-gu',
#  'iti sze-sag11-ku5',
#  'lu2-{d}ba-ba6 engar',
#  'maszkim-bi',
#  '{gi}dur sa',
#  'a-ru-a lu2-kal-la',
#  'an-na-ah-i3-li2 aszgab',
#  '1(esze3) lunga',
#  'kiszib3 szesz-kal-la',
#  'kisal-luh abzu',
#  'an-na-szum2',
#  'kusz-bi e2-gal ba-an-kux(KWU147)',
#  'ba-zi',
#  '2(ban2) kasz du',
#  '4(disz) amar az',
#  'zi-bi gaba-bi i-im-il2-il2',
#  '1(disz) udu niga',
#  'ki {d}mu-ul-lil2-da x KU IM DI-en',
#  'ur-{d}gu-nu-ra',
#  'n tug2 sza3-ga-du3',
#  'ki-a-nag szabra',
#  'ugula ukken-ne2',
#  '1(disz) sila4',
#  '2(disz) dusu2-nita2',
#  'a2 gesz-gar-ra',
#  'mu-tu',
#  '7(asz) gu2 2(u) 8(disz) ma-na 1(u) 5(disz) gin2 siki us2',
#  '3(u) 2(asz) 4(barig) 4(ban2) 5(disz) iti u5-bi2{muszen}-gu7',
#  'mu {d}amar-{d}suen lugal ur-bi2-lum mu-hul',
#  'mu us2-sa ki-masz{ki} ba-hul mu us2-sa-a-bi',
#  'ki szum2-ma GAN2 du5-uh2-ka-ta',
#  'iti sze-sag11-ku5',
#  'zi-ga',
#  'i3-dab5',
#  'szu-gid2 e2-muhaldim',
#  '1(u) 8(asz) 4(barig) 1(ban2) 4(disz) sila3 kasz saga gur',
#  'lugal uru16',
#  'ki szabra-ta',
#  'ki nu-ur2-{d}iszkur-ta',
#  'dub-sar',
#  '1(disz) lu2-dingir-ra ugula kikken',
#  'nibru{ki}',
#  '2(ban2) zu2-lum',
#  'inim-ma-ni i3-til',
#  'ki a-gu-ta',
#  '2(u) 9(asz) gu2 gi-ru-usz',
#  '3(u) la2 3(asz) u8',
#  '3(disz) sila3 kasz du',
#  '{gesz}gigir u4 6(disz)',
#  '1(u) gig gur sag-gal2',
#  'sa2-du11 u4 2(disz)-kam',
#  'mu si-mu-ru-um{ki} ba-hul',
#  '2(asz) n e2-...',
#  'kiszib3 {d}lamma-iri-na',
#  '5(disz) sila3 i3-gesz',
#  '1(disz) gurusz aszgab iti 1(disz)-sze3',
#  '3(ban2) 3(disz) nin-di-...',
#  'gal-sze3 de6-a',
#  'ma2 gid2-da ma diri-ga',
#  'giri3 nu-ur2-{d}iszkur dub-sar',
#  '2(esze3) ugula',
#  '6(disz) ku6 {gi}hal 1(barig)-ta',
#  'la2-ia3-am3',
#  '1(disz) bu3-ha-li2-li2',
#  'kiszib3 a-gu',
#  'dumu i3-kal-la',
#  'ki {d}iszkur-illat-ta',
#  '1(asz) 1(barig) gur geme2-{d}li9-si4 dumu ur-ku3',
#  '1(u) 6(asz) geme2 3(ban2)',
#  'x x da-bu',
#  "5(gesz'u) 9(gesz2) 3(u) sa gi",
#  '2/3(disz) sar 1/2(disz) gin2 e2 du3-a da e2 sib2-ta-na',
#  'geme2 szah2 nig2-gu7-a me',
#  '{gesz}gu-za munus pa-pah x ...',
#  '3(disz) udu 1(disz) masz2-gal',
#  '2(disz) gu4',
#  'mu lugal i3-pa3',
#  'ku3-bi ... 4(disz) gin2 ...',
#  'e2-ki-bi szesz-gal',
#  '1(disz) sila3 esza 2(disz) sila3 dabin',
#  'u3 lu2-{d}ba-ba6 dub-sar',
#  'zi-ga bur-sag',
#  'ti-la tu-ra-mu za-da i3-gal2 nam-mah-zu ga-am3-du11',
#  'lu2-kal-la',
#  '1/2(asz) x-x-LUM',
#  '{d}nin-da-sa2',
#  '1(gesz2) nigin2 pa-ku5',
#  '1(barig) gan-ezem',
#  'ba-zi',
#  '4(disz) sila4-nita2',
#  "szunigin 1(gesz'u) 1(gesz2) x 1(ban2) x gur",
#  'ma-ha-ar-ka',
#  'sza3-bi-ta',
#  'ensi2',
#  'szunigin 3(u) 5(disz) udu hi-a',
#  'kiszib3 a-kal-la',
#  'iti sze-sag11-ku5',
#  '1(barig) {d}en-lil2-bad3',
#  '... lu2-nisi',
#  'mu en-unu6-gal {d}inanna ba-hun',
#  '5(disz) sila3 kasz 3(disz) sila3 ninda',
#  '1(disz) ku6 1(disz) sa szum2',
#  'dumu ur-nigar{gar} szusz3',
#  '1(disz) gin2 ku3-babbar',
#  'um-ma-num2{ki} {gesz}tukul ba-sag3',
#  'szunigin 4(ban2) 1(disz) sila3 kasz 1(disz) kasz dida du 1(ban2) 5(disz) sila3',
#  'lugal-ni2-zu',
#  'sa2-du11-am6',
#  '2(disz) sila4 nu-ur4 diri',
#  'iti ezem-{d}li9-si4',
#  'bur2 balag',
#  'u4 da-ri2-sze3',
#  '3(ban2) su6-mu2',
#  'erin2 diri-ta',
#  '{d}lamma szu-a gi4-gi4',
#  '5(disz) sila3 kasz 3(disz) sila3 ninda 3(disz) gin2 szum2 3(disz) gin2 i3 2(disz) gin2 naga',
#  'u4 an-ne2 {d}en-lil2 {d}nanna {d}utu-bi',
#  'ki a-kal-la',
#  'ur-dingir-ra',
#  '3(asz) ...',
#  '1(barig) sze ur-gu-nu-um',
#  'iti masz-da3-gu7',
#  'mu en {d}nanna ba-hun',
#  'szunigin 2(u) 3(disz) dur3',
#  '2(disz) gin2 i3',
#  'geme2 3(disz)-e u4 1(disz)-a szu si 6(disz)-am3 i3-da6-da6',
#  '1(u) 3(asz) la2 1(ban2) gur',
#  'nig2-ezem-ma ezem pa4-u2-e',
#  'lugal-i3-mah sagi maszkim',
#  'mu us2-sa {d}szu-{d}suen lugal',
#  '3(disz) udu niga {d}inanna',
#  'lu2-sa6-ga',
#  'dam-dingir-mu',
#  '...-la dub-sar',
#  'e2-kikken-ta',
#  '1(asz) 1(barig) 4(ban2) 2(disz) sila3 la2 5(disz) gin2 i3-gesz',
#  'ku6-ra im-... DU NE mu-un-na-dub2-e',
#  'a2 erin2-na-bi u4 2(gesz2) 2(u) 4(disz)-kam',
#  '{d}suen-al-su3',
#  '1(ban2) 5(disz) sila3 ... x mu x x',
#  '1(disz) dida du',
#  'A 36',
#  'AN bulug4 bur',
#  'lugal an-ub-da limmu2-ba',
#  '{d}nin-lil2',
#  '4(ban2) nin-lu2-mu',
#  '3(disz) ab2-mah2 7(disz) gu4-gesz',
#  'lugal an-ub-da limmu2-ba',
#  'i7-da gub-ba-me',
#  'giri3 lugal-a2-zi-da dub-sar',
#  'za3-gu2-la2-sze3',
#  'ki na-ba-sa6-ta',
#  'dub-sar',
#  'he2-na-ab-szum2-mu',
#  'lu2-{d}nin-szubur dumu-gu4-gur',
#  '1(asz) dug kas ge6',
#  '1(disz) amar gu4 ur-{d}dumu-zi-da',
#  '{d}szul-gi-iri-mu',
#  'mu mar-tu ba-du3',
#  '... gin2 i3',
#  '1(ban2) 5(asz) sila3 ga-ar3',
#  '3(disz) sila3 kasz 2(disz) sila3 ninda',
#  "1(bur'u) 6(bur3) 2(esze3) GAN2 sze gur10-a",
#  'GAN2 za3-mu-ba-ni-us2',
#  'sza3 bala-a',
#  'nita kal-ga',
#  '3(disz) gurusz u4 2(u) 5(disz)-sze3',
#  'sipa ansze',
#  'mu-na-du3',
#  'i3-dab5',
#  '2(disz) x niga {d}nin-urta',
#  '1(gesz2) 3(u) 4(asz) ninda gu 3(u) du8',
#  '4(asz) ur-ba-ba',
#  'gal-UN',
#  'szakir3{ki}',
#  '... x lu gu-za-ni ...',
#  'pu2-sig4 bahar2-ra',
#  '...-x u3 x-...',
#  '5(disz) sila3 kasz 5(disz) sila3 zi3 1(disz) id-gur2 i3',
#  '3(disz) sila3 SZIM gu4-ku-ru',
#  '1/2(disz) 4(ban2) ur-{d}ba-ba6 im',
#  'kiszib3 ensi2',
#  'nig2 szu du11-ga ...',
#  '...-x-a giszimmar ba-an-mu2',
#  'n 1(barig) 2(ban2) sila3 gur',
#  '2(disz) sila3 tu7 2(disz) ur-{d}szu-suen egir sukkal-mah',
#  'mu hu-uh2-nu-ri{ki} ba-hul',
#  'e-da-ti',
#  'mu {gesz}mar-gid2-da ku3-sig17',
#  'e2-ur3',
#  '1(asz) ziz2 gur',
#  'iri-ku3-...',
#  '2(u) sa gi',
#  '2(u) ma-na mangaga',
#  '{d}nin-gir2-su',
#  '3(disz) sila3 kasz 2(disz) sila3 ninda 5(disz) gin2 szum2 3(disz) gin2 i3 2(disz) gin2 naga',
#  'ki ur-{d}szul-pa-e3',
#  'sza3-bi-ta',
#  '5(disz) udu',
#  'lu2-ma2',
#  'lugal kal-ga',
#  '3(u) udu',
#  'u3-su-ub',
#  'mu en {d}inanna masz2-e i3-pa3',
#  '1(disz) dub-sa-du3 zabar',
#  '2(disz) kusz balag',
#  'giri3 lu2-{d}nin-gir2-su dumu e2-ki gu-za-la2',
#  'szunigin 1(gesz2) 1(u) 8(disz) gurusz',
#  '1(gesz2) 4(u) ku6 kun-zi saga',
#  '1(disz) gu4 niga 4(disz) udu niga',
#  '5(u) la2 1(disz) {gesz}u3-suh5 szu-dim2 ma2 3(u) gur',
#  'ugula lu2-dingir-ra',
#  '4(asz) 1(ban2) 3(disz) sila3 sze munu4',
#  '2(u) la2 1(disz) gu4 u2',
#  'en-zu',
#  '2(asz@90) ku3 sa10 gin2 dingir-lu2-mah2',
#  '... GAN2 a-sza3 ka-ma-ri2{ki}',
#  'ma2-lah4',
#  'lu2-{d}gesz-bar-e3 tug2-du8',
#  'x udu a-lum niga saga us2',
#  'szubur',
#  'u4 2(u) 8(disz)-kam',
#  'lu2-usz-gi-na szesz-gal',
#  '1(gesz2) gurusz u4 1(disz)-sze3',
#  '1(disz) udu {d}en-ki',
#  'lugal uri5{ki}-ma',
#  'iti gu4-ra2-bi2-mu2',
#  'e2 {d}en-lil2-ka',
#  '5(u) gil-kisal gid2 4(disz) 1/2(disz) ninda-ta',
#  'ki-la2-bi 1(disz) 2/3(disz) ma-na siki kur-ra {gesz}ga-rig2 ak',
#  '1(disz) ba-zi',
#  'dub-sar',
#  'tug2 ki-la2 tag-ga',
#  '... dur3 su-su ... la-ga-x-x',
#  'ta-sze-ni2-la2',
#  'e2 {d}szul-gi',
#  'igi i-me-ru-sza',
#  '...-x szu-x-x',
#  '2(barig) ...',
#  '1(disz) lugal-geszkim-zi dumu ur-{d}nin-urta',
#  'nig2-gu-sur',
#  '1(u) 1(disz) masz2',
#  '3(asz) 4(barig) 4(ban2) sze gur',
#  '1(disz) mu-ni-na-ga-me',
#  'gu-u2-gu-a',
#  'ur-eme2-ga',
#  'dumu du-du',
#  '5(u) 8(disz) ad7 udu u2',
#  'ma2 gid2-da',
#  '...-x-da-ri-a',
#  'sza3-bi-ta',
#  'ku-ku-a lu2 {gesz}tukul',
#  'nam-ha-ni dub-sar',
#  '8(disz) ur-{d}ba-ba6',
#  'ama-kal-la dam a-al-li2',
#  'giri3 ur-{d}szara2',
#  'giri3 lu2-{d}gesz-bar-e3',
#  '{d}amar-{d}suen',
#  'a2-ne2-kur-ra',
#  '1(ban2) dabin',
#  'dumu gaszam-e-ne du10-UD ha-ra-ab-ak-en',
#  '1(asz) 1(barig) 4(disz) x-...',
#  'iti dal',
#  '1(disz) gu4 amar ga',
#  'zah3 lu2-dingir-ra',
#  '1(asz) 3(barig) sze gur lugal',
#  '{d}urasz ku3-gin7 uszum su-lim-ma izi-gar husz il2-il2-i',
#  'e-na-szum2',
#  'giri3 szusz3 gu4-ke4-ne',
#  '1(disz) gu4 {d}nin-lil2',
#  'mu ... x ...{ki} ba-hul',
#  'lugal-a-ni',
#  '6(disz) tug2 du8-a siki {gesz}garigx(|ZUM.SI|) ak',
#  '1(asz) ur-{d}inanna',
#  '5(u) 1(disz) sar al',
#  '... kalam-ma dalla mu-ni-in-e3',
#  '2(u) 4(disz) tug2',
#  'ki szesz-kur-ra-ta',
#  'szul-utul12-am3',
#  'szunigin 8(disz) gu4 hi-a',
#  'mur-gu4 {d}szara2-sze3',
#  '1(u) 3(disz) kusz gu4',
#  'ubur an-na-ke4 si sa2-e-de3 giri17-zal ki us2-u3-de3',
#  '... ur-ki-gu-la',
#  '7(disz) sila4 ba-ur4 sag u8-sze3',
#  '1(barig) dabin a-ga-de3{ki}',
#  'lugal-a-ni',
#  '1(disz) udu',
#  'szunigin 7(gesz2) 1(u) 2(disz) udu u2',
#  '1(disz) udu',
#  'u4 1(disz)-kam',
#  '1(u) 5(asz) ninda',
#  'umma{ki}',
#  '2(u) 1(asz) 2(barig) 2(ban2) 4(disz) sila3 sze gur',
#  '4(ban2) kasz du',
#  '3(u) ma-na udu a gar-ra',
#  '2(disz) gin2 i3 2(disz) gin2 naga',
#  'iti szu-esz5-sza',
#  'lugal-inim-gi-na sukkal',
#  'sza3 e2-masz siki igi saga',
#  '{d}en-lil2-la2-ra',
#  'ezem ki garza-ka gesz-hur-bi ba-kur2',
#  '5(disz) sila3 kasz 5(disz) ...',
#  'ki {d}iszkur-gu2-gal',
#  '5(disz) sila3 kasz 5(disz) sila3 ninda 2(disz) sa szum2',
#  '5(ban2) 2(disz) sila3 ninda saga igi-5(disz)-gal2-bi 1(ban2) 1/3(disz) sila3 4(disz) gin2',
#  '1(disz) gukkal gesz-du3 babbar',
#  'sze-bi 2(u) 7(asz) gur',
#  'ensi2',
#  'e-la-a sukkal',
#  '1(u) 3(disz) udu niga saga us2',
#  '3(gesz2) sze gur lugal',
#  'u4 gu4 masz-da-re-a-sze3 im-gen-na-a',
#  'giri3 ur-mes szabra',
#  'giri3 {d}nanna-ma-ba dub-sar',
#  '1(gesz2) 1(u) 8(disz) sa gu gada x 9(asz) gu2',
#  '... x zu2-lum ... 1/2(disz) ...',
#  '1(u) 3(disz) u8',
#  'ki-en-gi ki-uri',
#  '3(gesz2) 3(u) 7(disz) udu 1(disz) 1/2(disz) sila3',
#  'szunigin sze dida-bi 4(u) 1(barig) 4(ban2) 4(disz) gur',
#  'i3-dab5',
#  '1(asz) kusz a-ba-mu-na',
#  '4(disz) gu4 niga saga 6(disz) sila3 sze 3(ban2) duh saga-ta',
#  'bala u4 1(u) 9(disz)-kam',
#  'mu hu-uh2-nu-ri{ki} ba-hul',
#  '5(disz) udu niga 1(disz) x niga 1(disz) sila4',
#  'engar sza3-gu4-me',
#  '4(barig) 2(ban2)',
#  '7(disz) gin2 ku3-babbar ziz2-da udu-sze3 ba-la2',
#  'szabra-e2 ug-ti-ke4',
#  'sze-bi 4(u) 8(asz) 2(barig) gur',
#  '|BAD3.AN|{ki}',
#  '4(disz) kusz gu4 al-hul-a',
#  '{gesz}mar-gid2-da',
#  'a-kal-la',
#  '3(disz) sila3 kasz 2(disz) sila3 ninda 5(disz) gin2 szum2',
#  '... s,i-i-ru sza2 AN-e u KI-ti3',
#  'szu ba-ti',
#  'lagasz{ki} 1(|ASZxDISZ|)',
#  'kiszib3 dab-ba',
#  'szunigin 1/2(disz) sila3 szum2 szunigin 1(u) 8(disz) gin2 i3 szunigin 1(u) 2(disz) gin2 naga',
#  '1(disz) ur-{d}lamma dumu ka-da',
#  'ugula ab-ba-gi-na nu-banda3-gu4',
#  'inim e2-i3-gara2',
#  '1(disz) masz2',
#  '5(u) 3(disz) sila3 kasz du',
#  '4(disz) gu4-gesz',
#  'lugal an-ub-da limmu2-ba',
#  '...-me he2-me-en',
#  '5(u) 1(disz) masz2 kiszib3 la-la',
#  '... gu4 szu-gid2',
#  '1(u) 1(asz) {gesz}ur3 tur-tur',
#  '3(disz) sila3 zi3 dub-dub',
#  'sza3-tam ARAD2-zu',
#  '2(iku) GAN2 szuku gab2-ra-ni',
#  'aga3-us2 lugal',
#  'kiszib3 nig2-...',
#  '... 4(asz) e2 x ...',
#  'mu ha-ar-szi ki-masz{ki} ba-hul',
#  '3(disz) gurusz szitim lu2 nig2-{d}ba-ba6',
#  'munus-me',
#  'lu2-usz-gi-na dumu ka5-a-mu',
#  'dumu lu2-gu-la',
#  'u4 nig2-dab5 ma2 nig2-sag-ga2-sze3 im-gen-na-a',
#  'dumu-ni-me',
#  'dumu lugal-ti-da',
#  'u3 ma2 ba-al-la',
#  'ku6 NINA{ki}-sze3',
#  'sze gurx(|SZE.KIN|)-a',
#  'u-bar',
#  'ki an-ki-ta',
#  '6(asz) ninda lugal-lu-ni x',
#  '3(ban2) gesztin had2',
#  'a-ra2 1(disz)-kam',
#  '{d}nin-gir2-su',
#  'a-sza3 e2-duru5 {d}inanna',
#  'mu ...-ba-ka dumu munus-a-ni ensi2 an-sza{ki}-na-ke4 ba-tuku-a',
#  'ki-la2-bi 2(asz) gu2 5(u) ma-na 5(disz) gin2',
#  'iti ezem-{d}dumu-zi',
#  '3(disz) gu4 4(disz) ab2',
#  '1(disz) sila4 ga nu-ur4',
#  'mu-de6 5(|ASZxDISZ|)',
#  'en-dingir-mu',
#  'dub-sar',
#  'a2 zi3 ar3-a',
#  'szu ba-ti',
#  'iti ezem-{d}szul-gi',
#  'zi-ga-am3',
#  '{d}nin-e11-e',
#  '1(gesz2) 1(u) 7(disz) {munus}asz2-gar3',
#  '2(disz) sila3 kasz 2(disz) sila3 ninda',
#  '{gesz}gaba-tab gid2-da',
#  'ur-{d}suen',
#  'ARAD2-zu',
#  'sza3 ki x ...',
#  'mu {gesz}gigir nu-sa2 ku3-sig17 {d}utu',
#  'dub-sar',
#  '1(disz) gu4 mu 1(disz)',
#  'ki-be2 mu-na-gi4',
#  'mu en eridu{ki} ba-hun',
#  'a-ab-ba-ka ambar ba-ni-ib2-dim2-dim2',
#  'ki siki-ke4-ne',
#  '1(ban2) ninda AB 6(disz) sila3 zi3',
#  'szu-nigin2 2(u) 6(disz) ninda bappir3 ba-an-ne2 1(u) du8',
#  'dumu ur-ku3',
#  'mu-kux(DU) s,e-la-szu',
#  'szu ba-ti',
#  '2(disz) gesz sza3 bala-a',
#  'gesz-gi{ki}',
#  'lugal-{d}isztaran',
#  'lugal larsa{ki}-ma',
#  'PAP-PAP-{d}nisaba',
#  'sipa x ...',
#  'lu2-kal-la',
#  'mu si-mu-ru-um{ki} ba-hul',
#  'mu {d}szu-{d}suen lugal',
#  '2(asz) asz-ni',
#  '3(gesz2) 5(asz) 1(barig) 5(ban2) sze gur lugal',
#  '1(az) {kusz}du10-gan bar-si sag10',
#  'ugula ur-{d}en-lil2-la2',
#  '1(disz) a-hu-ni dumu u3-ma-bi',
#  'en-ku3',
#  'x x sze gesz x',
#  'ugula ur-zigum-ma',
#  'u4 nig2 ha-lam-ma sa6-ga ku4-ku4 e-ne ib2-ta-an-gar-ra',
#  '1(disz) id-gur2 i3',
#  '1(asz) gu2 siki',
#  '2(u) ...',
#  'u4 gid2-da ge6 lugud2-da dam gesz-nu2-a mi-ni-ib-nu2-u3-ne',
#  'su:la2 utuwa',
#  '1(disz) ur-{d}isztaran',
#  'iti ezem-{d}szul-gi',
#  'kiszib3 lugal-e-ba-an-sa6',
#  'dumu lu2-sa6-ga',
#  'x-e-si-A2 ur-sag igi zalag-ga zu2-kesz2 gin6-ne2-...',
#  'ki ur-gu2-edin-na-ta',
#  'a-za-bu3',
#  'ugula ur-mes dumu ur-{d}asznan',
#  'szu ba-ti',
#  '1(disz) ma-la-ku udu',
#  'mu 3(disz)-am3',
#  'nin-a-ni ku3 {d}inanna-ke4',
#  'nin-{d}nir-nu-da',
#  'dub-sar',
#  'gesz-hur e2-a-na ma-ra-pa3-pa3-de3',
#  '4(barig) 4(disz) sila3',
#  '1(asz) udu',
#  '{d}inanna-ke4 {tug2}dara4 me 7(disz) gal4-la-na x DU x x',
#  'mu us2-sa bad3 ba-du3 mu us2-sa-a-bi',
#  '1(asz) kas sig15',
#  '1(asz) tul2-ta ...',
#  'kiszib3 ur-{d}suen',
#  'bara2-nam-tar-ra',
#  'szunigin 1(disz) ab2 szu-gi4',
#  'a-ra2 2(disz)-kam',
#  '1(asz) sze gur lugal',
#  '{gesz}kiri6 u8-udu-a{ki}',
#  'n u4-sze3 i3-gu7',
#  'szu-{d}nin-isin2{si}',
#  'e2 ki-ag2-ga2-ni',
#  '3(iku) ur-{d}{sze3}szer7-da',
#  'giri3 u2-du-...',
#  '1(disz) sila4 du 1(disz) masz2 du',
#  'ki na-ba-sa6-ta',
#  '6(gesz2) 7(asz) 2(barig) 5(ban2) 3(disz) sila3 sze gur',
#  'A 8',
#  '1(disz) gu4 libir-a',
#  '1(disz) masz2-gal niga',
#  'mu-kux(DU)',
#  'ba-ab-dab5',
#  'lugal an-ub-da limmu2-ba',
#  'lugal an-ub-da limmu2-ba',
#  'alan TE-ME-bi {d}lamma mah e2-ke4',
#  '1(u) 3(disz) udu masz2 i3-kal-la',
#  'bad3-bi ni2 te-ge26-mu he2-em-i mu-bi he2-em-mi-sa4',
#  '3(disz) sila3 kasz 2(disz) sila3 ninda 5(disz) gin2 szum2',
#  '1(disz) sila4 {d}nin-lil2',
#  'kiszib3 lu2-kal-la',
#  '1(ban2) 5(disz) sila3 lu2-hu-rim3',
#  'i-za-az-me-szar giri17-dab5',
#  'mu ku-ba-tum-sze3',
#  '1(u) 1(disz) gin2 igi-4(disz)-gal2 la2 4(disz) sze',
#  '1(asz) masz2',
#  'zi x-...',
#  'iti sig4 u4 2(u) 7(disz) ba-zal',
#  'mu {d}amar-{d}suen ur-bi2-lum{ki} mu-hul',
#  'tukum-bi lugal-me an-na-kam',
#  'a-ra2 1(disz)-kam',
#  '3(ban2) ra-szim-a-li2-ik',
#  'giri3-se3-ga ensi2-ka',
#  'kiszib3 lu2-{d}ha-ia3',
#  'nam-mah',
#  'a-ki-dingir-szu',
#  'ur-sag kal-ga',
#  'ma-gu10 ma-gu10-a de3-ma-ab-BU-ne',
#  'dub-sar',
#  'mu-na-du3-a',
#  '{d}szul-pa-e3 e2-gal',
#  'lul-da mu a2-na mu abzu-na in-pa3',
#  'ugula lu2-kal-la',
#  '... x gesz-...',
#  '1(disz) temen-da',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  '5(asz) 4(barig) 5(ban2) 5(disz) sila3 sze gur',
#  '2(u) kin-ki-bur-ra',
#  'iti sig4-{gesz}i3-szub-ba-ga2-ra',
#  'bala egir',
#  '{d}nin-gir2-su',
#  'mu en-mah-gal-an-na en {d}x ba-hun',
#  'iti sze-sag11-ku5',
#  'n szagax(|LU2xESZ2|)',
#  'gurusz-e gu-nigin2 3(disz)-ta',
#  'giri3 lu2-{d}nin-gir2-su szabra-e2',
#  'mu ki-masz{ki} ba-hul',
#  '2(u) ma-sab haszhur-duru5',
#  'x-me',
#  'dub-sar',
#  'mu en {d}en-lil2-la2',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  'ba-usz2 u4 1(u) 6(disz)-kam',
#  'sza13-dub-ba',
#  '1(disz) ur-{d}nansze',
#  'umma{ki}',
#  "3(gesz'u) 6(gesz2) 2(u) 3(disz) sar al 5(disz)-ta",
#  'lugal-a-ni',
#  '4(asz) lu2 1(barig)',
#  '2(disz) kusz udu 1(u) 5(disz) gin2 sze-gin2',
#  'szu ba-ti',
#  'szu-nigin2 3(iku) 1/2(iku) 8(disz) sar ki szum2-ma',
#  '3(asz) 3(barig) 5(ban2) 8(disz) 2/3(disz) sila3 x',
#  'iti szu-numun',
#  '1(disz) ur-sag-ub3{ki} szesz-gal',
#  'i7-pa-e3 dumu lugal-uszurx(|LAL2.TUG2|)',
#  'a-sza3 ...',
#  'kiszib3 ensi2',
#  '1(disz) sila4',
#  'mu-na-du3',
#  '3(disz) ma2 1(gesz2) gur 2(ban2)-ta ma2-lah5-bi i3-ib2-u3',
#  '3(ban2) kasz dida en-um-i3-li2',
#  'ga2-nun sanga-ta',
#  'iti imin-kam zal-la-ta',
#  'i7 uri5{ki}-ma',
#  'kiszib3 {d}szara2-kam',
#  'iti ...',
#  'n 2(barig) 5(ban2) sze gur',
#  'kiszib3 ur-{d}nin-gesz-zi-da dumu engar-du10',
#  'ensi2',
#  'szunigin 1(disz) e2 asz gesz BAD',
#  'zi-ga',
#  '3(u) 3(asz) siki bar udu',
#  'e ki-sur-ra',
#  'a2-bi u4 1(gesz2) 4(u) 1(disz)',
#  '4(asz) gu2 gi',
#  'e2 gir2-su{ki}-ka-ni',
#  'dumu ku3-...',
#  'szu-a gi-na',
#  'kiszib3 a-da-ga',
#  'mu {d}amar-{d}suen lugal',
#  '1(disz) la-gi-ip',
#  'ki e2-gal-e-si-ta',
#  '4(asz) ne-sag',
#  'dumu ip-szu-ta',
#  '5(disz) erin2 bala du3 1(u) 4(disz) erin2 bala tusz',
#  'ugula bu3-ka-szuba3',
#  '... e2-na-lu-lu',
#  'u4 1(disz)-kam',
#  '... a-hu-szu-ni',
#  '4(disz) sa gu4 4(disz) kun gu4',
#  'ensi2',
#  'nigin-ba 1(disz) ansze',
#  '... gi-rin-na lal3-e x x x mu-nu2-a',
#  'nibru{ki}-ta gen-na',
#  '{d}nanna-kam sukkal maszkim',
#  'x. ugu2-a ga2-ga2',
#  'gug2 i3-nun-ta he2-em-da-gu7-e',
#  'GAN2 ab-ba-szim',
#  '|BAD3.AN|{ki}-ta',
#  'sa2-du11 kas sig15-kam',
#  'absin3-bi 2(u)',
#  'sze-bi 4(ban2) 5(disz) sila3',
#  'lugal {d}en-lil2-le',
#  '3(ban2) nam-nin-an-na-gam-gam',
#  '2(asz) 2(barig) ba-ha-an-sze-er',
#  '... gu2-na ur-{d}...',
#  'ha-am-mu-ra-pi2 x-a-ni x ...',
#  'i3-dab5',
#  'ki ur-{d}nanna-ta ba-zi',
#  'u3-na-a-du11',
#  'ki u2-sze3-he2-du-ta',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  'mu a-ra2 2(disz)-kam kar2-har{ki} ba-hul',
#  '4(ban2) 8(disz) 1/2(disz) sila3 dabin',
#  '2(u) sar-ta',
#  'mu ur-bi2-lum{ki} ba-hul',
#  '1(disz) i3-li2-mi-szu2',
#  '...-sze3',
#  'mu-na-du3',
#  'A 134d',
#  '1(disz) gu4 niga',
#  'dumu na-wi-ir-dingir',
#  '9(disz) geme2 kikken2 e2-kuruszda',
#  'x kusz udu babbar2',
#  'kas4 i3-dab5',
#  'dumu-la-bu dumu ga-du ra2-gaba',
#  '5(disz) sar e2 du3-a',
#  '...-ka ...',
#  'a mu-na-ru',
#  'mu e2-gal-la-a-sze3',
#  '6(asz) nin-uri3',
#  'szu ba-ti-esz',
#  '{u2}urua{a}{ki}-ta du-ni',
#  'ki-ag2 uri5{ki}-ma',
#  'dumu ...',
#  'n 2(asz) 4(ban2) gur ur-{d}ba-ba6 engar',
#  '3(disz) sila3 kasz du',
#  'n udu kur ur-{d}isztaran',
#  'ugula usz-bar',
#  '1(disz) kiszib3 za-gin3 ka-ba ku3-sig17 gar {kusz}ib2-be2 ku3-babbar',
#  '4(gesz2) 1(u) 5(disz) udu niga',
#  '2(gesz2) 8(asz) masz sza3-du10',
#  'na-ru2-a-bi',
#  '1(asz) 3(ban2) 3(disz) nin-a-e2-ta',
#  'ur-e2',
#  '{kusz}lu-ub2 szi-...',
#  '3(gesz2) 3(u) 7(disz) 1/2(disz) nu-banda3 lugal-igi',
#  '1(asz) gu2 siki du',
#  'zur-zur',
#  'szunigin 2(ban2) 1/3(disz) sila3 za3-hi-li',
#  'mu en {d}inanna unu{ki}-ga masz2-e i3-pa3',
#  '1(disz) ansze 2(disz)',
#  '2(disz) tug2 nig2-lam2 3(disz)-kam us2',
#  'a-sza3 ... us2-sa a-sza3 x x x',
#  'engar ma-gu-ul',
#  'szunigin 1(disz) dumu-munus 1(ban2)',
#  '1(barig) ur-{d}nin-mar{ki}',
#  'n sze n gu2',
#  'bala ur-{d}lamma ensi2 gir2-su{ki}-ka ba-an-zi',
#  '3(iku) GAN2 lugal-lu2',
#  'sza3 umma{ki}-sze3',
#  'ur-{d}nin-gesz-zi-da',
#  '{d}i-bi2-{d}suen-dan-le-ga-du maszkim',
#  'mu e2 {d}szara2 ba-du3',
#  "1(bur'u) GAN2 sze gurx(|SZE.KIN|)-a x-ke4 la2-a",
#  'u4 2(u) 8(disz)-kam',
#  'ugula da-da',
#  '1(bur3) 1(esze3) GAN2 1(u)-ta',
#  'x ... lugal-szu-nir-e',
#  'ad-gi4',
#  '1(disz) lugal-dub-la2',
#  'u4-da inim-ba',
#  'e2-na',
#  'lugal uri5{ki}-ma-ke4',
#  '2(asz) sila4',
#  'ki a-gu-ta',
#  'dingir-ra-bi2 lu2 kin-gi4-a lugal',
#  'abul {d}lugal-gu4-si-su',
#  'a-na i3-li2-za',
#  '2(disz) sila3 esza',
#  '1(barig) lugal-me-lam2',
#  'szesz-kal-la i3-dab5',
#  'sa2-du11 e2-si-bil',
#  'iti {d}li9-si4',
#  '{d}szu-{d}suen',
#  'nu-mu-gal2',
#  '1(disz) {d}szara2-a-mu ugula',
#  '3(disz) eme6-mah2',
#  'n 1(disz) 1/2(disz) gurusz gi zex(SIG7)-a 2(u) sar-ta',
#  '{d}nin-du6-babbar-ra',
#  'zi-ga',
#  '2(iku) 1/2(iku) nagar-gal (x)',
#  'i3-gal2',
#  'libir-am3',
#  '5(disz) sila3 kasz 5(disz) sila3 ninda 2(disz) sa szum2',
#  'lugal uri5{ki}-ma',
#  '3(ban2) kasz du u4 2(u) 8(disz)-kam',
#  'iti 1(u) 1(disz)-kam',
#  'iti pa4-u2-e',
#  'mu {d}i-bi2-{d}suen lugal uri5{ki}-ma-ke4 si-mu-ru-um{ki} mu-hul',
#  'sze-bi 2(gesz2) 5(asz) 3(ban2) gur',
#  'lu2-me-lam2',
#  '1(disz) ma-na im-babbar2',
#  'nam-ti',
#  '1(disz) sila4 {d}nanna',
#  'bur-sag-me',
#  '1(barig) 9(disz) sila3 ninda gal du 1(disz) sila3 duh',
#  'lugal an-ub-da limmu2-ba-ke4',
#  '2(ban2) giri3 lu2-{d}nin-szubur',
#  '5(disz) sila3 kasz saga 3(disz) sila3 ninda',
#  '2(barig) 4(ban2) amar-amar',
#  'gir4-bil-me',
#  '1(disz) a-gu-gu',
#  'dumu lugal-nam-tar-re',
#  'a-szi-an i3-dab5',
#  '5(asz) uruda ma-na',
#  '1(asz) mu-mu',
#  '1(asz) szu-ku6 5(disz)',
#  'lagasz{ki}-ka 4(|ASZxDISZ|)',
#  'u4-ba',
#  'mu {d}szu-{d}suen lugal ma2-gur8-mah {d}en-lil2 {d}nin-lil2 mu-ne-dim2',
#  'uru2-za-gu2',
#  'en {d}inanna',
#  'ki-la2-bi 3(disz) ma-na 1(u) gin2',
#  'ki {d}utu-mu-ta',
#  'x kiszib3 za-gin3',
#  '5(u) 8(asz) 4(ban2) 5(disz) sila3 gur',
#  'mu-kux(DU) x-x-... ensi2 ...',
#  'ur-nigar{gar}',
#  'sza3-gal {ansze}kunga2',
#  'x x x la im-...',
#  'esz3-ta gur-ra sa2-du11',
#  'szunigin 5(u) la2-ia3',
#  '1(asz) NI |MU+UD|',
#  'nig2-gur11 ...',
#  'u4 3(disz)-kam',
#  'sze-ba',
#  '2(bur3) GAN2 a-sza3 sipa',
#  '{d}szul-pa-e3 na-nam al-tar mu-un-da-an-gub',
#  'i-ni-in-gar-ra-a',
#  '1(disz) sa szum2',
#  'ki i3-du8 gal-ta',
#  'ugula {d}szara2-kam',
#  'a-ma-ru-kam',
#  'ARAD2-zu',
#  'gu3-de2-a',
#  'kiszib3 ur-{d}ba-ba6 dumu lugal-szuku',
#  'lagasz{ki}-ke4',
#  'masz a-sza3-ga',
#  '{gisz}i-ri9-na-bi musz-sag-kal-x',
#  '5(disz) sila3 kasz 3(disz) sila3 ninda 3(disz) gin2 szum2 3(disz) gin2 i3 2(disz) gin2 naga',
#  'eb i7 edin-na',
#  'sze-bi 3(asz) gur',
#  'lugal-...',
#  'lu2-du10-ga',
#  '1(gesz2) kusz masz2-gal',
#  'ga2-gi4-ta',
#  'igi 6(disz) en-edin-ne2',
#  'lu2 hun-ga2-me',
#  '8(gesz2) 4(u) gab2-IL2 ku6 nig2-ki 1(barig) 5(ban2) 5(disz) sila3-ta',
#  'i-di3-a',
#  'u4 1(u) 1(disz)-kam',
#  '1(disz) dug gal kasz du',
#  'u3-na-du11',
#  '1(gesz2) 2(asz) 1(ban2) gur',
#  'sa-bu-um{ki}-ta du-ni',
#  'mar-sa-asz-sze3',
#  'dingir-ba-ni',
#  'kiszib3 lu2-sa6-i3-zu',
#  'iti sze-sag11-ku5',
#  'aszgab',
#  'ur-nigar{gar}',
#  'ur-usz-gid2-da dam-gar3',
#  'bala du10 nig2-si-sa2',
#  'mu ha-am-mu-ra-pi2 lugal an {d}inanna {d}na-na-a-a e-ne-bi-ta',
#  '1(barig) 4(disz) bu3-ka',
#  'iti gu4-ra2-bi2-mu2-mu2',
#  'x dur3 1(disz) sag x-sze3',
#  'kiszib3 nu-tuku',
#  'i3-dab5',
#  'gurum2 ak u4 1(u)-kam',
#  'u3 IL2 ansze kunga2-me',
#  'ugula ur-mes',
#  'sanga {d}ga2-tum3-du10',
#  '1(disz) gi ma-an-sim nig2-ar3-ra',
#  '...-ne e2-bi e2-babbar',
#  '1(barig) 2(ban2) 7(disz) sila3 kasz du',
#  'gur zabar-ta',
#  'nu-banda3 ur-{d}ba-ba6',
#  "1(gesz'u) 2(gesz2) 2(u) 7(disz) sa gi kiszib3-bi 6(disz)-am3",
#  'kiszib3 ensi2',
#  'mu {d}szu-kak-ka3 lugal-e iri za-gin3 ku3-sig17 {d}dam-gal-nun-na-ra mu-na-dim2',
#  '1(asz) 1(barig) 3(ban2) ninda gur',
#  'e2-uz-ga',
#  'ka2',
#  'ki gu3-de2-a-ta',
#  'a-sza3-bi 6(bur3) GAN2',
#  '1(u) 1(asz) 1(disz) lu2 1(barig)',
#  '2(u) 1(disz) kusz udu siki mu2',
#  '6(disz) gin2 si-im-du3(NI) dah-ha',
#  '{d}en-ki a tu-da-ni',
#  'ki ur-{d}szara2 ...',
#  '2(gesz2) gir{ku6}',
#  'zar2-ra-a',
#  '2(disz) udu niga 4(disz)-kam us2',
#  '{d}en-lil2-la2-ra',
#  '3(barig) gig lugal',
#  '1(u) 2(asz) geme2 kikken',
#  '4(ban2) sze 4(ban2) ziz2',
#  '2(disz) gin2 i3',
#  'ki lu2-e2-an-na-ta',
#  '... in-nu tesz2 ...',
#  'adkin szeg9',
#  'ki {d}szara2-kam-ta',
#  'iti ezem-{d}me-ki-gal2',
#  'iti 1(disz)-kam',
#  '2(asz) 2(barig) lugal-sza3',
#  '1(barig) 2(ban2) gur kal',
#  '1(disz) tug2 guz-za 4(disz)-kam us2',
#  'e2-a-ni mu-na-ni-kux(KWU147)',
#  'kas3-pu-sza lu2 kin-gi4-a lugal',
#  '1(disz) sila4',
#  'ki bi2-du11-ga-ta',
#  'e2-da',
#  '... su-bala',
#  '1(disz) udu niga ki-a-nag ur-{d}namma',
#  '1(u) 4(disz) ninda gid2 4(disz) sar-ta',
#  'iti u4 1(u) 5(disz) ba-zal',
#  "szunigin 1(bur'u) 5(bur3) 2(esze3) 2(iku) 1/2(iku) GAN2 masz nu-tuku",
#  'lugal-a-ni',
#  '1(gesz2) ninda 2/3(asz) kasz 5(ban2) dan-num2',
#  'ki-la2-bi 3(u) 6(disz) 1/2(disz) ma-na 5(disz) gin2',
#  'e2-gal-e-si',
#  'ugu2 ad-da-gu-ka ba-a-gar',
#  '{d}szu-{d}suen',
#  'szunigin 4(disz) sila3 esza',
#  '1(disz) szesz-kal-la',
#  '... ki x ...',
#  '1(u) 8(disz) 1/2(disz) ninda 5(disz) kusz3 kur hi',
#  'n 2(disz) lugal-a-ni-x',
#  'di4-di4-la2 ur2 ama-bi ne-a ku6-sze6 a ba-ab-...',
#  'iti {gesz}apin-du8-a',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  '2(disz) sila3 lu2-{d}utu maszkim',
#  'lu2 e2-ninnu',
#  'A 93',
#  '1(disz) amar-masz-da3 e2-uz-ga',
#  'ur-PA-ke4',
#  'gaba-ri',
#  'mu {d}szu-{d}suen lugal',
#  'nam-szub eridu{ki}-ga pazur5-pazur5 mu-silig-e abzu-a',
#  'mi2-gu10 di nig2-ge-na-ka ka-ga14 mu-szi-gal2',
#  'e2-ninnu anzu2{muszen}-babbar2-ra-ni',
#  'gesz-gi4-gal2-bi-im',
#  '4(disz) sila3 lu2-{d}nanna',
#  'a-bi2-si2-im-ti',
#  '|KI.LUGAL.GUB| til3-la-da ni2 teg3-ge26-da-ne2-esz gur-gur-re-da-ne2-esz',
#  'nig2-la2-sag-ku6',
#  '1(asz) tug2 ib2-du3 udu sze gu7-a',
#  'szunigin 7(asz) ansze',
#  'dumu lugal-ku3-ga-ni',
#  'sze-bi 1(u) 4(asz) 4(barig) 3(disz) 1/3(disz) sila3 gur',
#  '1(ban2) al-mu',
#  'zi-ga',
#  'n ... lugal-nig2',
#  'ki lu2-dingir-ra-ta',
#  '3(disz) sila3 kasz 2(disz) sila3 ninda 5(disz) gin2 szum2 3(disz) gin2 i3 2(disz) gin2 naga',
#  '1(u) 2(asz) 4(barig) 3(ban2) 6(disz) sila3 gur',
#  'ki ur-{d}li9-si4-ta',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  ...]

# %%
lines
# Out:
# ['sag-ki hu-mu-ra-ab-zalag-ge',
#  'ki na-sa6-ta',
#  'iti szu-numun-ta',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  'ba-de6',
#  'mu us2-sa ki-masz{ki} ba-hul',
#  '1(asz) gu4 ab2',
#  '1(barig) 1(ban2) 5(disz) 1(disz) 1/2(disz) geme2-{d}szul-pa-e3 dumu-ni',
#  '1(asz) 2(ban2) nam-nin-...',
#  'dumu ur-{d}nansze',
#  'gu4 udu niga u2-sa',
#  'e2 kiszib3-ba-kam',
#  '1(disz) du-du-am3 u3 lugal-ba-tuku',
#  '{d}nin-sun2',
#  'nig2-du7-e pa mu-na-e3',
#  '2(ban2) ...',
#  'dub-sar',
#  '1(disz) {munus}asz2-gar3',
#  '8(disz) sila3 4(disz) gin2 tab-be-li2 u3 dan-num2',
#  'dumu lu2-ga',
#  'ur-kalam na-gada i3-dab5',
#  '1(disz) munu4 si-e3',
#  '1(u) 2(disz) gaszam',
#  '2(gesz2) 3(u) 7(disz) udu 1(disz) sila3',
#  'dub-sar',
#  '5(disz) 1/2(disz) ma-na 5(disz) gin2 siki tug2 guz-za 3(disz)-kam us2',
#  '5(ban2) 1(u) ba-at-ri',
#  '2(disz) sila3 nig2-ar3-ra saga',
#  '4(u) ka-dug ku3-babbar',
#  'e2-masz-sze3',
#  'ur-ma-ma lu2 bu3',
#  'iti pa4-u2-e',
#  'szunigin 1(disz) la2-ia3',
#  '4(ban2) nin-tesz2-mu',
#  '1(disz) szul-lu5 nu-{gesz}kiri6',
#  'n gu2 siki tug2 guz-za du',
#  '... nin-a-zu',
#  'szunigin 7(disz) gu4 mu 2(disz)',
#  '{d}inanna',
#  'dumu ur-e2-ninnu',
#  '1(disz) i3-li2-an-dul3',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  '1(barig) ama-na',
#  'szunigin 8(disz) dumu 1(ban2) 5(disz) sila3-ta',
#  'din |SZE.NUN&NUN|{+i-ti-sze-x}',
#  'iti ezem-{d}dumu-zi',
#  'szu ba-an-ti',
#  'du11-ga-ni si bi2-sa2',
#  '1(u) 8(disz) gurusz gub-ba la2-ia3 1(u) 5(disz)',
#  'kasz-de2-a ur-{d}iszkur ensi2 ha-ma-zi2{ki}',
#  'mu-na-ba-al',
#  'lu2-kal-la',
#  'sza3-ge engar',
#  '4(barig) ama-masz-min3',
#  'lugal an-ub-da limmu2-ba',
#  'szunigin 3(gesz2) 4(asz) 3(barig) 2(ban2) gur',
#  '5(asz) zi3',
#  '2(disz) sila3 ur3-re-ba-du7',
#  'ki e2 {d}nanna',
#  '1(asz) us2 e2-engur-ka',
#  'bahar3-e-ne szu ba-ab-ti',
#  'mu us2-sa bad3 ma-da ba-du3',
#  '... gur',
#  'ur-e2-an-na',
#  '5(disz) gu2 {u2}nin9',
#  '1(u) 2(asz) ur-gu-la',
#  'dub-sar',
#  'iti GAN2-masz',
#  'dumu nin-iri-ni-sze3',
#  'sza13-dub-ba-ka',
#  'dumu ba-zi',
#  'mu ur-bi2-lum{ki} ba-hul-sze3',
#  'lagasz{ki}-ke4',
#  'ki-la2-bi 2(asz) gu2 2(u) 4(disz) ma-na',
#  'sa2-du11 {d}nin-sun2',
#  'diri x tug2 guz-za x',
#  '1(disz) udu',
#  'szunigin 4(bur3) n GAN2',
#  'tug2 ki-la2 tag-ga',
#  'mu ma-da za-ab-sza-li{ki} ba-hul',
#  'giri3 ri-ib-hu-ti',
#  'mu en ga-esz5{ki}',
#  'iti diri me-ki-gal2 u2-sa',
#  '1(disz) udu niga 4(disz)-kam us2',
#  'szesz-da-da sanga',
#  'x x-na-sze3 ba-ra-da-du-de3-en',
#  '1(asz) geme2 3(ban2)',
#  'lugal uri5{ki}-ma',
#  '2(ban2) ga-ar3',
#  '{d}gesztin-an-na',
#  '{d}szul-gi',
#  '4(disz)',
#  'szunigin 2(asz) 3(ban2) nig2-ar3-ra saga gur',
#  'ki szu-{d}nin-kar-ak-ta',
#  '1(disz) kusz udu a-gar gu7-a',
#  'ki {d}iszkur-illat-ta',
#  'ugula ur-{d}nin-su',
#  'kiszib3 ur-{d}nun-gal',
#  'ganun ka i7 tum-al-ta',
#  '1(gesz2) 3(u) 3(asz) gesztin gal-gal',
#  '1(asz) kinda',
#  '2(u) 3(ban2) gur 5(disz) sila3 sze du',
#  'dab6-ru-um{ki}-ma ba-an-sa6',
#  'u3 gag',
#  '5(asz) 3(barig) 2(ban2) ur-{d}ba-ba6 dumu ur-nig2',
#  'dumu lugal-{gesz}kiri6',
#  '1(disz) sila4 kiszib3 ur-{d}en-ki kuruszda',
#  'dumu-munus-a-ni',
#  'an-na-ag2',
#  'iti nesag',
#  'naga-bi 1(barig) 1(ban2) 1/2(disz) sila3',
#  'giri3 lu2-{d}nanna dumu ba-ba',
#  'iti ezem-{d}...',
#  'szu-{d}suen',
#  'zi-ga',
#  'RU-lugal-me',
#  'mu mu-na-sa4',
#  'ka ba-ab-kesz2',
#  'mar-sa-asz mu-kux(DU)',
#  'u4 1(u) 3(disz)-sze3 ka-sahar-ta',
#  '2(asz) MI-si4-ad',
#  'mu ki-masz{ki} u3 hu-ur5-ti{ki} ba-hul',
#  '1(esze3) 4(iku)',
#  '5(asz) sze gur lugal',
#  '1/3(disz) ma-na x gin2 ku3 sze x x',
#  'baharx(EDIN)-ri',
#  'iti 1(disz)-kam',
#  '6(disz) 1/2(disz) gin2 6(disz) sze ku3',
#  'iti {d}dumu-zi-sze3',
#  'ugula ur-mes',
#  '{d}nin-gir2-su',
#  'gesztu2 dagal nig2-nam gal-le-esz zu',
#  'gu-nigin2-bi 7(gesz2) 2(u) 7(disz) 5/6(disz)',
#  'an-nu-ni-tum',
#  '2(u) {uruda}gur10 a-ra2 2(disz)-kam',
#  'ka-ma-ri2{ki}-ta',
#  '2(bur3) 1(esze3) la2 1/2(iku)',
#  'udu 1(asz)-sze3',
#  '1(disz) a-kal-la dumu e2-an-ne2',
#  'sipa gu4 niga',
#  '1(barig) e2-ki-bi',
#  'sa2-du11 ki-a-nag sza3-ba-na-sig szabra',
#  'gaba-ri',
#  'giri3 a-gu-a-ni dub-sar',
#  '1(gesz2) 1(u) 1(disz) x gur',
#  '1(asz) udu {d}en-...',
#  '1(asz) ni-ni',
#  'lu2-kal-la',
#  'e2-muhaldim-sze3',
#  'szunigin 4(asz) ansze ...',
#  '1(asz) ...',
#  '2(ban2) zi3-gu',
#  'iti sze-sag11-ku5',
#  'lu2-{d}ba-ba6 engar',
#  'maszkim-bi',
#  '{gi}dur sa',
#  'a-ru-a lu2-kal-la',
#  'an-na-ah-i3-li2 aszgab',
#  '1(esze3) lunga',
#  'kiszib3 szesz-kal-la',
#  'kisal-luh abzu',
#  'an-na-szum2',
#  'kusz-bi e2-gal ba-an-kux(KWU147)',
#  'ba-zi',
#  '2(ban2) kasz du',
#  '4(disz) amar az',
#  'zi-bi gaba-bi i-im-il2-il2',
#  '1(disz) udu niga',
#  'ki {d}mu-ul-lil2-da x KU IM DI-en',
#  'ur-{d}gu-nu-ra',
#  'n tug2 sza3-ga-du3',
#  'ki-a-nag szabra',
#  'ugula ukken-ne2',
#  '1(disz) sila4',
#  '2(disz) dusu2-nita2',
#  'a2 gesz-gar-ra',
#  'mu-tu',
#  '7(asz) gu2 2(u) 8(disz) ma-na 1(u) 5(disz) gin2 siki us2',
#  '3(u) 2(asz) 4(barig) 4(ban2) 5(disz) iti u5-bi2{muszen}-gu7',
#  'mu {d}amar-{d}suen lugal ur-bi2-lum mu-hul',
#  'mu us2-sa ki-masz{ki} ba-hul mu us2-sa-a-bi',
#  'ki szum2-ma GAN2 du5-uh2-ka-ta',
#  'iti sze-sag11-ku5',
#  'zi-ga',
#  'i3-dab5',
#  'szu-gid2 e2-muhaldim',
#  '1(u) 8(asz) 4(barig) 1(ban2) 4(disz) sila3 kasz saga gur',
#  'lugal uru16',
#  'ki szabra-ta',
#  'ki nu-ur2-{d}iszkur-ta',
#  'dub-sar',
#  '1(disz) lu2-dingir-ra ugula kikken',
#  'nibru{ki}',
#  '2(ban2) zu2-lum',
#  'inim-ma-ni i3-til',
#  'ki a-gu-ta',
#  '2(u) 9(asz) gu2 gi-ru-usz',
#  '3(u) la2 3(asz) u8',
#  '3(disz) sila3 kasz du',
#  '{gesz}gigir u4 6(disz)',
#  '1(u) gig gur sag-gal2',
#  'sa2-du11 u4 2(disz)-kam',
#  'mu si-mu-ru-um{ki} ba-hul',
#  '2(asz) n e2-...',
#  'kiszib3 {d}lamma-iri-na',
#  '5(disz) sila3 i3-gesz',
#  '1(disz) gurusz aszgab iti 1(disz)-sze3',
#  '3(ban2) 3(disz) nin-di-...',
#  'gal-sze3 de6-a',
#  'ma2 gid2-da ma diri-ga',
#  'giri3 nu-ur2-{d}iszkur dub-sar',
#  '2(esze3) ugula',
#  '6(disz) ku6 {gi}hal 1(barig)-ta',
#  'la2-ia3-am3',
#  '1(disz) bu3-ha-li2-li2',
#  'kiszib3 a-gu',
#  'dumu i3-kal-la',
#  'ki {d}iszkur-illat-ta',
#  '1(asz) 1(barig) gur geme2-{d}li9-si4 dumu ur-ku3',
#  '1(u) 6(asz) geme2 3(ban2)',
#  'x x da-bu',
#  "5(gesz'u) 9(gesz2) 3(u) sa gi",
#  '2/3(disz) sar 1/2(disz) gin2 e2 du3-a da e2 sib2-ta-na',
#  'geme2 szah2 nig2-gu7-a me',
#  '{gesz}gu-za munus pa-pah x ...',
#  '3(disz) udu 1(disz) masz2-gal',
#  '2(disz) gu4',
#  'mu lugal i3-pa3',
#  'ku3-bi ... 4(disz) gin2 ...',
#  'e2-ki-bi szesz-gal',
#  '1(disz) sila3 esza 2(disz) sila3 dabin',
#  'u3 lu2-{d}ba-ba6 dub-sar',
#  'zi-ga bur-sag',
#  'ti-la tu-ra-mu za-da i3-gal2 nam-mah-zu ga-am3-du11',
#  'lu2-kal-la',
#  '1/2(asz) x-x-LUM',
#  '{d}nin-da-sa2',
#  '1(gesz2) nigin2 pa-ku5',
#  '1(barig) gan-ezem',
#  'ba-zi',
#  '4(disz) sila4-nita2',
#  "szunigin 1(gesz'u) 1(gesz2) x 1(ban2) x gur",
#  'ma-ha-ar-ka',
#  'sza3-bi-ta',
#  'ensi2',
#  'szunigin 3(u) 5(disz) udu hi-a',
#  'kiszib3 a-kal-la',
#  'iti sze-sag11-ku5',
#  '1(barig) {d}en-lil2-bad3',
#  '... lu2-nisi',
#  'mu en-unu6-gal {d}inanna ba-hun',
#  '5(disz) sila3 kasz 3(disz) sila3 ninda',
#  '1(disz) ku6 1(disz) sa szum2',
#  'dumu ur-nigar{gar} szusz3',
#  '1(disz) gin2 ku3-babbar',
#  'um-ma-num2{ki} {gesz}tukul ba-sag3',
#  'szunigin 4(ban2) 1(disz) sila3 kasz 1(disz) kasz dida du 1(ban2) 5(disz) sila3',
#  'lugal-ni2-zu',
#  'sa2-du11-am6',
#  '2(disz) sila4 nu-ur4 diri',
#  'iti ezem-{d}li9-si4',
#  'bur2 balag',
#  'u4 da-ri2-sze3',
#  '3(ban2) su6-mu2',
#  'erin2 diri-ta',
#  '{d}lamma szu-a gi4-gi4',
#  '5(disz) sila3 kasz 3(disz) sila3 ninda 3(disz) gin2 szum2 3(disz) gin2 i3 2(disz) gin2 naga',
#  'u4 an-ne2 {d}en-lil2 {d}nanna {d}utu-bi',
#  'ki a-kal-la',
#  'ur-dingir-ra',
#  '3(asz) ...',
#  '1(barig) sze ur-gu-nu-um',
#  'iti masz-da3-gu7',
#  'mu en {d}nanna ba-hun',
#  'szunigin 2(u) 3(disz) dur3',
#  '2(disz) gin2 i3',
#  'geme2 3(disz)-e u4 1(disz)-a szu si 6(disz)-am3 i3-da6-da6',
#  '1(u) 3(asz) la2 1(ban2) gur',
#  'nig2-ezem-ma ezem pa4-u2-e',
#  'lugal-i3-mah sagi maszkim',
#  'mu us2-sa {d}szu-{d}suen lugal',
#  '3(disz) udu niga {d}inanna',
#  'lu2-sa6-ga',
#  'dam-dingir-mu',
#  '...-la dub-sar',
#  'e2-kikken-ta',
#  '1(asz) 1(barig) 4(ban2) 2(disz) sila3 la2 5(disz) gin2 i3-gesz',
#  'ku6-ra im-... DU NE mu-un-na-dub2-e',
#  'a2 erin2-na-bi u4 2(gesz2) 2(u) 4(disz)-kam',
#  '{d}suen-al-su3',
#  '1(ban2) 5(disz) sila3 ... x mu x x',
#  '1(disz) dida du',
#  'A 36',
#  'AN bulug4 bur',
#  'lugal an-ub-da limmu2-ba',
#  '{d}nin-lil2',
#  '4(ban2) nin-lu2-mu',
#  '3(disz) ab2-mah2 7(disz) gu4-gesz',
#  'lugal an-ub-da limmu2-ba',
#  'i7-da gub-ba-me',
#  'giri3 lugal-a2-zi-da dub-sar',
#  'za3-gu2-la2-sze3',
#  'ki na-ba-sa6-ta',
#  'dub-sar',
#  'he2-na-ab-szum2-mu',
#  'lu2-{d}nin-szubur dumu-gu4-gur',
#  '1(asz) dug kas ge6',
#  '1(disz) amar gu4 ur-{d}dumu-zi-da',
#  '{d}szul-gi-iri-mu',
#  'mu mar-tu ba-du3',
#  '... gin2 i3',
#  '1(ban2) 5(asz) sila3 ga-ar3',
#  '3(disz) sila3 kasz 2(disz) sila3 ninda',
#  "1(bur'u) 6(bur3) 2(esze3) GAN2 sze gur10-a",
#  'GAN2 za3-mu-ba-ni-us2',
#  'sza3 bala-a',
#  'nita kal-ga',
#  '3(disz) gurusz u4 2(u) 5(disz)-sze3',
#  'sipa ansze',
#  'mu-na-du3',
#  'i3-dab5',
#  '2(disz) x niga {d}nin-urta',
#  '1(gesz2) 3(u) 4(asz) ninda gu 3(u) du8',
#  '4(asz) ur-ba-ba',
#  'gal-UN',
#  'szakir3{ki}',
#  '... x lu gu-za-ni ...',
#  'pu2-sig4 bahar2-ra',
#  '...-x u3 x-...',
#  '5(disz) sila3 kasz 5(disz) sila3 zi3 1(disz) id-gur2 i3',
#  '3(disz) sila3 SZIM gu4-ku-ru',
#  '1/2(disz) 4(ban2) ur-{d}ba-ba6 im',
#  'kiszib3 ensi2',
#  'nig2 szu du11-ga ...',
#  '...-x-a giszimmar ba-an-mu2',
#  'n 1(barig) 2(ban2) sila3 gur',
#  '2(disz) sila3 tu7 2(disz) ur-{d}szu-suen egir sukkal-mah',
#  'mu hu-uh2-nu-ri{ki} ba-hul',
#  'e-da-ti',
#  'mu {gesz}mar-gid2-da ku3-sig17',
#  'e2-ur3',
#  '1(asz) ziz2 gur',
#  'iri-ku3-...',
#  '2(u) sa gi',
#  '2(u) ma-na mangaga',
#  '{d}nin-gir2-su',
#  '3(disz) sila3 kasz 2(disz) sila3 ninda 5(disz) gin2 szum2 3(disz) gin2 i3 2(disz) gin2 naga',
#  'ki ur-{d}szul-pa-e3',
#  'sza3-bi-ta',
#  '5(disz) udu',
#  'lu2-ma2',
#  'lugal kal-ga',
#  '3(u) udu',
#  'u3-su-ub',
#  'mu en {d}inanna masz2-e i3-pa3',
#  '1(disz) dub-sa-du3 zabar',
#  '2(disz) kusz balag',
#  'giri3 lu2-{d}nin-gir2-su dumu e2-ki gu-za-la2',
#  'szunigin 1(gesz2) 1(u) 8(disz) gurusz',
#  '1(gesz2) 4(u) ku6 kun-zi saga',
#  '1(disz) gu4 niga 4(disz) udu niga',
#  '5(u) la2 1(disz) {gesz}u3-suh5 szu-dim2 ma2 3(u) gur',
#  'ugula lu2-dingir-ra',
#  '4(asz) 1(ban2) 3(disz) sila3 sze munu4',
#  '2(u) la2 1(disz) gu4 u2',
#  'en-zu',
#  '2(asz@90) ku3 sa10 gin2 dingir-lu2-mah2',
#  '... GAN2 a-sza3 ka-ma-ri2{ki}',
#  'ma2-lah4',
#  'lu2-{d}gesz-bar-e3 tug2-du8',
#  'x udu a-lum niga saga us2',
#  'szubur',
#  'u4 2(u) 8(disz)-kam',
#  'lu2-usz-gi-na szesz-gal',
#  '1(gesz2) gurusz u4 1(disz)-sze3',
#  '1(disz) udu {d}en-ki',
#  'lugal uri5{ki}-ma',
#  'iti gu4-ra2-bi2-mu2',
#  'e2 {d}en-lil2-ka',
#  '5(u) gil-kisal gid2 4(disz) 1/2(disz) ninda-ta',
#  'ki-la2-bi 1(disz) 2/3(disz) ma-na siki kur-ra {gesz}ga-rig2 ak',
#  '1(disz) ba-zi',
#  'dub-sar',
#  'tug2 ki-la2 tag-ga',
#  '... dur3 su-su ... la-ga-x-x',
#  'ta-sze-ni2-la2',
#  'e2 {d}szul-gi',
#  'igi i-me-ru-sza',
#  '...-x szu-x-x',
#  '2(barig) ...',
#  '1(disz) lugal-geszkim-zi dumu ur-{d}nin-urta',
#  'nig2-gu-sur',
#  '1(u) 1(disz) masz2',
#  '3(asz) 4(barig) 4(ban2) sze gur',
#  '1(disz) mu-ni-na-ga-me',
#  'gu-u2-gu-a',
#  'ur-eme2-ga',
#  'dumu du-du',
#  '5(u) 8(disz) ad7 udu u2',
#  'ma2 gid2-da',
#  '...-x-da-ri-a',
#  'sza3-bi-ta',
#  'ku-ku-a lu2 {gesz}tukul',
#  'nam-ha-ni dub-sar',
#  '8(disz) ur-{d}ba-ba6',
#  'ama-kal-la dam a-al-li2',
#  'giri3 ur-{d}szara2',
#  'giri3 lu2-{d}gesz-bar-e3',
#  '{d}amar-{d}suen',
#  'a2-ne2-kur-ra',
#  '1(ban2) dabin',
#  'dumu gaszam-e-ne du10-UD ha-ra-ab-ak-en',
#  '1(asz) 1(barig) 4(disz) x-...',
#  'iti dal',
#  '1(disz) gu4 amar ga',
#  'zah3 lu2-dingir-ra',
#  '1(asz) 3(barig) sze gur lugal',
#  '{d}urasz ku3-gin7 uszum su-lim-ma izi-gar husz il2-il2-i',
#  'e-na-szum2',
#  'giri3 szusz3 gu4-ke4-ne',
#  '1(disz) gu4 {d}nin-lil2',
#  'mu ... x ...{ki} ba-hul',
#  'lugal-a-ni',
#  '6(disz) tug2 du8-a siki {gesz}garigx(|ZUM.SI|) ak',
#  '1(asz) ur-{d}inanna',
#  '5(u) 1(disz) sar al',
#  '... kalam-ma dalla mu-ni-in-e3',
#  '2(u) 4(disz) tug2',
#  'ki szesz-kur-ra-ta',
#  'szul-utul12-am3',
#  'szunigin 8(disz) gu4 hi-a',
#  'mur-gu4 {d}szara2-sze3',
#  '1(u) 3(disz) kusz gu4',
#  'ubur an-na-ke4 si sa2-e-de3 giri17-zal ki us2-u3-de3',
#  '... ur-ki-gu-la',
#  '7(disz) sila4 ba-ur4 sag u8-sze3',
#  '1(barig) dabin a-ga-de3{ki}',
#  'lugal-a-ni',
#  '1(disz) udu',
#  'szunigin 7(gesz2) 1(u) 2(disz) udu u2',
#  '1(disz) udu',
#  'u4 1(disz)-kam',
#  '1(u) 5(asz) ninda',
#  'umma{ki}',
#  '2(u) 1(asz) 2(barig) 2(ban2) 4(disz) sila3 sze gur',
#  '4(ban2) kasz du',
#  '3(u) ma-na udu a gar-ra',
#  '2(disz) gin2 i3 2(disz) gin2 naga',
#  'iti szu-esz5-sza',
#  'lugal-inim-gi-na sukkal',
#  'sza3 e2-masz siki igi saga',
#  '{d}en-lil2-la2-ra',
#  'ezem ki garza-ka gesz-hur-bi ba-kur2',
#  '5(disz) sila3 kasz 5(disz) ...',
#  'ki {d}iszkur-gu2-gal',
#  '5(disz) sila3 kasz 5(disz) sila3 ninda 2(disz) sa szum2',
#  '5(ban2) 2(disz) sila3 ninda saga igi-5(disz)-gal2-bi 1(ban2) 1/3(disz) sila3 4(disz) gin2',
#  '1(disz) gukkal gesz-du3 babbar',
#  'sze-bi 2(u) 7(asz) gur',
#  'ensi2',
#  'e-la-a sukkal',
#  '1(u) 3(disz) udu niga saga us2',
#  '3(gesz2) sze gur lugal',
#  'u4 gu4 masz-da-re-a-sze3 im-gen-na-a',
#  'giri3 ur-mes szabra',
#  'giri3 {d}nanna-ma-ba dub-sar',
#  '1(gesz2) 1(u) 8(disz) sa gu gada x 9(asz) gu2',
#  '... x zu2-lum ... 1/2(disz) ...',
#  '1(u) 3(disz) u8',
#  'ki-en-gi ki-uri',
#  '3(gesz2) 3(u) 7(disz) udu 1(disz) 1/2(disz) sila3',
#  'szunigin sze dida-bi 4(u) 1(barig) 4(ban2) 4(disz) gur',
#  'i3-dab5',
#  '1(asz) kusz a-ba-mu-na',
#  '4(disz) gu4 niga saga 6(disz) sila3 sze 3(ban2) duh saga-ta',
#  'bala u4 1(u) 9(disz)-kam',
#  'mu hu-uh2-nu-ri{ki} ba-hul',
#  '5(disz) udu niga 1(disz) x niga 1(disz) sila4',
#  'engar sza3-gu4-me',
#  '4(barig) 2(ban2)',
#  '7(disz) gin2 ku3-babbar ziz2-da udu-sze3 ba-la2',
#  'szabra-e2 ug-ti-ke4',
#  'sze-bi 4(u) 8(asz) 2(barig) gur',
#  '|BAD3.AN|{ki}',
#  '4(disz) kusz gu4 al-hul-a',
#  '{gesz}mar-gid2-da',
#  'a-kal-la',
#  '3(disz) sila3 kasz 2(disz) sila3 ninda 5(disz) gin2 szum2',
#  '... s,i-i-ru sza2 AN-e u KI-ti3',
#  'szu ba-ti',
#  'lagasz{ki} 1(|ASZxDISZ|)',
#  'kiszib3 dab-ba',
#  'szunigin 1/2(disz) sila3 szum2 szunigin 1(u) 8(disz) gin2 i3 szunigin 1(u) 2(disz) gin2 naga',
#  '1(disz) ur-{d}lamma dumu ka-da',
#  'ugula ab-ba-gi-na nu-banda3-gu4',
#  'inim e2-i3-gara2',
#  '1(disz) masz2',
#  '5(u) 3(disz) sila3 kasz du',
#  '4(disz) gu4-gesz',
#  'lugal an-ub-da limmu2-ba',
#  '...-me he2-me-en',
#  '5(u) 1(disz) masz2 kiszib3 la-la',
#  '... gu4 szu-gid2',
#  '1(u) 1(asz) {gesz}ur3 tur-tur',
#  '3(disz) sila3 zi3 dub-dub',
#  'sza3-tam ARAD2-zu',
#  '2(iku) GAN2 szuku gab2-ra-ni',
#  'aga3-us2 lugal',
#  'kiszib3 nig2-...',
#  '... 4(asz) e2 x ...',
#  'mu ha-ar-szi ki-masz{ki} ba-hul',
#  '3(disz) gurusz szitim lu2 nig2-{d}ba-ba6',
#  'munus-me',
#  'lu2-usz-gi-na dumu ka5-a-mu',
#  'dumu lu2-gu-la',
#  'u4 nig2-dab5 ma2 nig2-sag-ga2-sze3 im-gen-na-a',
#  'dumu-ni-me',
#  'dumu lugal-ti-da',
#  'u3 ma2 ba-al-la',
#  'ku6 NINA{ki}-sze3',
#  'sze gurx(|SZE.KIN|)-a',
#  'u-bar',
#  'ki an-ki-ta',
#  '6(asz) ninda lugal-lu-ni x',
#  '3(ban2) gesztin had2',
#  'a-ra2 1(disz)-kam',
#  '{d}nin-gir2-su',
#  'a-sza3 e2-duru5 {d}inanna',
#  'mu ...-ba-ka dumu munus-a-ni ensi2 an-sza{ki}-na-ke4 ba-tuku-a',
#  'ki-la2-bi 2(asz) gu2 5(u) ma-na 5(disz) gin2',
#  'iti ezem-{d}dumu-zi',
#  '3(disz) gu4 4(disz) ab2',
#  '1(disz) sila4 ga nu-ur4',
#  'mu-de6 5(|ASZxDISZ|)',
#  'en-dingir-mu',
#  'dub-sar',
#  'a2 zi3 ar3-a',
#  'szu ba-ti',
#  'iti ezem-{d}szul-gi',
#  'zi-ga-am3',
#  '{d}nin-e11-e',
#  '1(gesz2) 1(u) 7(disz) {munus}asz2-gar3',
#  '2(disz) sila3 kasz 2(disz) sila3 ninda',
#  '{gesz}gaba-tab gid2-da',
#  'ur-{d}suen',
#  'ARAD2-zu',
#  'sza3 ki x ...',
#  'mu {gesz}gigir nu-sa2 ku3-sig17 {d}utu',
#  'dub-sar',
#  '1(disz) gu4 mu 1(disz)',
#  'ki-be2 mu-na-gi4',
#  'mu en eridu{ki} ba-hun',
#  'a-ab-ba-ka ambar ba-ni-ib2-dim2-dim2',
#  'ki siki-ke4-ne',
#  '1(ban2) ninda AB 6(disz) sila3 zi3',
#  'szu-nigin2 2(u) 6(disz) ninda bappir3 ba-an-ne2 1(u) du8',
#  'dumu ur-ku3',
#  'mu-kux(DU) s,e-la-szu',
#  'szu ba-ti',
#  '2(disz) gesz sza3 bala-a',
#  'gesz-gi{ki}',
#  'lugal-{d}isztaran',
#  'lugal larsa{ki}-ma',
#  'PAP-PAP-{d}nisaba',
#  'sipa x ...',
#  'lu2-kal-la',
#  'mu si-mu-ru-um{ki} ba-hul',
#  'mu {d}szu-{d}suen lugal',
#  '2(asz) asz-ni',
#  '3(gesz2) 5(asz) 1(barig) 5(ban2) sze gur lugal',
#  '1(az) {kusz}du10-gan bar-si sag10',
#  'ugula ur-{d}en-lil2-la2',
#  '1(disz) a-hu-ni dumu u3-ma-bi',
#  'en-ku3',
#  'x x sze gesz x',
#  'ugula ur-zigum-ma',
#  'u4 nig2 ha-lam-ma sa6-ga ku4-ku4 e-ne ib2-ta-an-gar-ra',
#  '1(disz) id-gur2 i3',
#  '1(asz) gu2 siki',
#  '2(u) ...',
#  'u4 gid2-da ge6 lugud2-da dam gesz-nu2-a mi-ni-ib-nu2-u3-ne',
#  'su:la2 utuwa',
#  '1(disz) ur-{d}isztaran',
#  'iti ezem-{d}szul-gi',
#  'kiszib3 lugal-e-ba-an-sa6',
#  'dumu lu2-sa6-ga',
#  'x-e-si-A2 ur-sag igi zalag-ga zu2-kesz2 gin6-ne2-...',
#  'ki ur-gu2-edin-na-ta',
#  'a-za-bu3',
#  'ugula ur-mes dumu ur-{d}asznan',
#  'szu ba-ti',
#  '1(disz) ma-la-ku udu',
#  'mu 3(disz)-am3',
#  'nin-a-ni ku3 {d}inanna-ke4',
#  'nin-{d}nir-nu-da',
#  'dub-sar',
#  'gesz-hur e2-a-na ma-ra-pa3-pa3-de3',
#  '4(barig) 4(disz) sila3',
#  '1(asz) udu',
#  '{d}inanna-ke4 {tug2}dara4 me 7(disz) gal4-la-na x DU x x',
#  'mu us2-sa bad3 ba-du3 mu us2-sa-a-bi',
#  '1(asz) kas sig15',
#  '1(asz) tul2-ta ...',
#  'kiszib3 ur-{d}suen',
#  'bara2-nam-tar-ra',
#  'szunigin 1(disz) ab2 szu-gi4',
#  'a-ra2 2(disz)-kam',
#  '1(asz) sze gur lugal',
#  '{gesz}kiri6 u8-udu-a{ki}',
#  'n u4-sze3 i3-gu7',
#  'szu-{d}nin-isin2{si}',
#  'e2 ki-ag2-ga2-ni',
#  '3(iku) ur-{d}{sze3}szer7-da',
#  'giri3 u2-du-...',
#  '1(disz) sila4 du 1(disz) masz2 du',
#  'ki na-ba-sa6-ta',
#  '6(gesz2) 7(asz) 2(barig) 5(ban2) 3(disz) sila3 sze gur',
#  'A 8',
#  '1(disz) gu4 libir-a',
#  '1(disz) masz2-gal niga',
#  'mu-kux(DU)',
#  'ba-ab-dab5',
#  'lugal an-ub-da limmu2-ba',
#  'lugal an-ub-da limmu2-ba',
#  'alan TE-ME-bi {d}lamma mah e2-ke4',
#  '1(u) 3(disz) udu masz2 i3-kal-la',
#  'bad3-bi ni2 te-ge26-mu he2-em-i mu-bi he2-em-mi-sa4',
#  '3(disz) sila3 kasz 2(disz) sila3 ninda 5(disz) gin2 szum2',
#  '1(disz) sila4 {d}nin-lil2',
#  'kiszib3 lu2-kal-la',
#  '1(ban2) 5(disz) sila3 lu2-hu-rim3',
#  'i-za-az-me-szar giri17-dab5',
#  'mu ku-ba-tum-sze3',
#  '1(u) 1(disz) gin2 igi-4(disz)-gal2 la2 4(disz) sze',
#  '1(asz) masz2',
#  'zi x-...',
#  'iti sig4 u4 2(u) 7(disz) ba-zal',
#  'mu {d}amar-{d}suen ur-bi2-lum{ki} mu-hul',
#  'tukum-bi lugal-me an-na-kam',
#  'a-ra2 1(disz)-kam',
#  '3(ban2) ra-szim-a-li2-ik',
#  'giri3-se3-ga ensi2-ka',
#  'kiszib3 lu2-{d}ha-ia3',
#  'nam-mah',
#  'a-ki-dingir-szu',
#  'ur-sag kal-ga',
#  'ma-gu10 ma-gu10-a de3-ma-ab-BU-ne',
#  'dub-sar',
#  'mu-na-du3-a',
#  '{d}szul-pa-e3 e2-gal',
#  'lul-da mu a2-na mu abzu-na in-pa3',
#  'ugula lu2-kal-la',
#  '... x gesz-...',
#  '1(disz) temen-da',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  '5(asz) 4(barig) 5(ban2) 5(disz) sila3 sze gur',
#  '2(u) kin-ki-bur-ra',
#  'iti sig4-{gesz}i3-szub-ba-ga2-ra',
#  'bala egir',
#  '{d}nin-gir2-su',
#  'mu en-mah-gal-an-na en {d}x ba-hun',
#  'iti sze-sag11-ku5',
#  'n szagax(|LU2xESZ2|)',
#  'gurusz-e gu-nigin2 3(disz)-ta',
#  'giri3 lu2-{d}nin-gir2-su szabra-e2',
#  'mu ki-masz{ki} ba-hul',
#  '2(u) ma-sab haszhur-duru5',
#  'x-me',
#  'dub-sar',
#  'mu en {d}en-lil2-la2',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  'ba-usz2 u4 1(u) 6(disz)-kam',
#  'sza13-dub-ba',
#  '1(disz) ur-{d}nansze',
#  'umma{ki}',
#  "3(gesz'u) 6(gesz2) 2(u) 3(disz) sar al 5(disz)-ta",
#  'lugal-a-ni',
#  '4(asz) lu2 1(barig)',
#  '2(disz) kusz udu 1(u) 5(disz) gin2 sze-gin2',
#  'szu ba-ti',
#  'szu-nigin2 3(iku) 1/2(iku) 8(disz) sar ki szum2-ma',
#  '3(asz) 3(barig) 5(ban2) 8(disz) 2/3(disz) sila3 x',
#  'iti szu-numun',
#  '1(disz) ur-sag-ub3{ki} szesz-gal',
#  'i7-pa-e3 dumu lugal-uszurx(|LAL2.TUG2|)',
#  'a-sza3 ...',
#  'kiszib3 ensi2',
#  '1(disz) sila4',
#  'mu-na-du3',
#  '3(disz) ma2 1(gesz2) gur 2(ban2)-ta ma2-lah5-bi i3-ib2-u3',
#  '3(ban2) kasz dida en-um-i3-li2',
#  'ga2-nun sanga-ta',
#  'iti imin-kam zal-la-ta',
#  'i7 uri5{ki}-ma',
#  'kiszib3 {d}szara2-kam',
#  'iti ...',
#  'n 2(barig) 5(ban2) sze gur',
#  'kiszib3 ur-{d}nin-gesz-zi-da dumu engar-du10',
#  'ensi2',
#  'szunigin 1(disz) e2 asz gesz BAD',
#  'zi-ga',
#  '3(u) 3(asz) siki bar udu',
#  'e ki-sur-ra',
#  'a2-bi u4 1(gesz2) 4(u) 1(disz)',
#  '4(asz) gu2 gi',
#  'e2 gir2-su{ki}-ka-ni',
#  'dumu ku3-...',
#  'szu-a gi-na',
#  'kiszib3 a-da-ga',
#  'mu {d}amar-{d}suen lugal',
#  '1(disz) la-gi-ip',
#  'ki e2-gal-e-si-ta',
#  '4(asz) ne-sag',
#  'dumu ip-szu-ta',
#  '5(disz) erin2 bala du3 1(u) 4(disz) erin2 bala tusz',
#  'ugula bu3-ka-szuba3',
#  '... e2-na-lu-lu',
#  'u4 1(disz)-kam',
#  '... a-hu-szu-ni',
#  '4(disz) sa gu4 4(disz) kun gu4',
#  'ensi2',
#  'nigin-ba 1(disz) ansze',
#  '... gi-rin-na lal3-e x x x mu-nu2-a',
#  'nibru{ki}-ta gen-na',
#  '{d}nanna-kam sukkal maszkim',
#  'x. ugu2-a ga2-ga2',
#  'gug2 i3-nun-ta he2-em-da-gu7-e',
#  'GAN2 ab-ba-szim',
#  '|BAD3.AN|{ki}-ta',
#  'sa2-du11 kas sig15-kam',
#  'absin3-bi 2(u)',
#  'sze-bi 4(ban2) 5(disz) sila3',
#  'lugal {d}en-lil2-le',
#  '3(ban2) nam-nin-an-na-gam-gam',
#  '2(asz) 2(barig) ba-ha-an-sze-er',
#  '... gu2-na ur-{d}...',
#  'ha-am-mu-ra-pi2 x-a-ni x ...',
#  'i3-dab5',
#  'ki ur-{d}nanna-ta ba-zi',
#  'u3-na-a-du11',
#  'ki u2-sze3-he2-du-ta',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  'mu a-ra2 2(disz)-kam kar2-har{ki} ba-hul',
#  '4(ban2) 8(disz) 1/2(disz) sila3 dabin',
#  '2(u) sar-ta',
#  'mu ur-bi2-lum{ki} ba-hul',
#  '1(disz) i3-li2-mi-szu2',
#  '...-sze3',
#  'mu-na-du3',
#  'A 134d',
#  '1(disz) gu4 niga',
#  'dumu na-wi-ir-dingir',
#  '9(disz) geme2 kikken2 e2-kuruszda',
#  'x kusz udu babbar2',
#  'kas4 i3-dab5',
#  'dumu-la-bu dumu ga-du ra2-gaba',
#  '5(disz) sar e2 du3-a',
#  '...-ka ...',
#  'a mu-na-ru',
#  'mu e2-gal-la-a-sze3',
#  '6(asz) nin-uri3',
#  'szu ba-ti-esz',
#  '{u2}urua{a}{ki}-ta du-ni',
#  'ki-ag2 uri5{ki}-ma',
#  'dumu ...',
#  'n 2(asz) 4(ban2) gur ur-{d}ba-ba6 engar',
#  '3(disz) sila3 kasz du',
#  'n udu kur ur-{d}isztaran',
#  'ugula usz-bar',
#  '1(disz) kiszib3 za-gin3 ka-ba ku3-sig17 gar {kusz}ib2-be2 ku3-babbar',
#  '4(gesz2) 1(u) 5(disz) udu niga',
#  '2(gesz2) 8(asz) masz sza3-du10',
#  'na-ru2-a-bi',
#  '1(asz) 3(ban2) 3(disz) nin-a-e2-ta',
#  'ur-e2',
#  '{kusz}lu-ub2 szi-...',
#  '3(gesz2) 3(u) 7(disz) 1/2(disz) nu-banda3 lugal-igi',
#  '1(asz) gu2 siki du',
#  'zur-zur',
#  'szunigin 2(ban2) 1/3(disz) sila3 za3-hi-li',
#  'mu en {d}inanna unu{ki}-ga masz2-e i3-pa3',
#  '1(disz) ansze 2(disz)',
#  '2(disz) tug2 nig2-lam2 3(disz)-kam us2',
#  'a-sza3 ... us2-sa a-sza3 x x x',
#  'engar ma-gu-ul',
#  'szunigin 1(disz) dumu-munus 1(ban2)',
#  '1(barig) ur-{d}nin-mar{ki}',
#  'n sze n gu2',
#  'bala ur-{d}lamma ensi2 gir2-su{ki}-ka ba-an-zi',
#  '3(iku) GAN2 lugal-lu2',
#  'sza3 umma{ki}-sze3',
#  'ur-{d}nin-gesz-zi-da',
#  '{d}i-bi2-{d}suen-dan-le-ga-du maszkim',
#  'mu e2 {d}szara2 ba-du3',
#  "1(bur'u) GAN2 sze gurx(|SZE.KIN|)-a x-ke4 la2-a",
#  'u4 2(u) 8(disz)-kam',
#  'ugula da-da',
#  '1(bur3) 1(esze3) GAN2 1(u)-ta',
#  'x ... lugal-szu-nir-e',
#  'ad-gi4',
#  '1(disz) lugal-dub-la2',
#  'u4-da inim-ba',
#  'e2-na',
#  'lugal uri5{ki}-ma-ke4',
#  '2(asz) sila4',
#  'ki a-gu-ta',
#  'dingir-ra-bi2 lu2 kin-gi4-a lugal',
#  'abul {d}lugal-gu4-si-su',
#  'a-na i3-li2-za',
#  '2(disz) sila3 esza',
#  '1(barig) lugal-me-lam2',
#  'szesz-kal-la i3-dab5',
#  'sa2-du11 e2-si-bil',
#  'iti {d}li9-si4',
#  '{d}szu-{d}suen',
#  'nu-mu-gal2',
#  '1(disz) {d}szara2-a-mu ugula',
#  '3(disz) eme6-mah2',
#  'n 1(disz) 1/2(disz) gurusz gi zex(SIG7)-a 2(u) sar-ta',
#  '{d}nin-du6-babbar-ra',
#  'zi-ga',
#  '2(iku) 1/2(iku) nagar-gal (x)',
#  'i3-gal2',
#  'libir-am3',
#  '5(disz) sila3 kasz 5(disz) sila3 ninda 2(disz) sa szum2',
#  'lugal uri5{ki}-ma',
#  '3(ban2) kasz du u4 2(u) 8(disz)-kam',
#  'iti 1(u) 1(disz)-kam',
#  'iti pa4-u2-e',
#  'mu {d}i-bi2-{d}suen lugal uri5{ki}-ma-ke4 si-mu-ru-um{ki} mu-hul',
#  'sze-bi 2(gesz2) 5(asz) 3(ban2) gur',
#  'lu2-me-lam2',
#  '1(disz) ma-na im-babbar2',
#  'nam-ti',
#  '1(disz) sila4 {d}nanna',
#  'bur-sag-me',
#  '1(barig) 9(disz) sila3 ninda gal du 1(disz) sila3 duh',
#  'lugal an-ub-da limmu2-ba-ke4',
#  '2(ban2) giri3 lu2-{d}nin-szubur',
#  '5(disz) sila3 kasz saga 3(disz) sila3 ninda',
#  '2(barig) 4(ban2) amar-amar',
#  'gir4-bil-me',
#  '1(disz) a-gu-gu',
#  'dumu lugal-nam-tar-re',
#  'a-szi-an i3-dab5',
#  '5(asz) uruda ma-na',
#  '1(asz) mu-mu',
#  '1(asz) szu-ku6 5(disz)',
#  'lagasz{ki}-ka 4(|ASZxDISZ|)',
#  'u4-ba',
#  'mu {d}szu-{d}suen lugal ma2-gur8-mah {d}en-lil2 {d}nin-lil2 mu-ne-dim2',
#  'uru2-za-gu2',
#  'en {d}inanna',
#  'ki-la2-bi 3(disz) ma-na 1(u) gin2',
#  'ki {d}utu-mu-ta',
#  'x kiszib3 za-gin3',
#  '5(u) 8(asz) 4(ban2) 5(disz) sila3 gur',
#  'mu-kux(DU) x-x-... ensi2 ...',
#  'ur-nigar{gar}',
#  'sza3-gal {ansze}kunga2',
#  'x x x la im-...',
#  'esz3-ta gur-ra sa2-du11',
#  'szunigin 5(u) la2-ia3',
#  '1(asz) NI |MU+UD|',
#  'nig2-gur11 ...',
#  'u4 3(disz)-kam',
#  'sze-ba',
#  '2(bur3) GAN2 a-sza3 sipa',
#  '{d}szul-pa-e3 na-nam al-tar mu-un-da-an-gub',
#  'i-ni-in-gar-ra-a',
#  '1(disz) sa szum2',
#  'ki i3-du8 gal-ta',
#  'ugula {d}szara2-kam',
#  'a-ma-ru-kam',
#  'ARAD2-zu',
#  'gu3-de2-a',
#  'kiszib3 ur-{d}ba-ba6 dumu lugal-szuku',
#  'lagasz{ki}-ke4',
#  'masz a-sza3-ga',
#  '{gisz}i-ri9-na-bi musz-sag-kal-x',
#  '5(disz) sila3 kasz 3(disz) sila3 ninda 3(disz) gin2 szum2 3(disz) gin2 i3 2(disz) gin2 naga',
#  'eb i7 edin-na',
#  'sze-bi 3(asz) gur',
#  'lugal-...',
#  'lu2-du10-ga',
#  '1(gesz2) kusz masz2-gal',
#  'ga2-gi4-ta',
#  'igi 6(disz) en-edin-ne2',
#  'lu2 hun-ga2-me',
#  '8(gesz2) 4(u) gab2-IL2 ku6 nig2-ki 1(barig) 5(ban2) 5(disz) sila3-ta',
#  'i-di3-a',
#  'u4 1(u) 1(disz)-kam',
#  '1(disz) dug gal kasz du',
#  'u3-na-du11',
#  '1(gesz2) 2(asz) 1(ban2) gur',
#  'sa-bu-um{ki}-ta du-ni',
#  'mar-sa-asz-sze3',
#  'dingir-ba-ni',
#  'kiszib3 lu2-sa6-i3-zu',
#  'iti sze-sag11-ku5',
#  'aszgab',
#  'ur-nigar{gar}',
#  'ur-usz-gid2-da dam-gar3',
#  'bala du10 nig2-si-sa2',
#  'mu ha-am-mu-ra-pi2 lugal an {d}inanna {d}na-na-a-a e-ne-bi-ta',
#  '1(barig) 4(disz) bu3-ka',
#  'iti gu4-ra2-bi2-mu2-mu2',
#  'x dur3 1(disz) sag x-sze3',
#  'kiszib3 nu-tuku',
#  'i3-dab5',
#  'gurum2 ak u4 1(u)-kam',
#  'u3 IL2 ansze kunga2-me',
#  'ugula ur-mes',
#  'sanga {d}ga2-tum3-du10',
#  '1(disz) gi ma-an-sim nig2-ar3-ra',
#  '...-ne e2-bi e2-babbar',
#  '1(barig) 2(ban2) 7(disz) sila3 kasz du',
#  'gur zabar-ta',
#  'nu-banda3 ur-{d}ba-ba6',
#  "1(gesz'u) 2(gesz2) 2(u) 7(disz) sa gi kiszib3-bi 6(disz)-am3",
#  'kiszib3 ensi2',
#  'mu {d}szu-kak-ka3 lugal-e iri za-gin3 ku3-sig17 {d}dam-gal-nun-na-ra mu-na-dim2',
#  '1(asz) 1(barig) 3(ban2) ninda gur',
#  'e2-uz-ga',
#  'ka2',
#  'ki gu3-de2-a-ta',
#  'a-sza3-bi 6(bur3) GAN2',
#  '1(u) 1(asz) 1(disz) lu2 1(barig)',
#  '2(u) 1(disz) kusz udu siki mu2',
#  '6(disz) gin2 si-im-du3(NI) dah-ha',
#  '{d}en-ki a tu-da-ni',
#  'ki ur-{d}szara2 ...',
#  '2(gesz2) gir{ku6}',
#  'zar2-ra-a',
#  '2(disz) udu niga 4(disz)-kam us2',
#  '{d}en-lil2-la2-ra',
#  '3(barig) gig lugal',
#  '1(u) 2(asz) geme2 kikken',
#  '4(ban2) sze 4(ban2) ziz2',
#  '2(disz) gin2 i3',
#  'ki lu2-e2-an-na-ta',
#  '... in-nu tesz2 ...',
#  'adkin szeg9',
#  'ki {d}szara2-kam-ta',
#  'iti ezem-{d}me-ki-gal2',
#  'iti 1(disz)-kam',
#  '2(asz) 2(barig) lugal-sza3',
#  '1(barig) 2(ban2) gur kal',
#  '1(disz) tug2 guz-za 4(disz)-kam us2',
#  'e2-a-ni mu-na-ni-kux(KWU147)',
#  'kas3-pu-sza lu2 kin-gi4-a lugal',
#  '1(disz) sila4',
#  'ki bi2-du11-ga-ta',
#  'e2-da',
#  '... su-bala',
#  '1(disz) udu niga ki-a-nag ur-{d}namma',
#  '1(u) 4(disz) ninda gid2 4(disz) sar-ta',
#  'iti u4 1(u) 5(disz) ba-zal',
#  "szunigin 1(bur'u) 5(bur3) 2(esze3) 2(iku) 1/2(iku) GAN2 masz nu-tuku",
#  'lugal-a-ni',
#  '1(gesz2) ninda 2/3(asz) kasz 5(ban2) dan-num2',
#  'ki-la2-bi 3(u) 6(disz) 1/2(disz) ma-na 5(disz) gin2',
#  'e2-gal-e-si',
#  'ugu2 ad-da-gu-ka ba-a-gar',
#  '{d}szu-{d}suen',
#  'szunigin 4(disz) sila3 esza',
#  '1(disz) szesz-kal-la',
#  '... ki x ...',
#  '1(u) 8(disz) 1/2(disz) ninda 5(disz) kusz3 kur hi',
#  'n 2(disz) lugal-a-ni-x',
#  'di4-di4-la2 ur2 ama-bi ne-a ku6-sze6 a ba-ab-...',
#  'iti {gesz}apin-du8-a',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  '2(disz) sila3 lu2-{d}utu maszkim',
#  'lu2 e2-ninnu',
#  'A 93',
#  '1(disz) amar-masz-da3 e2-uz-ga',
#  'ur-PA-ke4',
#  'gaba-ri',
#  'mu {d}szu-{d}suen lugal',
#  'nam-szub eridu{ki}-ga pazur5-pazur5 mu-silig-e abzu-a',
#  'mi2-gu10 di nig2-ge-na-ka ka-ga14 mu-szi-gal2',
#  'e2-ninnu anzu2{muszen}-babbar2-ra-ni',
#  'gesz-gi4-gal2-bi-im',
#  '4(disz) sila3 lu2-{d}nanna',
#  'a-bi2-si2-im-ti',
#  '|KI.LUGAL.GUB| til3-la-da ni2 teg3-ge26-da-ne2-esz gur-gur-re-da-ne2-esz',
#  'nig2-la2-sag-ku6',
#  '1(asz) tug2 ib2-du3 udu sze gu7-a',
#  'szunigin 7(asz) ansze',
#  'dumu lugal-ku3-ga-ni',
#  'sze-bi 1(u) 4(asz) 4(barig) 3(disz) 1/3(disz) sila3 gur',
#  '1(ban2) al-mu',
#  'zi-ga',
#  'n ... lugal-nig2',
#  'ki lu2-dingir-ra-ta',
#  '3(disz) sila3 kasz 2(disz) sila3 ninda 5(disz) gin2 szum2 3(disz) gin2 i3 2(disz) gin2 naga',
#  '1(u) 2(asz) 4(barig) 3(ban2) 6(disz) sila3 gur',
#  'ki ur-{d}li9-si4-ta',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  ...]

# %%
demo=lines[0:150]

# %%
demo
# Out:
# ['sag-ki hu-mu-ra-ab-zalag-ge',
#  'ki na-sa6-ta',
#  'iti szu-numun-ta',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  'ba-de6',
#  'mu us2-sa ki-masz{ki} ba-hul',
#  '1(asz) gu4 ab2',
#  '1(barig) 1(ban2) 5(disz) 1(disz) 1/2(disz) geme2-{d}szul-pa-e3 dumu-ni',
#  '1(asz) 2(ban2) nam-nin-...',
#  'dumu ur-{d}nansze',
#  'gu4 udu niga u2-sa',
#  'e2 kiszib3-ba-kam',
#  '1(disz) du-du-am3 u3 lugal-ba-tuku',
#  '{d}nin-sun2',
#  'nig2-du7-e pa mu-na-e3',
#  '2(ban2) ...',
#  'dub-sar',
#  '1(disz) {munus}asz2-gar3',
#  '8(disz) sila3 4(disz) gin2 tab-be-li2 u3 dan-num2',
#  'dumu lu2-ga',
#  'ur-kalam na-gada i3-dab5',
#  '1(disz) munu4 si-e3',
#  '1(u) 2(disz) gaszam',
#  '2(gesz2) 3(u) 7(disz) udu 1(disz) sila3',
#  'dub-sar',
#  '5(disz) 1/2(disz) ma-na 5(disz) gin2 siki tug2 guz-za 3(disz)-kam us2',
#  '5(ban2) 1(u) ba-at-ri',
#  '2(disz) sila3 nig2-ar3-ra saga',
#  '4(u) ka-dug ku3-babbar',
#  'e2-masz-sze3',
#  'ur-ma-ma lu2 bu3',
#  'iti pa4-u2-e',
#  'szunigin 1(disz) la2-ia3',
#  '4(ban2) nin-tesz2-mu',
#  '1(disz) szul-lu5 nu-{gesz}kiri6',
#  'n gu2 siki tug2 guz-za du',
#  '... nin-a-zu',
#  'szunigin 7(disz) gu4 mu 2(disz)',
#  '{d}inanna',
#  'dumu ur-e2-ninnu',
#  '1(disz) i3-li2-an-dul3',
#  '3(disz) gin2 i3 2(disz) gin2 naga',
#  '1(barig) ama-na',
#  'szunigin 8(disz) dumu 1(ban2) 5(disz) sila3-ta',
#  'din |SZE.NUN&NUN|{+i-ti-sze-x}',
#  'iti ezem-{d}dumu-zi',
#  'szu ba-an-ti',
#  'du11-ga-ni si bi2-sa2',
#  '1(u) 8(disz) gurusz gub-ba la2-ia3 1(u) 5(disz)',
#  'kasz-de2-a ur-{d}iszkur ensi2 ha-ma-zi2{ki}',
#  'mu-na-ba-al',
#  'lu2-kal-la',
#  'sza3-ge engar',
#  '4(barig) ama-masz-min3',
#  'lugal an-ub-da limmu2-ba',
#  'szunigin 3(gesz2) 4(asz) 3(barig) 2(ban2) gur',
#  '5(asz) zi3',
#  '2(disz) sila3 ur3-re-ba-du7',
#  'ki e2 {d}nanna',
#  '1(asz) us2 e2-engur-ka',
#  'bahar3-e-ne szu ba-ab-ti',
#  'mu us2-sa bad3 ma-da ba-du3',
#  '... gur',
#  'ur-e2-an-na',
#  '5(disz) gu2 {u2}nin9',
#  '1(u) 2(asz) ur-gu-la',
#  'dub-sar',
#  'iti GAN2-masz',
#  'dumu nin-iri-ni-sze3',
#  'sza13-dub-ba-ka',
#  'dumu ba-zi',
#  'mu ur-bi2-lum{ki} ba-hul-sze3',
#  'lagasz{ki}-ke4',
#  'ki-la2-bi 2(asz) gu2 2(u) 4(disz) ma-na',
#  'sa2-du11 {d}nin-sun2',
#  'diri x tug2 guz-za x',
#  '1(disz) udu',
#  'szunigin 4(bur3) n GAN2',
#  'tug2 ki-la2 tag-ga',
#  'mu ma-da za-ab-sza-li{ki} ba-hul',
#  'giri3 ri-ib-hu-ti',
#  'mu en ga-esz5{ki}',
#  'iti diri me-ki-gal2 u2-sa',
#  '1(disz) udu niga 4(disz)-kam us2',
#  'szesz-da-da sanga',
#  'x x-na-sze3 ba-ra-da-du-de3-en',
#  '1(asz) geme2 3(ban2)',
#  'lugal uri5{ki}-ma',
#  '2(ban2) ga-ar3',
#  '{d}gesztin-an-na',
#  '{d}szul-gi',
#  '4(disz)',
#  'szunigin 2(asz) 3(ban2) nig2-ar3-ra saga gur',
#  'ki szu-{d}nin-kar-ak-ta',
#  '1(disz) kusz udu a-gar gu7-a',
#  'ki {d}iszkur-illat-ta',
#  'ugula ur-{d}nin-su',
#  'kiszib3 ur-{d}nun-gal',
#  'ganun ka i7 tum-al-ta',
#  '1(gesz2) 3(u) 3(asz) gesztin gal-gal',
#  '1(asz) kinda',
#  '2(u) 3(ban2) gur 5(disz) sila3 sze du',
#  'dab6-ru-um{ki}-ma ba-an-sa6',
#  'u3 gag',
#  '5(asz) 3(barig) 2(ban2) ur-{d}ba-ba6 dumu ur-nig2',
#  'dumu lugal-{gesz}kiri6',
#  '1(disz) sila4 kiszib3 ur-{d}en-ki kuruszda',
#  'dumu-munus-a-ni',
#  'an-na-ag2',
#  'iti nesag',
#  'naga-bi 1(barig) 1(ban2) 1/2(disz) sila3',
#  'giri3 lu2-{d}nanna dumu ba-ba',
#  'iti ezem-{d}...',
#  'szu-{d}suen',
#  'zi-ga',
#  'RU-lugal-me',
#  'mu mu-na-sa4',
#  'ka ba-ab-kesz2',
#  'mar-sa-asz mu-kux(DU)',
#  'u4 1(u) 3(disz)-sze3 ka-sahar-ta',
#  '2(asz) MI-si4-ad',
#  'mu ki-masz{ki} u3 hu-ur5-ti{ki} ba-hul',
#  '1(esze3) 4(iku)',
#  '5(asz) sze gur lugal',
#  '1/3(disz) ma-na x gin2 ku3 sze x x',
#  'baharx(EDIN)-ri',
#  'iti 1(disz)-kam',
#  '6(disz) 1/2(disz) gin2 6(disz) sze ku3',
#  'iti {d}dumu-zi-sze3',
#  'ugula ur-mes',
#  '{d}nin-gir2-su',
#  'gesztu2 dagal nig2-nam gal-le-esz zu',
#  'gu-nigin2-bi 7(gesz2) 2(u) 7(disz) 5/6(disz)',
#  'an-nu-ni-tum',
#  '2(u) {uruda}gur10 a-ra2 2(disz)-kam',
#  'ka-ma-ri2{ki}-ta',
#  '2(bur3) 1(esze3) la2 1/2(iku)',
#  'udu 1(asz)-sze3',
#  '1(disz) a-kal-la dumu e2-an-ne2',
#  'sipa gu4 niga',
#  '1(barig) e2-ki-bi',
#  'sa2-du11 ki-a-nag sza3-ba-na-sig szabra',
#  'gaba-ri',
#  'giri3 a-gu-a-ni dub-sar',
#  '1(gesz2) 1(u) 1(disz) x gur',
#  '1(asz) udu {d}en-...',
#  '1(asz) ni-ni',
#  'lu2-kal-la',
#  'e2-muhaldim-sze3',
#  'szunigin 4(asz) ansze ...']

# %%
def savefile(filename,LIST):
    with open(filename, 'w') as f:
        for line in LIST:
            f.write("%s\n" % line)
            
            
savefile("Dataset/sumerian_demo.txt",demo)
